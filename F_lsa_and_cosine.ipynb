# %% [markdown]
# # LSA - Latent Semantic Analysis (Phân tích ngữ nghĩa tiềm ẩn)
#
# - LSA là 1 phương pháp chủ yếu sử dụng trong NLP. LSA được sử dụng để tìm ra các “chủ đề ẩn” trong Corpus, từ đó tạo ra một không gian ngữ nghĩa tiềm ẩn (Latent Semantic Space) và chiếu các vector văn bản và vector token lên không gian đó. Sự khác biệt so với PCA: LSA được thiết kế để hoạt động trên các dạng ma trận từ ngữ - văn bản (TDM) như đầu ra của TF-IDF. LSA không căn giữa dữ liệu đầu văn như PCA. LSA sử dụng khai triển kì dị rút gọn (Truncated SVD) là cơ chế chính cho việc giảm chiều dữ liệu.
# - Vậy, với ma trận TF-IDF gốc, ta có thể hiểu mỗi vector văn bản là 1 sample, và mỗi vector token là 1 đặc trưng, đo độ “quan trọng” của token đó với văn bản cụ thể đó. Điều này dẫn tới không gian lớn và thưa. LSA sẽ giảm chiều của không gian đặc trưng đó từ các token riêng biệt xuống các “chủ đề ẩn” ở đó ma trận TDM sẽ dày hơn và nhỏ hơn, không chỉ giảm tính toán mà còn giúp ta có thể khám phá các “chủ đề ẩn” này.
#
# ### Khai triển kì dị rút gọn
# Giả sử ma trận $ W \in \mathbb{R}^{n \times N} $ là ma trận TF-IDF gốc của chúng ta, trong đó có $ n $ hàng đại diện cho các vector token và $ N $ cột đại diện cho các vector văn bản, khi đó khai triển kì dị rút gọn được định nghĩa như sau:
#
# $$ W \approx W_k = U_k \Sigma_k V_k^T $$
#
# Trong đó:
# - $ k $ là số chủ đề tiềm ẩn ta mong muốn tìm.
# - $ W_k \in \mathbb{R}^{n \times N} $ là một ma trận xấp xỉ thiểu hạng của ma trận gốc $ W $.
# - $ U_k \in \mathbb{R}^{n \times k} $ là ma trận thể hiện MQH token - topic, theo hàng.
# - $ \Sigma_k \in \mathbb{R}^{k \times k} $ là ma trận chéo chứa các giá trị kì dị, hay độ quan trọng của mỗi topic theo thứ tự giảm dần.
# - $ V_k^T \in \mathbb{R}^{k \times N} $ là ma trận thể hiện MQH doc. - topic, theo cột.
#
# ### Thể hiện các token và văn bản trong không gian tiềm ẩn
#
# - LSA sẽ tạo ra không gian tiềm ẩn mà trong đó các chủ đề tiềm ẩn được coi là các chiều.
# - Sử dụng các hàng của $ U_k $, ta có thể biểu diễn các token trong không gian tiềm ẩn này.
# - Sử dụng các cột của $ D_k = \Sigma_k V_k^T \in \mathbb{R}^{k \times N} $, ta có thể biểu diễn các văn bản trong không gian tiềm ẩn này
# - Kết hợp cả biểu diễn token và văn bản trên cùng 1 biểu đồ, ta thu được Biplot.

# %%
# Nhập thư viện
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

import warnings
warnings.filterwarnings('ignore')

import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

# Đọc bộ dữ liệu
corpus = pd.read_csv('data/cleaned_mhc.csv')

# %%
n_topics = 2
n_top_words = 15
n_top_docs = 15

vectorizer = TfidfVectorizer(max_features=3500)
svd_model = TruncatedSVD(n_components=n_topics, random_state=42)

X_cleaned_tfidf = vectorizer.fit_transform(corpus['text'])
X_latent = svd_model.fit_transform(X_cleaned_tfidf)

def display_topics_and_docs(model, feature_names, num_top_words, X_latent, n_top_docs):
    for idx, topic in enumerate(model.components_):
        top_words = [feature_names[i] for i in topic.argsort()[:-num_top_words - 1:-1]]
        print(f"\nTopic {idx + 1}: {', '.join(top_words)}")
        
        top_doc_indices = np.argsort(X_latent[:, idx])[:-n_top_docs - 1:-1]
        print(f"Top {n_top_docs} documents for Topic {idx + 1}:")
        for doc_idx in top_doc_indices:
            label = corpus['label'].iloc[doc_idx]
            text_preview = corpus['text'].iloc[doc_idx][:100]
            print(f"Class {label}: {text_preview} ...")

print("\nTop topics and their representative documents in Cleaned Corpus:")
display_topics_and_docs(svd_model, vectorizer.get_feature_names_out(), n_top_words, X_latent, n_top_docs)
# Out:
# Top topics and their representative documents in Cleaned Corpus:
#
# Topic 1: im, want, like, feel, know, life, ive, get, cant, dont, friend, time, people, even, one
# Top 15 documents for Topic 1:
# Class 1: yet another fucking post even know happened feel bad swear mood swing easily distinct one closest fr ...
# Class 1: fuck made post talked situation little friend leaving college parent really like care long im fed re ...
# Class 1: gonna long rant feel free skip want feel fucking hopeless wrote redflag note month ago parent found  ...
# Class 1: actually feel alright thats past year going quite well outside ive started leaving house pretty much ...
# Class 1: hopeless reddit im longtime lurker need help family friend connected avenue communication feel comfo ...
# Class 1: wanting kill since grade im scared please listen know anymore im last straw everything im going give ...
# Class 1: understand life know im posting feel ashamed im posting want die want live feel like ive never reall ...
# Class 1: want write something need write something guess add anxiety bipolar disorder im poor get help medica ...
# Class 1: amp im scared always sad since ive antidepressant since still feel sad world make sad cruel mean peo ...
# Class 1: want kill even know life good mother love love friend love boyfriend love go law school hard home re ...
# Class 1: go hospital suicidal typo im mobile feeling well class worst mental health life nearly every day wan ...
# Class 1: get stressed want die feel like everything much im frustrated want cry time cant find summer job kno ...
# Class 1: less year objectively believe im going give thought believe going write redflag note fully committed ...
# Class 1: feel lost decided im going start writing thing phone similar journal started tonight ive feeling pre ...
# Class 1: im much pain im exhausted im ready go nowmy name bell im year old less hour ago pointed air rifle he ...
#
# Topic 2: movie, film, one, character, great, story, good, scene, well, see, also, time, first, seen, watch
# Top 15 documents for Topic 2:
# Class 0: still cant describe feel received site rare movie little spoken known difficult find even fan contra ...
# Class 0: people chase movie featuring audrey seem understand character really audrey real life personality he ...
# Class 0: reason movie better known appreciated seems subject controversial subject movie never got proper big ...
# Class 0: spielberg first dramatic film letdown beautifully made film without flaw life africanamerican woman  ...
# Class 0: film blade master may cheap clumsy appearance sometimes share thought problem way beyond era film se ...
# Class 0: industry dropped ball trailer movie justice opened hand full screen people opportunity see work mout ...
# Class 0: police investigation murder suspicion movie film nowadays deal crime believed involve viewer provide ...
# Class 0: boogie night one best film come go far say imdb top actually understand many would dislike due subje ...
# Class 0: im fan especially gackt first discover movie watch trailer think silly long waiting time watched las ...
# Class 0: fury good film good cast includes paul molina mark francisco ramn jos javier acting actor good reall ...
# Class 0: movie modern day movie one rare epic film make want sequel especially liked damian performance deser ...
# Class 0: world oldschool kung movie revenge picture came dime dozen took lot film stand even make fan favorit ...
# Class 0: movie may seemed like much people everything look comedy fall funny moment accompanied moment two se ...
# Class 0: movie bad people want make believe isbr reason many people hate movie laurel hardy last one together ...
# Class 0: movie really well made one great looking passionately directed tell every shot thought executed perf ...

# %%
from IPython.display import display, HTML

def style_df_with_highlights(df, highlight_terms):
    def highlight_words(val):
        if isinstance(val, str) and val.upper() in [term.upper() for term in highlight_terms]:
            return 'background-color: #800080'
        return ''
    
    return df.style.applymap(highlight_words)

def display_topics_tabular(model, feature_names, num_top_words, highlight_terms, words_per_row=15):
    topic_dfs = []
    
    for idx, topic in enumerate(model.components_):
        top_words = [feature_names[i] for i in topic.argsort()[:-num_top_words - 1:-1]]
        top_words = [word.upper() if word in highlight_terms else word for word in top_words]
        
        num_rows = (len(top_words) + words_per_row - 1) // words_per_row
        
        rows = []
        for row in range(num_rows):
            start_idx = row * words_per_row
            end_idx = min(start_idx + words_per_row, len(top_words))
            row_words = top_words[start_idx:end_idx]
            row_words.extend([''] * (words_per_row - len(row_words)))
            rows.append(row_words)
        
        df = pd.DataFrame(
            rows,
            columns=[f'Token_{i+1}' for i in range(words_per_row)]
        )
        
        df.index = [f'Row_{i+1}' for i in range(len(df))]
        
        topic_dfs.append((idx + 1, df))

    for topic_num, df in topic_dfs:
        print(f"\nTopic {topic_num}")
        
        styled_df = style_df_with_highlights(df, highlight_terms)
        
        display(styled_df)
        print("\n")

highlight_terms = ['suicidal', 'depression', 'suicide', 'kill', 'myself', 'die',
                   'died', 'pain', 'sad', 'help', 'sorry', 'anxiety', 'therapy',
                   'suffering', 'killing', 'pill', 'depressed', 'death', 'cry', 'redflag', 'tired',
                   'movie', 'film', 'character', 'story', 'actor', 'performance', 'show',
                   'plot', 'acting', 'scene', 'watch', 'seen', 'funny', 'dvd', 'drama', 
		   'dialouge', 'entertaining', 'hollywood', 'humor', 'star', 'horror', 'series',
		   'genre', 'production', 'cinema', 'effect', 'audience', 'picture', 'actress']

n_topics = 3
n_top_words = 195
svd_model = TruncatedSVD(n_components=n_topics, random_state=42)

X_cleaned_tfidf = vectorizer.fit_transform(corpus['text'])
svd_model.fit(X_cleaned_tfidf)
print("\nTop topics in Corpus:")
display_topics_tabular(svd_model, vectorizer.get_feature_names_out(), n_top_words, highlight_terms)
# Out:
# Top topics in Corpus:
#
# Topic 1
# <style type="text/css">
# #T_8e708_row1_col8, #T_8e708_row2_col4, #T_8e708_row2_col13, #T_8e708_row4_col0, #T_8e708_row4_col10, #T_8e708_row5_col8, #T_8e708_row6_col6, #T_8e708_row6_col11, #T_8e708_row7_col8, #T_8e708_row8_col5, #T_8e708_row9_col4, #T_8e708_row9_col7, #T_8e708_row9_col8, #T_8e708_row10_col0, #T_8e708_row11_col6, #T_8e708_row12_col6 {
#   background-color: #800080;
# }
# </style>
# <table id="T_8e708">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8e708_level0_col0" class="col_heading level0 col0" >Token_1</th>
#       <th id="T_8e708_level0_col1" class="col_heading level0 col1" >Token_2</th>
#       <th id="T_8e708_level0_col2" class="col_heading level0 col2" >Token_3</th>
#       <th id="T_8e708_level0_col3" class="col_heading level0 col3" >Token_4</th>
#       <th id="T_8e708_level0_col4" class="col_heading level0 col4" >Token_5</th>
#       <th id="T_8e708_level0_col5" class="col_heading level0 col5" >Token_6</th>
#       <th id="T_8e708_level0_col6" class="col_heading level0 col6" >Token_7</th>
#       <th id="T_8e708_level0_col7" class="col_heading level0 col7" >Token_8</th>
#       <th id="T_8e708_level0_col8" class="col_heading level0 col8" >Token_9</th>
#       <th id="T_8e708_level0_col9" class="col_heading level0 col9" >Token_10</th>
#       <th id="T_8e708_level0_col10" class="col_heading level0 col10" >Token_11</th>
#       <th id="T_8e708_level0_col11" class="col_heading level0 col11" >Token_12</th>
#       <th id="T_8e708_level0_col12" class="col_heading level0 col12" >Token_13</th>
#       <th id="T_8e708_level0_col13" class="col_heading level0 col13" >Token_14</th>
#       <th id="T_8e708_level0_col14" class="col_heading level0 col14" >Token_15</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e708_level0_row0" class="row_heading level0 row0" >Row_1</th>
#       <td id="T_8e708_row0_col0" class="data row0 col0" >im</td>
#       <td id="T_8e708_row0_col1" class="data row0 col1" >want</td>
#       <td id="T_8e708_row0_col2" class="data row0 col2" >like</td>
#       <td id="T_8e708_row0_col3" class="data row0 col3" >feel</td>
#       <td id="T_8e708_row0_col4" class="data row0 col4" >know</td>
#       <td id="T_8e708_row0_col5" class="data row0 col5" >life</td>
#       <td id="T_8e708_row0_col6" class="data row0 col6" >ive</td>
#       <td id="T_8e708_row0_col7" class="data row0 col7" >get</td>
#       <td id="T_8e708_row0_col8" class="data row0 col8" >cant</td>
#       <td id="T_8e708_row0_col9" class="data row0 col9" >dont</td>
#       <td id="T_8e708_row0_col10" class="data row0 col10" >friend</td>
#       <td id="T_8e708_row0_col11" class="data row0 col11" >time</td>
#       <td id="T_8e708_row0_col12" class="data row0 col12" >people</td>
#       <td id="T_8e708_row0_col13" class="data row0 col13" >even</td>
#       <td id="T_8e708_row0_col14" class="data row0 col14" >one</td>
#     </tr>
#     <tr>
#       <th id="T_8e708_level0_row1" class="row_heading level0 row1" >Row_2</th>
#       <td id="T_8e708_row1_col0" class="data row1 col0" >really</td>
#       <td id="T_8e708_row1_col1" class="data row1 col1" >year</td>
#       <td id="T_8e708_row1_col2" class="data row1 col2" >would</td>
#       <td id="T_8e708_row1_col3" class="data row1 col3" >think</td>
#       <td id="T_8e708_row1_col4" class="data row1 col4" >thing</td>
#       <td id="T_8e708_row1_col5" class="data row1 col5" >day</td>
#       <td id="T_8e708_row1_col6" class="data row1 col6" >going</td>
#       <td id="T_8e708_row1_col7" class="data row1 col7" >go</td>
#       <td id="T_8e708_row1_col8" class="data row1 col8" >HELP</td>
#       <td id="T_8e708_row1_col9" class="data row1 col9" >never</td>
#       <td id="T_8e708_row1_col10" class="data row1 col10" >make</td>
#       <td id="T_8e708_row1_col11" class="data row1 col11" >much</td>
#       <td id="T_8e708_row1_col12" class="data row1 col12" >anymore</td>
#       <td id="T_8e708_row1_col13" class="data row1 col13" >fucking</td>
#       <td id="T_8e708_row1_col14" class="data row1 col14" >thought</td>
#     </tr>
#     <tr>
#       <th id="T_8e708_level0_row2" class="row_heading level0 row2" >Row_3</th>
#       <td id="T_8e708_row2_col0" class="data row2 col0" >way</td>
#       <td id="T_8e708_row2_col1" class="data row2 col1" >good</td>
#       <td id="T_8e708_row2_col2" class="data row2 col2" >someone</td>
#       <td id="T_8e708_row2_col3" class="data row2 col3" >anything</td>
#       <td id="T_8e708_row2_col4" class="data row2 col4" >DIE</td>
#       <td id="T_8e708_row2_col5" class="data row2 col5" >need</td>
#       <td id="T_8e708_row2_col6" class="data row2 col6" >end</td>
#       <td id="T_8e708_row2_col7" class="data row2 col7" >talk</td>
#       <td id="T_8e708_row2_col8" class="data row2 col8" >better</td>
#       <td id="T_8e708_row2_col9" class="data row2 col9" >everything</td>
#       <td id="T_8e708_row2_col10" class="data row2 col10" >hate</td>
#       <td id="T_8e708_row2_col11" class="data row2 col11" >love</td>
#       <td id="T_8e708_row2_col12" class="data row2 col12" >nothing</td>
#       <td id="T_8e708_row2_col13" class="data row2 col13" >KILL</td>
#       <td id="T_8e708_row2_col14" class="data row2 col14" >family</td>
#     </tr>
#     <tr>
#       <th id="T_8e708_level0_row3" class="row_heading level0 row3" >Row_4</th>
#       <td id="T_8e708_row3_col0" class="data row3 col0" >live</td>
#       <td id="T_8e708_row3_col1" class="data row3 col1" >see</td>
#       <td id="T_8e708_row3_col2" class="data row3 col2" >could</td>
#       <td id="T_8e708_row3_col3" class="data row3 col3" >always</td>
#       <td id="T_8e708_row3_col4" class="data row3 col4" >anyone</td>
#       <td id="T_8e708_row3_col5" class="data row3 col5" >feeling</td>
#       <td id="T_8e708_row3_col6" class="data row3 col6" >school</td>
#       <td id="T_8e708_row3_col7" class="data row3 col7" >care</td>
#       <td id="T_8e708_row3_col8" class="data row3 col8" >still</td>
#       <td id="T_8e708_row3_col9" class="data row3 col9" >say</td>
#       <td id="T_8e708_row3_col10" class="data row3 col10" >something</td>
#       <td id="T_8e708_row3_col11" class="data row3 col11" >every</td>
#       <td id="T_8e708_row3_col12" class="data row3 col12" >got</td>
#       <td id="T_8e708_row3_col13" class="data row3 col13" >back</td>
#       <td id="T_8e708_row3_col14" class="data row3 col14" >work</td>
#     </tr>
#     <tr>
#       <th id="T_8e708_level0_row4" class="row_heading level0 row4" >Row_5</th>
#       <td id="T_8e708_row4_col0" class="data row4 col0" >REDFLAG</td>
#       <td id="T_8e708_row4_col1" class="data row4 col1" >right</td>
#       <td id="T_8e708_row4_col2" class="data row4 col2" >ill</td>
#       <td id="T_8e708_row4_col3" class="data row4 col3" >shit</td>
#       <td id="T_8e708_row4_col4" class="data row4 col4" >keep</td>
#       <td id="T_8e708_row4_col5" class="data row4 col5" >everyone</td>
#       <td id="T_8e708_row4_col6" class="data row4 col6" >ever</td>
#       <td id="T_8e708_row4_col7" class="data row4 col7" >last</td>
#       <td id="T_8e708_row4_col8" class="data row4 col8" >take</td>
#       <td id="T_8e708_row4_col9" class="data row4 col9" >bad</td>
#       <td id="T_8e708_row4_col10" class="data row4 col10" >TIRED</td>
#       <td id="T_8e708_row4_col11" class="data row4 col11" >tell</td>
#       <td id="T_8e708_row4_col12" class="data row4 col12" >job</td>
#       <td id="T_8e708_row4_col13" class="data row4 col13" >point</td>
#       <td id="T_8e708_row4_col14" class="data row4 col14" >happy</td>
#     </tr>
#     <tr>
#       <th id="T_8e708_level0_row5" class="row_heading level0 row5" >Row_6</th>
#       <td id="T_8e708_row5_col0" class="data row5 col0" >parent</td>
#       <td id="T_8e708_row5_col1" class="data row5 col1" >try</td>
#       <td id="T_8e708_row5_col2" class="data row5 col2" >person</td>
#       <td id="T_8e708_row5_col3" class="data row5 col3" >since</td>
#       <td id="T_8e708_row5_col4" class="data row5 col4" >tried</td>
#       <td id="T_8e708_row5_col5" class="data row5 col5" >month</td>
#       <td id="T_8e708_row5_col6" class="data row5 col6" >getting</td>
#       <td id="T_8e708_row5_col7" class="data row5 col7" >alone</td>
#       <td id=
# Topic 2
# <style type="text/css">
# #T_1938c_row0_col0, #T_1938c_row0_col1, #T_1938c_row0_col3, #T_1938c_row0_col5, #T_1938c_row0_col7, #T_1938c_row0_col13, #T_1938c_row0_col14, #T_1938c_row1_col0, #T_1938c_row1_col3, #T_1938c_row1_col4, #T_1938c_row1_col7, #T_1938c_row1_col8, #T_1938c_row1_col9, #T_1938c_row3_col11, #T_1938c_row4_col2, #T_1938c_row4_col6, #T_1938c_row5_col10, #T_1938c_row6_col13, #T_1938c_row7_col10, #T_1938c_row7_col11, #T_1938c_row8_col0, #T_1938c_row8_col9, #T_1938c_row9_col1, #T_1938c_row9_col3, #T_1938c_row9_col4, #T_1938c_row10_col3, #T_1938c_row11_col14, #T_1938c_row12_col14 {
#   background-color: #800080;
# }
# </style>
# <table id="T_1938c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1938c_level0_col0" class="col_heading level0 col0" >Token_1</th>
#       <th id="T_1938c_level0_col1" class="col_heading level0 col1" >Token_2</th>
#       <th id="T_1938c_level0_col2" class="col_heading level0 col2" >Token_3</th>
#       <th id="T_1938c_level0_col3" class="col_heading level0 col3" >Token_4</th>
#       <th id="T_1938c_level0_col4" class="col_heading level0 col4" >Token_5</th>
#       <th id="T_1938c_level0_col5" class="col_heading level0 col5" >Token_6</th>
#       <th id="T_1938c_level0_col6" class="col_heading level0 col6" >Token_7</th>
#       <th id="T_1938c_level0_col7" class="col_heading level0 col7" >Token_8</th>
#       <th id="T_1938c_level0_col8" class="col_heading level0 col8" >Token_9</th>
#       <th id="T_1938c_level0_col9" class="col_heading level0 col9" >Token_10</th>
#       <th id="T_1938c_level0_col10" class="col_heading level0 col10" >Token_11</th>
#       <th id="T_1938c_level0_col11" class="col_heading level0 col11" >Token_12</th>
#       <th id="T_1938c_level0_col12" class="col_heading level0 col12" >Token_13</th>
#       <th id="T_1938c_level0_col13" class="col_heading level0 col13" >Token_14</th>
#       <th id="T_1938c_level0_col14" class="col_heading level0 col14" >Token_15</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1938c_level0_row0" class="row_heading level0 row0" >Row_1</th>
#       <td id="T_1938c_row0_col0" class="data row0 col0" >MOVIE</td>
#       <td id="T_1938c_row0_col1" class="data row0 col1" >FILM</td>
#       <td id="T_1938c_row0_col2" class="data row0 col2" >one</td>
#       <td id="T_1938c_row0_col3" class="data row0 col3" >CHARACTER</td>
#       <td id="T_1938c_row0_col4" class="data row0 col4" >great</td>
#       <td id="T_1938c_row0_col5" class="data row0 col5" >STORY</td>
#       <td id="T_1938c_row0_col6" class="data row0 col6" >good</td>
#       <td id="T_1938c_row0_col7" class="data row0 col7" >SCENE</td>
#       <td id="T_1938c_row0_col8" class="data row0 col8" >well</td>
#       <td id="T_1938c_row0_col9" class="data row0 col9" >see</td>
#       <td id="T_1938c_row0_col10" class="data row0 col10" >also</td>
#       <td id="T_1938c_row0_col11" class="data row0 col11" >first</td>
#       <td id="T_1938c_row0_col12" class="data row0 col12" >time</td>
#       <td id="T_1938c_row0_col13" class="data row0 col13" >SEEN</td>
#       <td id="T_1938c_row0_col14" class="data row0 col14" >WATCH</td>
#     </tr>
#     <tr>
#       <th id="T_1938c_level0_row1" class="row_heading level0 row1" >Row_2</th>
#       <td id="T_1938c_row1_col0" class="data row1 col0" >SHOW</td>
#       <td id="T_1938c_row1_col1" class="data row1 col1" >best</td>
#       <td id="T_1938c_row1_col2" class="data row1 col2" >would</td>
#       <td id="T_1938c_row1_col3" class="data row1 col3" >ACTOR</td>
#       <td id="T_1938c_row1_col4" class="data row1 col4" >PERFORMANCE</td>
#       <td id="T_1938c_row1_col5" class="data row1 col5" >love</td>
#       <td id="T_1938c_row1_col6" class="data row1 col6" >many</td>
#       <td id="T_1938c_row1_col7" class="data row1 col7" >PLOT</td>
#       <td id="T_1938c_row1_col8" class="data row1 col8" >FUNNY</td>
#       <td id="T_1938c_row1_col9" class="data row1 col9" >ACTING</td>
#       <td id="T_1938c_row1_col10" class="data row1 col10" >made</td>
#       <td id="T_1938c_row1_col11" class="data row1 col11" >little</td>
#       <td id="T_1938c_row1_col12" class="data row1 col12" >cast</td>
#       <td id="T_1938c_row1_col13" class="data row1 col13" >role</td>
#       <td id="T_1938c_row1_col14" class="data row1 col14" >saw</td>
#     </tr>
#     <tr>
#       <th id="T_1938c_level0_row2" class="row_heading level0 row2" >Row_3</th>
#       <td id="T_1938c_row2_col0" class="data row2 col0" >man</td>
#       <td id="T_1938c_row2_col1" class="data row2 col1" >two</td>
#       <td id="T_1938c_row2_col2" class="data row2 col2" >make</td>
#       <td id="T_1938c_row2_col3" class="data row2 col3" >comedy</td>
#       <td id="T_1938c_row2_col4" class="data row2 col4" >watching</td>
#       <td id="T_1938c_row2_col5" class="data row2 col5" >part</td>
#       <td id="T_1938c_row2_col6" class="data row2 col6" >play</td>
#       <td id="T_1938c_row2_col7" class="data row2 col7" >lot</td>
#       <td id="T_1938c_row2_col8" class="data row2 col8" >music</td>
#       <td id="T_1938c_row2_col9" class="data row2 col9" >director</td>
#       <td id="T_1938c_row2_col10" class="data row2 col10" >new</td>
#       <td id="T_1938c_row2_col11" class="data row2 col11" >woman</td>
#       <td id="T_1938c_row2_col12" class="data row2 col12" >real</td>
#       <td id="T_1938c_row2_col13" class="data row2 col13" >quite</td>
#       <td id="T_1938c_row2_col14" class="data row2 col14" >action</td>
#     </tr>
#     <tr>
#       <th id="T_1938c_level0_row3" class="row_heading level0 row3" >Row_4</th>
#       <td id="T_1938c_row3_col0" class="data row3 col0" >excellent</td>
#       <td id="T_1938c_row3_col1" class="data row3 col1" >fun</td>
#       <td id="T_1938c_row3_col2" class="data row3 col2" >girl</td>
#       <td id="T_1938c_row3_col3" class="data row3 col3" >look</td>
#       <td id="T_1938c_row3_col4" class="data row3 col4" >fan</td>
#       <td id="T_1938c_row3_col5" class="data row3 col5" >could</td>
#       <td id="T_1938c_row3_col6" class="data row3 col6" >come</td>
#       <td id="T_1938c_row3_col7" class="data row3 col7" >interesting</td>
#       <td id="T_1938c_row3_col8" class="data row3 col8" >young</td>
#       <td id="T_1938c_row3_col9" class="data row3 col9" >really</td>
#       <td id="T_1938c_row3_col10" class="data row3 col10" >guy</td>
#       <td id="T_1938c_row3_col11" class="data row3 col11" >DVD</td>
#       <td id="T_1938c_row3_col12" class="data row3 col12" >like</td>
#       <td id="T_1938c_row3_col13" class="data row3 col13" >must</td>
#       <td id="T_1938c_row3_col14" class="data row3 col14" >beautiful</td>
#     </tr>
#     <tr>
#       <th id="T_1938c_level0_row4" class="row_heading level0 row4" >Row_5</th>
#       <td id="T_1938c_row4_col0" class="data row4 col0" >year</td>
#       <td id="T_1938c_row4_col1" class="data row4 col1" >people</td>
#       <td id="T_1938c_row4_col2" class="data row4 col2" >HORROR</td>
#       <td id="T_1938c_row4_col3" class="data row4 col3" >wonderful</td>
#       <td id="T_1938c_row4_col4" class="data row4 col4" >played</td>
#       <td id="T_1938c_row4_col5" class="data row4 col5" >may</td>
#       <td id="T_1938c_row4_col6" class="data row4 col6" >STAR</td>
#       <td id="T_1938c_row4_col7" class="data row4 col7" >big</td>
#       <td id="T_1938c_row4_col8" class="data row4 col8" >got</td>
#       <td id="T_1938c_row4_col9" class="data row4 col9" >war</td>
#       <td id="T_1938c_row4_col10" class="data row4 col10" >however</td>
#       <td id="T_1938c_row4_col11" class="data row4 col11" >way</td>
#       <td id="T_1938c_row4_col12" class="data row4 col12" >say</td>
#       <td id="T_1938c_row4_col13" class="data row4 col13" >still</td>
#       <td id="T_1938c_row4_col14" class="data row4 col14" >original</td>
#     </tr>
#     <tr>
#       <th id="T_1938c_level0_row5" class="row_heading level0 row5" >Row_6</th>
#       <td id="T_1938c_row5_col0" class="data row5 col0" >although</td>
#       <td id="T_1938c_row5_col1" class="data row5 col1" >perfect</td>
#       <td id="T_1938c_row5_col2" class="data row5 col2" >recommend</td>
#       <td id="T_1938c_row5_col3" class="data row5 col3" >old</td>
#       <td id="T_1938c_
# Topic 3
# <style type="text/css">
# #T_d59ed_row0_col1, #T_d59ed_row0_col2, #T_d59ed_row0_col6, #T_d59ed_row0_col8, #T_d59ed_row0_col11, #T_d59ed_row1_col0, #T_d59ed_row1_col4, #T_d59ed_row1_col10, #T_d59ed_row2_col0, #T_d59ed_row2_col1, #T_d59ed_row2_col7, #T_d59ed_row2_col8, #T_d59ed_row2_col12, #T_d59ed_row3_col6, #T_d59ed_row3_col9, #T_d59ed_row4_col13, #T_d59ed_row5_col4, #T_d59ed_row5_col12, #T_d59ed_row7_col12, #T_d59ed_row9_col6, #T_d59ed_row9_col7, #T_d59ed_row9_col9, #T_d59ed_row10_col1, #T_d59ed_row12_col1, #T_d59ed_row12_col2, #T_d59ed_row12_col5, #T_d59ed_row12_col10 {
#   background-color: #800080;
# }
# </style>
# <table id="T_d59ed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d59ed_level0_col0" class="col_heading level0 col0" >Token_1</th>
#       <th id="T_d59ed_level0_col1" class="col_heading level0 col1" >Token_2</th>
#       <th id="T_d59ed_level0_col2" class="col_heading level0 col2" >Token_3</th>
#       <th id="T_d59ed_level0_col3" class="col_heading level0 col3" >Token_4</th>
#       <th id="T_d59ed_level0_col4" class="col_heading level0 col4" >Token_5</th>
#       <th id="T_d59ed_level0_col5" class="col_heading level0 col5" >Token_6</th>
#       <th id="T_d59ed_level0_col6" class="col_heading level0 col6" >Token_7</th>
#       <th id="T_d59ed_level0_col7" class="col_heading level0 col7" >Token_8</th>
#       <th id="T_d59ed_level0_col8" class="col_heading level0 col8" >Token_9</th>
#       <th id="T_d59ed_level0_col9" class="col_heading level0 col9" >Token_10</th>
#       <th id="T_d59ed_level0_col10" class="col_heading level0 col10" >Token_11</th>
#       <th id="T_d59ed_level0_col11" class="col_heading level0 col11" >Token_12</th>
#       <th id="T_d59ed_level0_col12" class="col_heading level0 col12" >Token_13</th>
#       <th id="T_d59ed_level0_col13" class="col_heading level0 col13" >Token_14</th>
#       <th id="T_d59ed_level0_col14" class="col_heading level0 col14" >Token_15</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d59ed_level0_row0" class="row_heading level0 row0" >Row_1</th>
#       <td id="T_d59ed_row0_col0" class="data row0 col0" >im</td>
#       <td id="T_d59ed_row0_col1" class="data row0 col1" >MOVIE</td>
#       <td id="T_d59ed_row0_col2" class="data row0 col2" >FILM</td>
#       <td id="T_d59ed_row0_col3" class="data row0 col3" >gonna</td>
#       <td id="T_d59ed_row0_col4" class="data row0 col4" >ive</td>
#       <td id="T_d59ed_row0_col5" class="data row0 col5" >going</td>
#       <td id="T_d59ed_row0_col6" class="data row0 col6" >TIRED</td>
#       <td id="T_d59ed_row0_col7" class="data row0 col7" >cant</td>
#       <td id="T_d59ed_row0_col8" class="data row0 col8" >SORRY</td>
#       <td id="T_d59ed_row0_col9" class="data row0 col9" >bored</td>
#       <td id="T_d59ed_row0_col10" class="data row0 col10" >ill</td>
#       <td id="T_d59ed_row0_col11" class="data row0 col11" >CHARACTER</td>
#       <td id="T_d59ed_row0_col12" class="data row0 col12" >fucking</td>
#       <td id="T_d59ed_row0_col13" class="data row0 col13" >great</td>
#       <td id="T_d59ed_row0_col14" class="data row0 col14" >done</td>
#     </tr>
#     <tr>
#       <th id="T_d59ed_level0_row1" class="row_heading level0 row1" >Row_2</th>
#       <td id="T_d59ed_row1_col0" class="data row1 col0" >STORY</td>
#       <td id="T_d59ed_row1_col1" class="data row1 col1" >guy</td>
#       <td id="T_d59ed_row1_col2" class="data row1 col2" >wanna</td>
#       <td id="T_d59ed_row1_col3" class="data row1 col3" >school</td>
#       <td id="T_d59ed_row1_col4" class="data row1 col4" >SCENE</td>
#       <td id="T_d59ed_row1_col5" class="data row1 col5" >well</td>
#       <td id="T_d59ed_row1_col6" class="data row1 col6" >scared</td>
#       <td id="T_d59ed_row1_col7" class="data row1 col7" >girl</td>
#       <td id="T_d59ed_row1_col8" class="data row1 col8" >good</td>
#       <td id="T_d59ed_row1_col9" class="data row1 col9" >thats</td>
#       <td id="T_d59ed_row1_col10" class="data row1 col10" >WATCH</td>
#       <td id="T_d59ed_row1_col11" class="data row1 col11" >pretty</td>
#       <td id="T_d59ed_row1_col12" class="data row1 col12" >play</td>
#       <td id="T_d59ed_row1_col13" class="data row1 col13" >sure</td>
#       <td id="T_d59ed_row1_col14" class="data row1 col14" >class</td>
#     </tr>
#     <tr>
#       <th id="T_d59ed_level0_row2" class="row_heading level0 row2" >Row_3</th>
#       <td id="T_d59ed_row2_col0" class="data row2 col0" >SEEN</td>
#       <td id="T_d59ed_row2_col1" class="data row2 col1" >ACTOR</td>
#       <td id="T_d59ed_row2_col2" class="data row2 col2" >first</td>
#       <td id="T_d59ed_row2_col3" class="data row2 col3" >got</td>
#       <td id="T_d59ed_row2_col4" class="data row2 col4" >sick</td>
#       <td id="T_d59ed_row2_col5" class="data row2 col5" >tonight</td>
#       <td id="T_d59ed_row2_col6" class="data row2 col6" >probably</td>
#       <td id="T_d59ed_row2_col7" class="data row2 col7" >PERFORMANCE</td>
#       <td id="T_d59ed_row2_col8" class="data row2 col8" >FUNNY</td>
#       <td id="T_d59ed_row2_col9" class="data row2 col9" >fuck</td>
#       <td id="T_d59ed_row2_col10" class="data row2 col10" >game</td>
#       <td id="T_d59ed_row2_col11" class="data row2 col11" >kinda</td>
#       <td id="T_d59ed_row2_col12" class="data row2 col12" >PLOT</td>
#       <td id="T_d59ed_row2_col13" class="data row2 col13" >man</td>
#       <td id="T_d59ed_row2_col14" class="data row2 col14" >reddit</td>
#     </tr>
#     <tr>
#       <th id="T_d59ed_level0_row3" class="row_heading level0 row3" >Row_4</th>
#       <td id="T_d59ed_row3_col0" class="data row3 col0" >also</td>
#       <td id="T_d59ed_row3_col1" class="data row3 col1" >looking</td>
#       <td id="T_d59ed_row3_col2" class="data row3 col2" >watching</td>
#       <td id="T_d59ed_row3_col3" class="data row3 col3" >post</td>
#       <td id="T_d59ed_row3_col4" class="data row3 col4" >cast</td>
#       <td id="T_d59ed_row3_col5" class="data row3 col5" >ready</td>
#       <td id="T_d59ed_row3_col6" class="data row3 col6" >ACTING</td>
#       <td id="T_d59ed_row3_col7" class="data row3 col7" >chat</td>
#       <td id="T_d59ed_row3_col8" class="data row3 col8" >job</td>
#       <td id="T_d59ed_row3_col9" class="data row3 col9" >SHOW</td>
#       <td id="T_d59ed_row3_col10" class="data row3 col10" >music</td>
#       <td id="T_d59ed_row3_col11" class="data row3 col11" >one</td>
#       <td id="T_d59ed_row3_col12" class="data row3 col12" >best</td>
#       <td id="T_d59ed_row3_col13" class="data row3 col13" >saw</td>
#       <td id="T_d59ed_row3_col14" class="data row3 col14" >new</td>
#     </tr>
#     <tr>
#       <th id="T_d59ed_level0_row4" class="row_heading level0 row4" >Row_5</th>
#       <td id="T_d59ed_row4_col0" class="data row4 col0" >comedy</td>
#       <td id="T_d59ed_row4_col1" class="data row4 col1" >bit</td>
#       <td id="T_d59ed_row4_col2" class="data row4 col2" >lol</td>
#       <td id="T_d59ed_row4_col3" class="data row4 col3" >director</td>
#       <td id="T_d59ed_row4_col4" class="data row4 col4" >fan</td>
#       <td id="T_d59ed_row4_col5" class="data row4 col5" >role</td>
#       <td id="T_d59ed_row4_col6" class="data row4 col6" >old</td>
#       <td id="T_d59ed_row4_col7" class="data row4 col7" >hour</td>
#       <td id="T_d59ed_row4_col8" class="data row4 col8" >posting</td>
#       <td id="T_d59ed_row4_col9" class="data row4 col9" >boy</td>
#       <td id="T_d59ed_row4_col10" class="data row4 col10" >two</td>
#       <td id="T_d59ed_row4_col11" class="data row4 col11" >excellent</td>
#       <td id="T_d59ed_row4_col12" class="data row4 col12" >hey</td>
#       <td id="T_d59ed_row4_col13" class="data row4 col13" >DVD</td>
#       <td id="T_d59ed_row4_col14" class="data row4 col14" >whats</td>
#     </tr>
#     <tr>
#       <th id="T_d59ed_level0_row5" class="row_heading level0 row5" >Row_6</th>
#       <td id="T_d59ed_row5_col0" class="data row5 col0" >favorite</td>
#       <td id="T_d59ed_row5_col1" class="data row5 col1" >goodbye</td>
#       <td id="T_d59ed_row5_col2" class="data row5 col2" >dad</td>
#       <td id="T_d59ed_row5_col3" class="data row5 col3" >fun</td>
#       <td id="T_d59ed_row5_col4" class="data row5 col4" >

# %% [markdown]
# ### Các Scripts sử dụng cho việc trực quan hóa
# - Quan sát các văn bản trong không gian 3 chiều tìm bởi LSA: `scripts/density_class_3d.py`.
# - Trực quan độ dày của 2 lớp trên không gian 2 chiều tìm bởi LSA: `scripts/density_class.py`.
# - Biplot 3 chiều động với package `plotly`: `scripts/term_document_plotly.py`.
# - Biplot 2 chiều với các token được chọn lọc: `scripts/density_tdm_1.py`.
# - Phân tích Cosine Similarity: `scripts/similarity_lsa.py`.
# - Phân tích Explained Variance: `scripts/explained_variance.py`.

# %%
from scipy.stats import gaussian_kde

tfidf = TfidfVectorizer(max_features=3500)
tfidf_matrix = tfidf.fit_transform(corpus['text'])

lsa = TruncatedSVD(n_components=2, random_state=42)
doc_coords = lsa.fit_transform(tfidf_matrix)

labels = corpus['label']

def create_density_plots(doc_coords, labels):
    fig, axs = plt.subplots(1, 2, figsize=(12, 6))
    colors = ['viridis', 'plasma']

    mask0 = labels == 1
    mask1 = labels == 0

    label0_points = doc_coords[mask0]
    label1_points = doc_coords[mask1]

    xy0 = np.vstack([label0_points[:, 0], label0_points[:, 1]])
    density0 = gaussian_kde(xy0)(xy0)
    density0 = (density0 - density0.min()) / (density0.max() - density0.min())

    xy1 = np.vstack([label1_points[:, 0], label1_points[:, 1]])
    density1 = gaussian_kde(xy1)(xy1)
    density1 = (density1 - density1.min()) / (density1.max() - density1.min())

    axs[0].scatter(
        label0_points[:, 0],
        label0_points[:, 1],
        c=density0,
        cmap=colors[0],
        s=50,
        alpha=0.6
    )
    axs[0].scatter(
        label1_points[:, 0],
        label1_points[:, 1],
        c=density1,
        cmap=colors[1],
        s=50,
        alpha=0.6
    )
    axs[0].set_title('Label 0 on top of Label 1')
    axs[0].grid(True, alpha=0.3)

    axs[1].scatter(
        label1_points[:, 0],
        label1_points[:, 1],
        c=density1,
        cmap=colors[1],
        s=50,
        alpha=0.6
    )
    axs[1].scatter(
        label0_points[:, 0],
        label0_points[:, 1],
        c=density0,
        cmap=colors[0],
        s=50,
        alpha=0.6
    )
    axs[1].set_title('Label 1 on top of Label 0')
    axs[1].grid(True, alpha=0.3)

    for ax in axs:
        ax.set_xlabel('LSA Component 1')
        ax.set_ylabel('LSA Component 2')

    plt.tight_layout()
    return plt


plt.style.use('default')
plot = create_density_plots(doc_coords, labels)

print("\nLabel Distribution:")
print(corpus['label'].value_counts())

plt.show()
# Out:
# Label Distribution:
# label
# 1    12648
# 0    10592
# Name: count, dtype: int64

# %%
from mpl_toolkits.mplot3d import Axes3D

tfidf = TfidfVectorizer(max_features=3500)
tfidf_matrix = tfidf.fit_transform(corpus['text'])

lsa = TruncatedSVD(n_components=3, random_state=42)
doc_coords = lsa.fit_transform(tfidf_matrix)

labels = corpus['label']

def create_3d_density_plot(doc_coords, labels):
    # Create 3D figure
    fig = plt.figure(figsize=(12, 8))
    ax = fig.add_subplot(111, projection='3d')

    mask0 = labels == 0
    mask1 = labels == 1

    label0_points = doc_coords[mask0]
    label1_points = doc_coords[mask1]

    ax.scatter(
        label0_points[:, 0],
        label0_points[:, 1],
        label0_points[:, 2],
        c='#FFFF99',
        s=50,
        alpha=0.6,
        edgecolors='black',
        label='Class 0'
    )

    ax.scatter(
        label1_points[:, 0],
        label1_points[:, 1],
        label1_points[:, 2],
        c='#99FFE5',
        s=50,
        alpha=0.6,
        edgecolors='black',
        label='Class 1'
    )

    ax.set_xlabel('LSA Component 1')
    ax.set_ylabel('LSA Component 2')
    ax.set_zlabel('LSA Component 3')
    ax.set_title('3D LSA Components Distribution')

    ax.legend()

    ax.set_facecolor('white')
    fig.set_facecolor('white')

    return plt


plt.style.use('default')
plot = create_3d_density_plot(doc_coords, labels)

print("\nLabel Distribution:")
print(corpus['label'].value_counts())

plt.show()
# Out:
# Label Distribution:
# label
# 1    12648
# 0    10592
# Name: count, dtype: int64

# %%
tfidf = TfidfVectorizer(max_features=3500)
tfidf_matrix = tfidf.fit_transform(corpus['text'])

n_components = 2
lsa = TruncatedSVD(n_components=n_components, random_state=42)
doc_coords = lsa.fit_transform(tfidf_matrix)

term_coords = lsa.components_.T * np.sqrt(lsa.singular_values_)

highlight_terms = ['suicidal', 'depression', 'suicide', 'kill', 'myself', 'die',
                   'died', 'pain', 'sad', 'help', 'sorry', 'anxiety', 'therapy',
                   'suffering', 'killing', 'pill',
                   'movie', 'film', 'character', 'story', 'actor', 'performance', 'show',
                   'plot', 'acting']

terms = tfidf.get_feature_names_out()
highlight_indices = [i for i, term in enumerate(terms) if term in highlight_terms]
highlighted_term_coords = term_coords[highlight_indices]
highlighted_terms = [terms[i] for i in highlight_indices]

def plot_lsa_biplot(doc_coords, term_coords, labels, ax):
    xy = np.vstack([doc_coords[:, 0], doc_coords[:, 1]])
    density = gaussian_kde(xy)(xy)
    density = (density - density.min()) / (density.max() - density.min())

    class_0_mask = labels == 0
    class_1_mask = labels == 1

    scatter_0 = ax.scatter(
        doc_coords[class_0_mask, 0],
        doc_coords[class_0_mask, 1],
        c=density[class_0_mask],
        cmap='summer',
        s=50,
        alpha=0.6,
        label='Class 0 (green)'
    )

    scatter_1 = ax.scatter(
        doc_coords[class_1_mask, 0],
        doc_coords[class_1_mask, 1],
        c=density[class_1_mask],
        cmap='spring',
        s=50,
        alpha=0.6,
        label='Class 1 (pink)'
    )

    for i, term in enumerate(highlighted_terms):
        ax.text(
            highlighted_term_coords[i, 0],
            highlighted_term_coords[i, 1],
            term,
            color='black',
            alpha=0.7,
            fontsize=8
        )
        ax.scatter(
            highlighted_term_coords[i, 0],
            highlighted_term_coords[i, 1],
            color='black',
            alpha=0.3,
            s=10
        )

    ax.legend(loc='upper right')

    ax.set_title('Biplot of Selected Terms with LSA Components')
    ax.set_xlabel('LSA Component 1')
    ax.set_ylabel('LSA Component 2')
    ax.grid(True, alpha=0.3)

fig, ax = plt.subplots(figsize=(10, 8))

plot_lsa_biplot(doc_coords, term_coords, corpus['label'], ax)

plt.tight_layout()
plt.show()

print("\nLabel Distribution:")
print(corpus['label'].value_counts())

def calculate_label_centroids(doc_coords, labels):
    centroids = {}
    for label in labels.unique():
        mask = labels == label
        centroid = doc_coords[mask].mean(axis=0)
        centroids[label] = centroid

    return pd.DataFrame.from_dict(centroids, orient='index',
                                  columns=['Component_1', 'Component_2'])

centroids_df = calculate_label_centroids(doc_coords, corpus['label'])
print("\nLabel Centroids:")
print(centroids_df)
# Out:
# Label Distribution:
# label
# 1    12648
# 0    10592
# Name: count, dtype: int64
#
# Label Centroids:
#    Component_1  Component_2
# 0     0.134474     0.060609
# 1     0.261488    -0.019996

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

tfidf = TfidfVectorizer(max_features=3500)
tfidf_matrix = tfidf.fit_transform(corpus['text'])

n_components = 100
lsa = TruncatedSVD(n_components=n_components, random_state=42)
doc_coords = lsa.fit_transform(tfidf_matrix)

print(doc_coords.shape)

term_coords = lsa.components_.T * np.sqrt(lsa.singular_values_)

def analyze_similarities(tfidf, term_coords, doc_coords, corpus, top_n=10):
    term_similarities = cosine_similarity(term_coords)

    feature_names = np.array(tfidf.get_feature_names_out())

    doc_similarities = cosine_similarity(doc_coords)

    def get_top_similar(similarities, items, idx, n=top_n):
        sim_scores = similarities[idx]
        top_indices = np.argsort(sim_scores)[::-1][1:n + 1]

        items_array = np.array(list(items))
        return list(zip(items_array[top_indices], sim_scores[top_indices]))

    interesting_terms = ['suicidal', 'depression', 'suicide', 'kill', 'myself', 'die',
                         'died', 'pain', 'sad', 'help', 'sorry', 'anxiety', 'therapy',
                         'suffering', 'killing', 'pill',
                         'movie', 'film', 'character', 'story', 'actor', 'performance', 'show',
                         'plot', 'acting']
    term_results = {}

    for term in interesting_terms:
        if term in feature_names:
            idx = np.where(feature_names == term)[0][0]
            similar_terms = get_top_similar(term_similarities, feature_names, idx)
            term_results[term] = similar_terms

    sample_docs = [0, 10, 20, 30]
    doc_results = {}

    doc_indices = np.arange(len(corpus))

    for doc_idx in sample_docs:
        similar_docs = get_top_similar(doc_similarities, doc_indices, doc_idx)
        doc_results[doc_idx] = {
            'original': corpus['text'].iloc[doc_idx][:200] + "...",
            'original_label': corpus['label'].iloc[doc_idx],
            'similar': [(corpus['text'].iloc[int(idx)][:200] + "...",
                         corpus['label'].iloc[int(idx)],
                         score)
                        for idx, score in similar_docs]
        }

    return term_results, doc_results


term_results, doc_results = analyze_similarities(tfidf, term_coords, doc_coords, corpus)

print("Similar Terms Analysis:")
print("-" * 50)
for term, similars in term_results.items():
    print(f"\nSimilar terms to '{term}':")
    for similar_term, score in similars:
        print(f"  {similar_term}: {score:.3f}")

print("\nSimilar Documents Analysis:")
print("-" * 50)
for doc_idx, results in doc_results.items():
    print(f"\nOriginal Document {doc_idx} [Class: {results['original_label']}]:")
    print(results['original'])
    print("\nSimilar Documents:")
    for i, (doc, label, score) in enumerate(results['similar'], 1):
        print(f"\n{i}. Similarity Score: {score:.3f} [Class: {label}]")
        print(doc)
# Out:
# (23240, 100)
# Similar Terms Analysis:
# --------------------------------------------------
#
# Similar terms to 'suicidal':
#   ideation: 0.845
#   thought: 0.788
#   intrusive: 0.736
#   tendency: 0.662
#   battling: 0.636
#   actively: 0.556
#   inpatient: 0.517
#   ocd: 0.510
#   lately: 0.487
#   frequent: 0.482
#
# Similar terms to 'depression':
#   severe: 0.861
#   anxiety: 0.801
#   diagnosed: 0.782
#   disorder: 0.743
#   ocd: 0.705
#   symptom: 0.690
#   depressive: 0.660
#   clinical: 0.659
#   struggling: 0.647
#   manic: 0.644
#
# Similar terms to 'suicide':
#   cannot: 0.748
#   notredflag: 0.513
#   cope: 0.464
#   mechanism: 0.401
#   emptiness: 0.399
#   affect: 0.397
#   depressant: 0.384
#   solve: 0.381
#   rely: 0.366
#   reach: 0.362
#
# Similar terms to 'kill':
#   myself: 0.854
#   requires: 0.496
#   vodka: 0.473
#   pussy: 0.446
#   self: 0.376
#   sympathy: 0.372
#   gun: 0.360
#   bare: 0.358
#   gut: 0.354
#   wanting: 0.348
#
# Similar terms to 'myself':
#   kill: 0.854
#   vodka: 0.498
#   pussy: 0.477
#   bottle: 0.406
#   gun: 0.400
#   brave: 0.379
#   badly: 0.370
#   gut: 0.368
#   overdose: 0.361
#   requires: 0.348
#
# Similar terms to 'die':
#   dying: 0.519
#   survival: 0.511
#   peacefully: 0.493
#   wanting: 0.478
#   crash: 0.470
#   accident: 0.458
#   instinct: 0.403
#   death: 0.390
#   eventually: 0.384
#   realization: 0.357
#
# Similar terms to 'died':
#   killed: 0.737
#   grandpa: 0.657
#   cat: 0.609
#   grandma: 0.595
#   sister: 0.593
#   cancer: 0.560
#   uncle: 0.557
#   aunt: 0.531
#   passed: 0.529
#   grandmother: 0.518
#
# Similar terms to 'pain':
#   physical: 0.696
#   unbearable: 0.679
#   agony: 0.670
#   sharp: 0.632
#   painful: 0.603
#   chronic: 0.591
#   misery: 0.580
#   constant: 0.571
#   void: 0.554
#   filled: 0.554
#
# Similar terms to 'sad':
#   sadness: 0.492
#   lonely: 0.408
#   cat: 0.406
#   cheer: 0.406
#   confused: 0.383
#   lil: 0.360
#   unhealthy: 0.344
#   dog: 0.334
#   angry: 0.320
#   pro: 0.315
#
# Similar terms to 'help':
#   seek: 0.800
#   professional: 0.661
#   seeking: 0.493
#   returned: 0.464
#   reaching: 0.459
#   worried: 0.436
#   helping: 0.432
#   resource: 0.427
#   therapist: 0.411
#   counseling: 0.377
#
# Similar terms to 'sorry':
#   reading: 0.540
#   forgive: 0.536
#   goodbye: 0.451
#   rambling: 0.444
#   thank: 0.429
#   native: 0.429
#   hope: 0.425
#   read: 0.413
#   apology: 0.403
#   grammar: 0.372
#
# Similar terms to 'anxiety':
#   depression: 0.801
#   disorder: 0.792
#   severe: 0.769
#   diagnosed: 0.734
#   ocd: 0.724
#   panic: 0.650
#   manic: 0.649
#   social: 0.641
#   bipolar: 0.640
#   chronic: 0.629
#
# Similar terms to 'therapy':
#   medication: 0.850
#   antidepressant: 0.725
#   psychiatrist: 0.717
#   therapist: 0.716
#   med: 0.715
#   treatment: 0.702
#   psychologist: 0.617
#   doctor: 0.614
#   bipolar: 0.614
#   hospitalized: 0.611
#
# Similar terms to 'suffering':
#   misery: 0.744
#   suffer: 0.686
#   existence: 0.671
#   painful: 0.589
#   continue: 0.585
#   chronic: 0.542
#   constant: 0.539
#   solution: 0.533
#   pain: 0.520
#   disease: 0.501
#
# Similar terms to 'killing':
#   thinking: 0.590
#   convinced: 0.440
#   planned: 0.431
#   inevitable: 0.420
#   plan: 0.402
#   ideation: 0.389
#   sober: 0.384
#   terrified: 0.381
#   actually: 0.376
#   capable: 0.373
#
# Similar terms to 'pill':
#   bottle: 0.833
#   overdose: 0.805
#   took: 0.689
#   alcohol: 0.658
#   taking: 0.653
#   liver: 0.653
#   dizzy: 0.649
#   xanax: 0.641
#   vodka: 0.609
#   overdosing: 0.604
#
# Similar terms to 'movie':
#   moviebr: 0.908
#   theater: 0.814
#   bruce: 0.762
#   imdb: 0.758
#   enjoyed: 0.720
#   complaint: 0.697
#   collection: 0.684
#   flick: 0.675
#   recommend: 0.669
#   itbr: 0.667
#
# Similar terms to 'film':
#   filmbr: 0.929
#   cinema: 0.902
#   dialogue: 0.887
#   festival: 0.872
#   cinematography: 0.867
#   filmmaker: 0.866
#   viewing: 0.859
#   remarkable: 0.850
#   beautifully: 0.830
#   narrative: 0.827
#
# Similar terms to 'character':
#   role: 0.908
#   actor: 0.883
#   cast: 0.878
#   plot: 0.872
#   sequence: 0.860
#   james: 0.859
#   michael: 0.858
#   drama: 0.858
#   performance: 0.855
#   directing: 0.852
#
# Similar terms to 'story':
#   fascinating: 0.763
#   screenplay: 0.737
#   based: 0.724
#   mysterious: 0.723
#   tale: 0.719
#   village: 0.719
#   short: 0.713
#   michael: 0.707
#   character: 0.706
#   robert: 0.706
#
# Similar terms to 'actor':
#   cast: 0.949
#   classic: 0.938
#   role: 0.927
#   plot: 0.926
#   acting: 0.921
#   actress: 0.917
#   itbr: 0.911
#   comedy: 0.911
#   excellent: 0.909
#   audience: 0.908
#
# Similar terms to 'performance':
#   director: 0.955
#   script: 0.939
#   excellent: 0.937
#   audience: 0.937
#   scene: 0.934
#   cast: 0.932
#   dialogue: 0.931
#   role: 0.924
#   cinematography: 0.922
#   sequence: 0.919
#
# Similar terms to 'show':
#   episode: 0.861
#   series: 0.861
#   television: 0.858
#   season: 0.781
#   watch: 0.739
#   scif: 0.725
#   cartoon: 0.705
#   pilot: 0.692
#   produced: 0.686
#   tony: 0.681
#
# Similar terms to 'plot':
#   classic: 0.930
#   actor: 0.926
#   scene: 0.919
#   acting: 0.916
#   role: 0.912
#   suspense: 0.907
#   cast: 0.904
#   audience: 0.903
#   flick: 0.897
#   directing: 0.895
#
# Similar terms to 'acting':
#   actor: 0.921
#   plot: 0.916
#   scene: 0.903
#   classic: 0.902
#   excellent: 0.897
#   cast: 0.888
#   believable: 0.887
#   audience: 0.887
#   itbr: 0.885
#   rating: 0.881
#
# Similar Documents Analysis:
# --------------------------------------------------
#
# Original Document 0 [Class: 0]:
# dear american teen question dutch person heard guy get way easier thing learn age grader like right guy learn math...
#
# Similar Documents:
#
# 1. Similarity Score: 0.785 [Class: 0]
# yknow grey commonly known kind make certain thing guy bit noticeable like easier notice guy grey specifically...
#
# 2. Similarity Score: 0.756 [Class: 0]
# used movie college ethic course year also woody allen crime terrific ethical study fiction focus much unrealistic feature stranger fictional film obviously false many level love film comedy told many ...
#
# 3. Similarity Score: 0.746 [Class: 0]
# genuine question everyone skirt guy thats trend right guy skirt dont understand came probably sound stupid killed cat...
#
# 4. Similarity Score: 0.733 [Class: 0]
# guy epic battle best user teenager every vote count guy...
#
# 5. Similarity Score: 0.726 [Class: 0]
# punishment failing guy failed real god figured thing made fail punishment...
#
# 6. Similarity Score: 0.713 [Class: 0]
# fruit loop suck seriously taste good guy guy prefer like sugar loop...
#
# 7. Similarity Score: 0.699 [Class: 0]
# wtf guy weve lied baby carrot arent actually baby theyre normal carrot cut...
#
# 8. Similarity Score: 0.699 [Class: 0]
# technology bane throw opinion guy floor auto mod auto mod auto mod auto mod...
#
# 9. Similarity Score: 0.695 [Class: 0]
# chicken laid egg guy went check chicken coop saw medium brown egg...
#
# 10. Similarity Score: 0.690 [Class: 0]
# guy guy guy wait scroll past favorite joke always make smile seagull fly sea cause flew bay theyd...
#
# Original Document 10 [Class: 0]:
# motivated ngl cant wait get shape know gonna overnight im happy right...
#
# Similar Documents:
#
# 1. Similarity Score: 0.698 [Class: 0]
# ground going open swallow evil ground gonna open swallow evil right thats see word bond ground symbol poor people right poor people gonna open whole world swallow rich people cause rich people gonna f...
#
# 2. Similarity Score: 0.683 [Class: 0]
# cant believe tomorrow halloween im gonna put razor blade snicker...
#
# 3. Similarity Score: 0.648 [Class: 1]
# think im gonna horrible cant switch online either im taking bunch pill get shower tonight...
#
# 4. Similarity Score: 0.642 [Class: 1]
# im afraid everythings gonna get sort looking like theyll get better im afraid everythings gonna get worse thing get worse somehow know know ill able go living im dealing lot different kind feeling rig...
#
# 5. Similarity Score: 0.607 [Class: 0]
# cha cha real smooth im gonna steal lego collection im gonna front...
#
# 6. Similarity Score: 0.606 [Class: 0]
# second thats gonna take gonna take second agonizing second get agonizing life gonna chicken cant...
#
# 7. Similarity Score: 0.589 [Class: 0]
# im coming back arent gonna ready first im gonna take shit im gonna leave im gonna prove everyone wrong dont need know post ready...
#
# 8. Similarity Score: 0.584 [Class: 0]
# millennials baby called generation alpha gen baby generation beta guess gotta stay virgin cause im gonna raise beta duck...
#
# 9. Similarity Score: 0.584 [Class: 0]
# year im gonna get im gonna workout least every day drink least gallon water per day know already working regularly drinking water lot really gonna awesome...
#
# 10. Similarity Score: 0.581 [Class: 1]
# im gonna tonightim gonna kill gonna steal pill grandma im gonna swallow whole bottle kill im next month im complete fuck asshole failure one like ruin every friendship probably shouldve killed sooner ...
#
# Original Document 20 [Class: 1]:
# want die even tho feel like dead everyone want tell depression loneliness general feeling wanting end life good dont even know im idk im looking posting im ashamed problem point feel ashamed writing s...
#
# Similar Documents:
#
# 1. Similarity Score: 0.733 [Class: 1]
# feeling passively suicidal alot think alot google depression test time like need someone give permission reassure feel like definitely mental health problem even though ive diagnosed med helping stopp...
#
# 2. Similarity Score: 0.719 [Class: 1]
# im feeling really dumb like ill never get anywhere lifeive got lot cleverness hood barely ever show anything people say im smart apply barely anything dont concentrate mostly feel like trick people th...
#
# 3. Similarity Score: 0.700 [Class: 1]
# dont want anything anymore dont want mean dont know want dont know anything mistake ive made life feel like im gonna anything good ever come ever never anything life dont remember day havent money iss...
#
# 4. Similarity Score: 0.695 [Class: 1]
# thought getting course everything get fucked im still depressed yay think hospital make feel bad honestly want around sick people making worse like anyone actually help tell suicidal thought let go wa...
#
# 5. Similarity Score: 0.694 [Class: 1]
# person love doesnt love im well school cant imagine good last girlfriend told wasnt going date anyone rest college unless someone special came along well special person came along went broke boyfriend...
#
# 6. Similarity Score: 0.691 [Class: 1]
# feel like wasted life idk do feel like ive made many mistake past live life didnt want live unmotivated depressed high school didnt get accepted college didnt even get money goddamn fafsa dont friend ...
#
# 7. Similarity Score: 0.690 [Class: 1]
# always feel im attention guess need help someone talk man tough time lately seems like ill look back everything life seems like big failure go back youngest memory kid even like wow always bottom life...
#
# 8. Similarity Score: 0.683 [Class: 1]
# almost almost last month really close didnt regret feel like couldve missed chance end pain im really trying stay alive feel like one everyone life either cruel abusive flat uncaring try reach people ...
#
# 9. Similarity Score: 0.682 [Class: 1]
# dont know start say feel helpless feel defeated im started college september im england took year school due reason ill go bit happy much anymore ive problem since primary school ive constantly bullie...
#
# 10. Similarity Score: 0.681 [Class: 1]
# actually feel alright thats past year going quite well outside ive started leaving house pretty much daily social interaction struggling ofc seeing therapist general people telling good way etc etc im...
#
# Original Document 30 [Class: 0]:
# im probably going get body pillow printed plain white body pillow need hug something im cry sleep...
#
# Similar Documents:
#
# 1. Similarity Score: 0.671 [Class: 0]
# found cockroach bed one closet get rid someone actually help im terrified cockroach im go bed two climbing crack bed im going sleep couch im genuinely terrified...
#
# 2. Similarity Score: 0.664 [Class: 0]
# im tired need sleep get babysit cant fall asleep going fun deal kid...
#
# 3. Similarity Score: 0.627 [Class: 0]
# welp im going bed ive gotta wake whatever need much sleep ill fine im hormonal right im tired anything...
#
# 4. Similarity Score: 0.619 [Class: 0]
# currently eating raw havent slept yet need something occupy time idea im posting im probably gonna get downvoted oblivion idc...
#
# 5. Similarity Score: 0.607 [Class: 0]
# sleep put random crap comment wake night ish pretending write something get deleted pretending write something get deleted...
#
# 6. Similarity Score: 0.596 [Class: 1]
# sleep day awake else get empty shell spend time bed usually cry im awake...
#
# 7. Similarity Score: 0.596 [Class: 0]
# watching right go bed guess sleep tonight im probably actually going sleep another hour still...
#
# 8. Similarity Score: 0.595 [Class: 0]
# wait bunch video learn language sleep damn im going keep sleeping rate...
#
# 9. Similarity Score: 0.594 [Class: 1]
# help pulling im little concerned managing sleeping much last night sleep tired cant sleep wrote note entitled event death im sitting razor blade know im going anything probably im little concerned sup...
#
# 10. Similarity Score: 0.591 [Class: 0]
# ive laying bed eye shut trying sleep close literally hour cant im tired one bit trying get better sleep schedule hard got hour sleep yesterday im probably going stay day sleep time becomes ill able go...

# %% [markdown]
# ### Tóm tắt quá trình LSA
# - Ta thấy rằng hầu hết những chủ đề tiềm ẩn này khá khó để có thể hiểu được.
# - Tuy nhiên ta có thể sử dụng trực quan để đưa ra các phỏng đoán dựa vào việc phân tích các terms và documents đại diện cho chủ đề đó.
# - Bước trên có thể được thông suốt hơn nữa bằng cách sử dụng Cosine Similarity.
# - Ngoài ra, thay vì sử dụng Explained Variance để chọn được 1 số chiều tối ưu như với PCA, khi hiểu rằng các chiều của LSA là các chủ đề tiềm ẩn và variance giữa các chủ đề này thường không mang lại nhiều ý nghĩa, thực chất trên tất cả mọi Corpus, lượng chủ đề thường không quá nhiều, chỉ từ 5 - 300 tùy vào độ lớn của Corpus.
# - Vì vậy, ta sẽ chỉ chọn số chiều giảm về 100 với 1 phỏng đoán ngây thơ rằng ước tính có 100 chủ đề tiềm ẩn trong cả Corpus khi sử dụng cho việc đánh giá phân loại. Ngoài ra, lựa chọn này cũng để đảm bảo chúng ta không mất quá nhiều thông tin gốc.
# - Đơn giản hiểu rằng, chúng ta đang đánh đổi interpretability để sử dụng những chủ đề tiềm ẩn này, do với ma trận TF-IDF gốc, mỗi đặc trưng vẫn là 1 token cụ thể có thể hiểu được.
