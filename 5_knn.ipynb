# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns
import time

import warnings
warnings.filterwarnings('ignore')

original_corpus = pd.read_csv('data/mental_health.csv')
cleaned_corpus = pd.read_csv('data/cleaned_mhc.csv')

print("Shape of Original Corpus", original_corpus.shape)
print("Shape of Cleaned Corpus", cleaned_corpus.shape)
# Out:
# Shape of Original Corpus (27977, 2)
# Shape of Cleaned Corpus (23240, 2)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import time

k_values = [1, 5, 10, 50, 100, 200, 300, 500, 1000, 2000, 5000, 8000]
vectorizer = TfidfVectorizer(max_features=3500)

metrics_original_euclidean = {"K": [], "Training Accuracy": [], "Test Accuracy": [], "Precision": [], "Recall": [], "F1": [], "Test Time (s)": []}
metrics_cleaned_euclidean = {"K": [], "Training Accuracy": [], "Test Accuracy": [], "Precision": [], "Recall": [], "F1": [], "Test Time (s)": []}
metrics_original_cosine = {"K": [], "Training Accuracy": [], "Test Accuracy": [], "Precision": [], "Recall": [], "F1": [], "Test Time (s)": []}
metrics_cleaned_cosine = {"K": [], "Training Accuracy": [], "Test Accuracy": [], "Precision": [], "Recall": [], "F1": [], "Test Time (s)": []}

def run_knn(corpus, target, metrics_dict, dataset_name, metric='euclidean'):
    best_f1 = 0
    best_conf_matrix = None
    best_k = None
    best_test_time = None

    for k in k_values:
        X_train, X_test, y_train, y_test = train_test_split(corpus, target, test_size=0.2, random_state=42)
        vectorizer = TfidfVectorizer(max_features=3500)
        
        X_train_tfidf = vectorizer.fit_transform(X_train)
        X_test_tfidf = vectorizer.transform(X_test)
       
        knn = KNeighborsClassifier(n_neighbors=k, metric=metric)

        knn.fit(X_train_tfidf, y_train)
        
        start_test = time.perf_counter()
        y_test_pred = knn.predict(X_test_tfidf)
        test_time = time.perf_counter() - start_test
        
        y_train_pred = knn.predict(X_train_tfidf)
        
        train_acc = accuracy_score(y_train, y_train_pred)
        test_acc = accuracy_score(y_test, y_test_pred)
        prec = precision_score(y_test, y_test_pred)
        rec = recall_score(y_test, y_test_pred)
        f1 = f1_score(y_test, y_test_pred)
        
        metrics_dict["K"].append(k)
        metrics_dict["Training Accuracy"].append(train_acc)
        metrics_dict["Test Accuracy"].append(test_acc)
        metrics_dict["Precision"].append(prec)
        metrics_dict["Recall"].append(rec)
        metrics_dict["F1"].append(f1)
        metrics_dict["Test Time (s)"].append(test_time)

        if f1 > best_f1:
            best_f1 = f1
            best_conf_matrix = confusion_matrix(y_test, y_test_pred)
            best_k = k
            best_test_time = test_time

    print(f"Best F1 Score for {dataset_name} Corpus (k={best_k}, metric={metric}): {best_f1:.4f}, "
          f"Test time: {best_test_time:.4f} s")
    print("Confusion Matrix:\n", best_conf_matrix)

run_knn(original_corpus['text'], original_corpus['label'], metrics_original_euclidean, "Original", metric='euclidean')
run_knn(cleaned_corpus['text'], cleaned_corpus['label'], metrics_cleaned_euclidean, "Cleaned", metric='euclidean')
run_knn(original_corpus['text'], original_corpus['label'], metrics_original_cosine, "Original", metric='cosine')
run_knn(cleaned_corpus['text'], cleaned_corpus['label'], metrics_cleaned_cosine, "Cleaned", metric='cosine')

df_original_euclidean = pd.DataFrame(metrics_original_euclidean)
df_cleaned_euclidean = pd.DataFrame(metrics_cleaned_euclidean)
df_original_cosine = pd.DataFrame(metrics_original_cosine)
df_cleaned_cosine = pd.DataFrame(metrics_cleaned_cosine)

print("\nMetrics for Original Corpus with Euclidean Distance:\n", df_original_euclidean)
print("\nMetrics for Cleaned Corpus with Euclidean Distance:\n", df_cleaned_euclidean)
print("\nMetrics for Original Corpus with Cosine Distance:\n", df_original_cosine)
print("\nMetrics for Cleaned Corpus with Cosine Distance:\n", df_cleaned_cosine)
# Out:
# Best F1 Score for Original Corpus (k=200, metric=euclidean): 0.8842, Test time: 3.9373 s
# Confusion Matrix:
#  [[2285  517]
#  [ 170 2624]]
# Best F1 Score for Cleaned Corpus (k=50, metric=euclidean): 0.9030, Test time: 3.0995 s
# Confusion Matrix:
#  [[1712  387]
#  [ 132 2417]]
# Best F1 Score for Original Corpus (k=50, metric=cosine): 0.8868, Test time: 3.5978 s
# Confusion Matrix:
#  [[2390  412]
#  [ 240 2554]]
# Best F1 Score for Cleaned Corpus (k=50, metric=cosine): 0.8993, Test time: 3.0074 s
# Confusion Matrix:
#  [[1664  435]
#  [ 111 2438]]
#
# Metrics for Original Corpus with Euclidean Distance:
#         K  Training Accuracy  Test Accuracy  Precision    Recall        F1  \
# 0      1           0.999196       0.510543   0.642487  0.044381  0.083026
# 1      5           0.670390       0.520372   0.550738  0.213672  0.307891
# 2     10           0.559805       0.510365   0.594406  0.060845  0.110390
# 3     50           0.507573       0.501608   0.857143  0.002147  0.004284
# 4    100           0.880122       0.873481   0.915538  0.822477  0.866516
# 5    200           0.881060       0.877234   0.835403  0.939155  0.884246
# 6    300           0.858049       0.857934   0.794577  0.964925  0.871505
# 7    500           0.811894       0.812187   0.732835  0.981747  0.839223
# 8   1000           0.724677       0.726948   0.647828  0.992842  0.784059
# 9   2000           0.632367       0.633667   0.577019  0.997495  0.731112
# 10  5000           0.530852       0.536276   0.518464  1.000000  0.682879
# 11  8000           0.495867       0.500357   0.499821  1.000000  0.666508
#
#     Test Time (s)
# 0        3.156713
# 1        3.854066
# 2        3.778533
# 3        3.754469
# 4        3.881848
# 5        3.937292
# 6        3.956378
# 7        3.917255
# 8        4.386173
# 9        4.891397
# 10       6.079440
# 11       7.381756
#
# Metrics for Cleaned Corpus with Euclidean Distance:
#         K  Training Accuracy  Test Accuracy  Precision    Recall        F1  \
# 0      1           1.000000       0.459122   0.739726  0.021185  0.041190
# 1      5           0.807336       0.748709   0.934004  0.582974  0.717874
# 2     10           0.869083       0.842513   0.929957  0.770891  0.842986
# 3     50           0.889200       0.888339   0.861983  0.948215  0.903045
# 4    100           0.870321       0.868330   0.820589  0.972538  0.890126
# 5    200           0.832993       0.835628   0.774700  0.987446  0.868230
# 6    300           0.804593       0.807659   0.743597  0.990977  0.849647
# 7    500           0.764899       0.770654   0.706374  0.995685  0.826441
# 8   1000           0.707778       0.708692   0.653402  0.998431  0.789882
# 9   2000           0.656411       0.661145   0.618147  0.999608  0.763903
# 10  5000           0.567556       0.573150   0.562321  1.000000  0.719853
# 11  8000           0.543298       0.548623   0.548526  1.000000  0.708449
#
#     Test Time (s)
# 0        2.507299
# 1        3.070974
# 2        3.069957
# 3        3.099454
# 4        3.116461
# 5        3.120638
# 6        3.189233
# 7        3.256297
# 8        3.503803
# 9        3.612555
# 10       4.851267
# 11       5.772697
#
# Metrics for Original Corpus with Cosine Distance:
#         K  Training Accuracy  Test Accuracy  Precision    Recall        F1  \
# 0      1           0.998481       0.780021   0.822002  0.714030  0.764221
# 1      5           0.896430       0.840600   0.871194  0.798855  0.833458
# 2     10           0.886645       0.855075   0.893609  0.805655  0.847356
# 3     50           0.888432       0.883488   0.861092  0.914102  0.886806
# 4    100           0.878870       0.874911   0.829452  0.943450  0.882786
# 5    200           0.856843       0.857398   0.793012  0.966714  0.871290
# 6    300           0.833743       0.833631   0.759254  0.976378  0.854235
# 7    500           0.792190       0.794317   0.712879  0.984610  0.826995
# 8   1000           0.712613       0.717119   0.639484  0.993558  0.778136
# 9   2000           0.633350       0.634739   0.577801  0.996779  0.731547
# 10  5000           0.535544       0.542888   0.522064  0.999284  0.685827
# 11  8000           0.504848       0.510901   0.505162  0.998210  0.670836
#
#     Test Time (s)
# 0        2.962827
# 1        3.630593
# 2        3.595393
# 3        3.597781
# 4        3.728912
# 5        3.859333
# 6        3.887067
# 7        4.030364
# 8        4.153118
# 9        4.618776
# 10       5.688808
# 11       6.816005
#
# Metrics for Cleaned Corpus with Cosine Distance:
#         K  Training Accuracy  Test Accuracy  Precision    Recall        F1  \
# 0      1           1.000000       0.800559   0.850475  0.772067  0.809377
# 1      5           0.900602       0.868546   0.882399  0.877207  0.879795
# 2     10           0.892265       0.873064   0.891330  0.875245  0.883215
# 3     50           0.884359       0.882530   0.848590  0.956454  0.899299
# 4    100           0.865372       0.864028   0.813133  0.976461  0.887344
# 5    200           0.830142       0.830895   0.769325  0.987838  0.864995
# 6    300           0.802711       0.805508   0.741132  0.991761  0.848322
# 7    500           0.763662       0.768503   0.704413  0.995685  0.825098
# 8   1000           0.707025       0.708477   0.653234  0.998431  0.789760
# 9   2000           0.655927       0.660929   0.617997  0.999608  0.763789
# 10  5000           0.567448       0.572719   0.562073  1.000000  0.719650
# 11  8000           0.543352       0.548623   0.548526  1.000000  0.708449
#
#     Test Time (s)
# 0        2.295097
# 1        2.849058
# 2        2.874992
# 3        3.007400
# 4        2.936133
# 5        2.897938
# 6        3.023760
# 7        3.129520
# 8        3.184776
# 9        3.594386
# 10       4.557880
# 11       5.457348

# %%
metrics_to_plot = ["Training Accuracy", "Test Accuracy", "Precision", "Recall", "F1", "Test Time (s)"]

df_original_euclidean["Metric"] = "Euclidean"
df_original_cosine["Metric"] = "Cosine"
df_original_combined = pd.concat([df_original_euclidean, df_original_cosine])

df_cleaned_euclidean["Metric"] = "Euclidean"
df_cleaned_cosine["Metric"] = "Cosine"
df_cleaned_combined = pd.concat([df_cleaned_euclidean, df_cleaned_cosine])

fig, axes = plt.subplots(len(metrics_to_plot), 2, figsize=(16, 36), sharey=True)
fig.suptitle("KNN Metrics for Original and Cleaned Corpora (Blue L2 | Orange Cosine)", fontsize=16)

for i, metric in enumerate(metrics_to_plot):
    sns.barplot(ax=axes[i, 0], y="K", x=metric, hue="Metric", data=df_original_combined, orient='h', 
                palette={"Euclidean": "royalblue", "Cosine": "orange"})
    axes[i, 0].set_title(f"Original Corpus - {metric}")
    axes[i, 0].get_legend().remove()

    sns.barplot(ax=axes[i, 1], y="K", x=metric, hue="Metric", data=df_cleaned_combined, orient='h', 
                palette={"Euclidean": "royalblue", "Cosine": "orange"})
    axes[i, 1].set_title(f"Cleaned Corpus - {metric}")
    axes[i, 1].get_legend().remove()

handles, labels = axes[0, 0].get_legend_handles_labels()
fig.legend(handles, labels, loc="upper right", title="Metric")

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
metrics_to_display = ["K", "Training Accuracy", "Test Accuracy", "Precision", "Recall", "F1", "Test Time (s)"]

table_original_pivot = table_original.pivot_table(index="K", columns="Metric", values=metrics_to_display)
table_cleaned_pivot = table_cleaned.pivot_table(index="K", columns="Metric", values=metrics_to_display)

def apply_dual_heatmap(table, cmap_euclidean="YlGnBu", cmap_cosine="OrRd"):
    styled_table = table.style
    
    for col in table.columns:
        if "Euclidean" in col:
            styled_table = styled_table.background_gradient(cmap=cmap_euclidean, subset=(slice(None), col))
        elif "Cosine" in col:
            styled_table = styled_table.background_gradient(cmap=cmap_cosine, subset=(slice(None), col))
    
    return styled_table

print("Metrics Table with Heatmap for Original Corpus:")
display(apply_dual_heatmap(table_original_pivot))

print("\nMetrics Table with Heatmap for Cleaned Corpus:")
display(apply_dual_heatmap(table_cleaned_pivot))
# Out:
# Metrics Table with Heatmap for Original Corpus:
# <style type="text/css">
# #T_32b50_row0_col0, #T_32b50_row9_col8 {
#   background-color: #fda671;
#   color: #000000;
# }
# #T_32b50_row0_col1 {
#   background-color: #f3fabd;
#   color: #000000;
# }
# #T_32b50_row0_col2 {
#   background-color: #c4170f;
#   color: #f1f1f1;
# }
# #T_32b50_row0_col3 {
#   background-color: #92d5b9;
#   color: #000000;
# }
# #T_32b50_row0_col4, #T_32b50_row0_col8, #T_32b50_row11_col0, #T_32b50_row11_col2, #T_32b50_row11_col6, #T_32b50_row11_col10 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# #T_32b50_row0_col5 {
#   background-color: #f9fdcc;
#   color: #000000;
# }
# #T_32b50_row0_col6 {
#   background-color: #dc3c28;
#   color: #f1f1f1;
# }
# #T_32b50_row0_col7, #T_32b50_row2_col7 {
#   background-color: #fcfed1;
#   color: #000000;
# }
# #T_32b50_row0_col9, #T_32b50_row3_col1, #T_32b50_row3_col5, #T_32b50_row3_col7, #T_32b50_row11_col3, #T_32b50_row11_col7, #T_32b50_row11_col11 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_32b50_row0_col10, #T_32b50_row2_col2, #T_32b50_row3_col0, #T_32b50_row3_col6, #T_32b50_row10_col4, #T_32b50_row11_col4, #T_32b50_row11_col8 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_32b50_row0_col11, #T_32b50_row4_col3, #T_32b50_row5_col1, #T_32b50_row5_col7, #T_32b50_row9_col5, #T_32b50_row10_col5, #T_32b50_row11_col5, #T_32b50_row11_col9 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_32b50_row1_col0 {
#   background-color: #d62f1e;
#   color: #f1f1f1;
# }
# #T_32b50_row1_col1, #T_32b50_row1_col11 {
#   background-color: #90d4b9;
#   color: #000000;
# }
# #T_32b50_row1_col2 {
#   background-color: #960000;
#   color: #f1f1f1;
# }
# #T_32b50_row1_col3 {
#   background-color: #edf8b2;
#   color: #000000;
# }
# #T_32b50_row1_col4 {
#   background-color: #fdca94;
#   color: #000000;
# }
# #T_32b50_row1_col5 {
#   background-color: #d3eeb3;
#   color: #000000;
# }
# #T_32b50_row1_col6, #T_32b50_row5_col4 {
#   background-color: #ae0000;
#   color: #f1f1f1;
# }
# #T_32b50_row1_col7 {
#   background-color: #f8fcc9;
#   color: #000000;
# }
# #T_32b50_row1_col8 {
#   background-color: #fee0b8;
#   color: #000000;
# }
# #T_32b50_row1_col9 {
#   background-color: #e1f3b2;
#   color: #000000;
# }
# #T_32b50_row1_col10 {
#   background-color: #ca1e14;
#   color: #f1f1f1;
# }
# #T_32b50_row2_col0 {
#   background-color: #c3150e;
#   color: #f1f1f1;
# }
# #T_32b50_row2_col1 {
#   background-color: #eef8b3;
#   color: #000000;
# }
# #T_32b50_row2_col3 {
#   background-color: #ceecb3;
#   color: #000000;
# }
# #T_32b50_row2_col4 {
#   background-color: #fdc68f;
#   color: #000000;
# }
# #T_32b50_row2_col5 {
#   background-color: #f7fcc6;
#   color: #000000;
# }
# #T_32b50_row2_col6 {
#   background-color: #9e0000;
#   color: #f1f1f1;
# }
# #T_32b50_row2_col8, #T_32b50_row3_col8 {
#   background-color: #fee2bb;
#   color: #000000;
# }
# #T_32b50_row2_col9 {
#   background-color: #e7f6b1;
#   color: #000000;
# }
# #T_32b50_row2_col10, #T_32b50_row3_col10 {
#   background-color: #cf2618;
#   color: #f1f1f1;
# }
# #T_32b50_row2_col11 {
#   background-color: #edf8b1;
#   color: #000000;
# }
# #T_32b50_row3_col2 {
#   background-color: #a10000;
#   color: #f1f1f1;
# }
# #T_32b50_row3_col3 {
#   background-color: #253896;
#   color: #f1f1f1;
# }
# #T_32b50_row3_col4 {
#   background-color: #e0442f;
#   color: #f1f1f1;
# }
# #T_32b50_row3_col9 {
#   background-color: #e8f6b1;
#   color: #000000;
# }
# #T_32b50_row3_col11 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_32b50_row4_col0 {
#   background-color: #860000;
#   color: #f1f1f1;
# }
# #T_32b50_row4_col1 {
#   background-color: #0d2161;
#   color: #f1f1f1;
# }
# #T_32b50_row4_col2 {
#   background-color: #be0f0a;
#   color: #f1f1f1;
# }
# #T_32b50_row4_col4 {
#   background-color: #c71b12;
#   color: #f1f1f1;
# }
# #T_32b50_row4_col5 {
#   background-color: #24459c;
#   color: #f1f1f1;
# }
# #T_32b50_row4_col6, #T_32b50_row8_col4 {
#   background-color: #870000;
#   color: #f1f1f1;
# }
# #T_32b50_row4_col7 {
#   background-color: #0a1e5c;
#   color: #f1f1f1;
# }
# #T_32b50_row4_col8 {
#   background-color: #fdddb0;
#   color: #000000;
# }
# #T_32b50_row4_col9 {
#   background-color: #e0f3b2;
#   color: #000000;
# }
# #T_32b50_row4_col10 {
#   background-color: #d52d1d;
#   color: #f1f1f1;
# }
# #T_32b50_row4_col11, #T_32b50_row5_col11 {
#   background-color: #2259a6;
#   color: #f1f1f1;
# }
# #T_32b50_row5_col0 {
#   background-color: #9c0000;
#   color: #f1f1f1;
# }
# #T_32b50_row5_col2 {
#   background-color: #d93422;
#   color: #f1f1f1;
# }
# #T_32b50_row5_col3 {
#   background-color: #234b9f;
#   color: #f1f1f1;
# }
# #T_32b50_row5_col5 {
#   background-color: #162874;
#   color: #f1f1f1;
# }
# #T_32b50_row5_col6 {
#   background-color: #9b0000;
#   color: #f1f1f1;
# }
# #T_32b50_row5_col8 {
#   background-color: #fdd7a4;
#   color: #000000;
# }
# #T_32b50_row5_col9, #T_32b50_row9_col3 {
#   background-color: #dbf1b2;
#   color: #000000;
# }
# #T_32b50_row5_col10 {
#   background-color: #de3f2b;
#   color: #f1f1f1;
# }
# #T_32b50_row6_col0 {
#   background-color: #ba0906;
#   color: #f1f1f1;
# }
# #T_32b50_row6_col1 {
#   background-color: #0b1f5e;
#   color: #f1f1f1;
# }
# #T_32b50_row6_col2 {
#   background-color: #e9583e;
#   color: #f1f1f1;
# }
# #T_32b50_row6_col3 {
#   background-color: #206eb0;
#   color: #f1f1f1;
# }
# #T_32b50_row6_col4 {
#   background-color: #a00000;
#   color: #f1f1f1;
# }
# #T_32b50_row6_col5 {
#   background-color: #0f2367;
#   color: #f1f1f1;
# }
# #T_32b50_row6_col6 {
#   background-color: #b50302;
#   color: #f1f1f1;
# }
# #T_32b50_row6_col7, #T_32b50_row7_col1 {
#   background-color: #142670;
#   color: #f1f1f1;
# }
# #T_32b50_row6_col8 {
#   background-color: #fdd6a2;
#   color: #000000;
# }
# #T_32b50_row6_col9 {
#   background-color: #daf0b3;
#   color: #000000;
# }
# #T_32b50_row6_col10 {
#   background-color: #e7533a;
#   color: #f1f1f1;
# }
# #T_32b50_row6_col11 {
#   background-color: #216aad;
#   color: #f1f1f1;
# }
# #T_32b50_row7_col0 {
#   background-color: #dc3a27;
#   color: #f1f1f1;
# }
# #T_32b50_row7_col2 {
#   background-color: #f98254;
#   color: #f1f1f1;
# }
# #T_32b50_row7_col3 {
#   background-color: #2fa4c2;
#   color: #f1f1f1;
# }
# #T_32b50_row7_col4 {
#   background-color: #940000;
#   color: #f1f1f1;
# }
# #T_32b50_row7_col5 {
#   background-color: #0c2060;
#   color: #f1f1f1;
# }
# #T_32b50_row7_col6 {
#   background-color: #d42c1c;
#   color: #f1f1f1;
# }
# #T_32b50_row7_col7, #T_32b50_row9_col1 {
#   background-color: #24449c;
#   color: #f1f1f1;
# }
# #T_32b50_row7_col8 {
#   background-color: #fdcf99;
#   color: #000000;
# }
# #T_32b50_row7_col9 {
#   background-color: #dcf1b2;
#   color: #000000;
# }
# #T_32b50_row7_col10 {
#   background-color: #f3724e;
#   color: #f1f1f1;
# }
# #T_32b50_row7_col11 {
#   background-color: #1d90c0;
#   color: #f1f1f1;
# }
# #T_32b50_row8_col0 {
#   background-color: #fc8e5a;
#   color: #f1f1f1;
# }
# #T_32b50_row8_col1 {
#   background-color: #22328f;
#   color: #f1f1f1;
# }
# #T_32b50_row8_col2 {
#   background-color: #fdc18a;
#   color: #000000;
# }
# #T_32b50_row8_col3 {
#   background-color: #89d1ba;
#   color: #000000;
# }
# #T_32b50_row8_col5 {
#   background-color: #091e5a;
#   color: #f1f1f1;
# }
# #T_32b50_row8_col6 {
#   background-color: #f67c52;
#   color: #f1f1f1;
# }
# #T_32b50_row8_col7 {
#   background-color: #2498c1;
#   color: #f1f1f1;
# }
# #T_32b50_row8_col8 {
#   background-color: #fdc892;
#   color: #000000;
# }
# #T_32b50_row8_col9 {
#   background-color: #b0e0b6;
#   color: #000000;
# }
# #T_32b50_row8_col10 {
#   background-color: #fdab75;
#   color: #000000;
# }
# #T_32b50_row8_col11 {
#   background-color: #57bec1;
#   color: #000000;
# }
# #T_32b50_row9_col0 {
#   background-color: #fdce98;
#   color: #000000;
# }
# #T_32b50_row9_col2 {
#   background-color: #fedfb4;
#   color: #000000;
# }
# #T_32b50_row9_col4 {
#   background-color: #820000;
#   color: #f1f1f1;
# }
# #T_32b50_row9_col6 {
#   background-color: #fdc38d;
#   color: #000000;
# }
# #T_32b50_row9_col7 {
#   background-color: #8cd2ba;
#   color: #000000;
# }
# #T_32b50_row9_col9 {
#   background-color: #6dc6be;
#   color: #000000;
# }
# #T_32b50_row9_col10 {
#   background-color: #fdd29c;
#   color: #000000;
# }
# #T_32b50_row9_col11 {
#   background-color: #bbe4b5;
#   color: #000000;
# }
# #T_32b50_row10_col0 {
#   background-color: #feefd9;
#   color: #000000;
# }
# #T_32b50_row10_col1 {
#   background-color: #2356a4;
#   color: #f1f1f1;
# }
# #T_32b50_row10_col2 {
#   background-color: #fff2e0;
#   color: #000000;
# }
# #T_32b50_row10_col3 {
#   background-color: #f9fdcb;
#   color: #000000;
# }
# #T_32b50_row10_col6 {
#   background-color: #feedd4;
#   color: #000000;
# }
# #T_32b50_row10_col7 {
#   ba
# Metrics Table with Heatmap for Cleaned Corpus:
# <style type="text/css">
# #T_b1eed_row0_col0 {
#   background-color: #f98455;
#   color: #f1f1f1;
# }
# #T_b1eed_row0_col1, #T_b1eed_row0_col5, #T_b1eed_row0_col7, #T_b1eed_row0_col9, #T_b1eed_row11_col3, #T_b1eed_row11_col11 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_b1eed_row0_col2 {
#   background-color: #b00000;
#   color: #f1f1f1;
# }
# #T_b1eed_row0_col3 {
#   background-color: #44b7c4;
#   color: #f1f1f1;
# }
# #T_b1eed_row0_col4, #T_b1eed_row0_col8, #T_b1eed_row11_col0, #T_b1eed_row11_col2, #T_b1eed_row11_col6, #T_b1eed_row11_col10 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# #T_b1eed_row0_col6 {
#   background-color: #d52d1d;
#   color: #f1f1f1;
# }
# #T_b1eed_row0_col10, #T_b1eed_row2_col2, #T_b1eed_row3_col0, #T_b1eed_row3_col6, #T_b1eed_row9_col4, #T_b1eed_row10_col4, #T_b1eed_row11_col4, #T_b1eed_row11_col8 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_b1eed_row0_col11, #T_b1eed_row1_col3, #T_b1eed_row3_col1, #T_b1eed_row3_col7, #T_b1eed_row8_col5, #T_b1eed_row9_col5, #T_b1eed_row10_col5, #T_b1eed_row11_col5, #T_b1eed_row11_col9 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_b1eed_row1_col0, #T_b1eed_row4_col4 {
#   background-color: #a90000;
#   color: #f1f1f1;
# }
# #T_b1eed_row1_col1 {
#   background-color: #2352a3;
#   color: #f1f1f1;
# }
# #T_b1eed_row1_col2 {
#   background-color: #890000;
#   color: #f1f1f1;
# }
# #T_b1eed_row1_col4 {
#   background-color: #fc9b66;
#   color: #000000;
# }
# #T_b1eed_row1_col5, #T_b1eed_row6_col11 {
#   background-color: #2ca1c2;
#   color: #f1f1f1;
# }
# #T_b1eed_row1_col6 {
#   background-color: #8f0000;
#   color: #f1f1f1;
# }
# #T_b1eed_row1_col7 {
#   background-color: #1f7db6;
#   color: #f1f1f1;
# }
# #T_b1eed_row1_col8 {
#   background-color: #fee0b8;
#   color: #000000;
# }
# #T_b1eed_row1_col9, #T_b1eed_row2_col9 {
#   background-color: #dff2b2;
#   color: #000000;
# }
# #T_b1eed_row1_col10 {
#   background-color: #cd2316;
#   color: #f1f1f1;
# }
# #T_b1eed_row1_col11, #T_b1eed_row8_col7 {
#   background-color: #2a9ec1;
#   color: #f1f1f1;
# }
# #T_b1eed_row2_col0 {
#   background-color: #a10000;
#   color: #f1f1f1;
# }
# #T_b1eed_row2_col1 {
#   background-color: #172978;
#   color: #f1f1f1;
# }
# #T_b1eed_row2_col3, #T_b1eed_row6_col5 {
#   background-color: #0a1e5c;
#   color: #f1f1f1;
# }
# #T_b1eed_row2_col4 {
#   background-color: #fc9f6a;
#   color: #000000;
# }
# #T_b1eed_row2_col5 {
#   background-color: #2258a5;
#   color: #f1f1f1;
# }
# #T_b1eed_row2_col6 {
#   background-color: #8a0000;
#   color: #f1f1f1;
# }
# #T_b1eed_row2_col7 {
#   background-color: #21308b;
#   color: #f1f1f1;
# }
# #T_b1eed_row2_col8 {
#   background-color: #fedfb5;
#   color: #000000;
# }
# #T_b1eed_row2_col10 {
#   background-color: #d32a1b;
#   color: #f1f1f1;
# }
# #T_b1eed_row2_col11 {
#   background-color: #216daf;
#   color: #f1f1f1;
# }
# #T_b1eed_row3_col2 {
#   background-color: #b20000;
#   color: #f1f1f1;
# }
# #T_b1eed_row3_col3 {
#   background-color: #24489d;
#   color: #f1f1f1;
# }
# #T_b1eed_row3_col4 {
#   background-color: #c51810;
#   color: #f1f1f1;
# }
# #T_b1eed_row3_col5 {
#   background-color: #142670;
#   color: #f1f1f1;
# }
# #T_b1eed_row3_col8 {
#   background-color: #fdd8a7;
#   color: #000000;
# }
# #T_b1eed_row3_col9, #T_b1eed_row9_col3 {
#   background-color: #dcf1b2;
#   color: #000000;
# }
# #T_b1eed_row3_col10 {
#   background-color: #d7301f;
#   color: #f1f1f1;
# }
# #T_b1eed_row3_col11 {
#   background-color: #225ca7;
#   color: #f1f1f1;
# }
# #T_b1eed_row4_col0 {
#   background-color: #990000;
#   color: #f1f1f1;
# }
# #T_b1eed_row4_col1, #T_b1eed_row5_col5 {
#   background-color: #0b1f5e;
#   color: #f1f1f1;
# }
# #T_b1eed_row4_col2 {
#   background-color: #d12719;
#   color: #f1f1f1;
# }
# #T_b1eed_row4_col3 {
#   background-color: #2070b0;
#   color: #f1f1f1;
# }
# #T_b1eed_row4_col5 {
#   background-color: #0e2265;
#   color: #f1f1f1;
# }
# #T_b1eed_row4_col6 {
#   background-color: #960000;
#   color: #f1f1f1;
# }
# #T_b1eed_row4_col7 {
#   background-color: #12256d;
#   color: #f1f1f1;
# }
# #T_b1eed_row4_col8, #T_b1eed_row9_col2 {
#   background-color: #fddcaf;
#   color: #000000;
# }
# #T_b1eed_row4_col9 {
#   background-color: #dbf1b2;
#   color: #000000;
# }
# #T_b1eed_row4_col10 {
#   background-color: #df432d;
#   color: #f1f1f1;
# }
# #T_b1eed_row4_col11, #T_b1eed_row10_col9 {
#   background-color: #216bae;
#   color: #f1f1f1;
# }
# #T_b1eed_row5_col0 {
#   background-color: #c3150e;
#   color: #f1f1f1;
# }
# #T_b1eed_row5_col1 {
#   background-color: #11246b;
#   color: #f1f1f1;
# }
# #T_b1eed_row5_col2 {
#   background-color: #ec5d42;
#   color: #f1f1f1;
# }
# #T_b1eed_row5_col3 {
#   background-color: #289cc1;
#   color: #f1f1f1;
# }
# #T_b1eed_row5_col4 {
#   background-color: #940000;
#   color: #f1f1f1;
# }
# #T_b1eed_row5_col6 {
#   background-color: #bb0b07;
#   color: #f1f1f1;
# }
# #T_b1eed_row5_col7 {
#   background-color: #243392;
#   color: #f1f1f1;
# }
# #T_b1eed_row5_col8 {
#   background-color: #fddeb3;
#   color: #000000;
# }
# #T_b1eed_row5_col9 {
#   background-color: #daf0b3;
#   color: #000000;
# }
# #T_b1eed_row5_col10 {
#   background-color: #ef6447;
#   color: #f1f1f1;
# }
# #T_b1eed_row5_col11 {
#   background-color: #1d8dbe;
#   color: #f1f1f1;
# }
# #T_b1eed_row6_col0 {
#   background-color: #da3724;
#   color: #f1f1f1;
# }
# #T_b1eed_row6_col1 {
#   background-color: #162874;
#   color: #f1f1f1;
# }
# #T_b1eed_row6_col2 {
#   background-color: #f67a51;
#   color: #f1f1f1;
# }
# #T_b1eed_row6_col3 {
#   background-color: #3fb4c4;
#   color: #f1f1f1;
# }
# #T_b1eed_row6_col4 {
#   background-color: #8e0000;
#   color: #f1f1f1;
# }
# #T_b1eed_row6_col6 {
#   background-color: #d2291a;
#   color: #f1f1f1;
# }
# #T_b1eed_row6_col7 {
#   background-color: #23499e;
#   color: #f1f1f1;
# }
# #T_b1eed_row6_col8 {
#   background-color: #fdd8a6;
#   color: #000000;
# }
# #T_b1eed_row6_col9, #T_b1eed_row11_col7 {
#   background-color: #d4eeb3;
#   color: #000000;
# }
# #T_b1eed_row6_col10 {
#   background-color: #f57750;
#   color: #f1f1f1;
# }
# #T_b1eed_row7_col0 {
#   background-color: #f0694a;
#   color: #f1f1f1;
# }
# #T_b1eed_row7_col1 {
#   background-color: #1c2d81;
#   color: #f1f1f1;
# }
# #T_b1eed_row7_col2 {
#   background-color: #fc9e69;
#   color: #000000;
# }
# #T_b1eed_row7_col3 {
#   background-color: #6fc7bd;
#   color: #000000;
# }
# #T_b1eed_row7_col4 {
#   background-color: #860000;
#   color: #f1f1f1;
# }
# #T_b1eed_row7_col5 {
#   background-color: #091e5a;
#   color: #f1f1f1;
# }
# #T_b1eed_row7_col6 {
#   background-color: #e9573d;
#   color: #f1f1f1;
# }
# #T_b1eed_row7_col7 {
#   background-color: #2168ad;
#   color: #f1f1f1;
# }
# #T_b1eed_row7_col8 {
#   background-color: #fdd19b;
#   color: #000000;
# }
# #T_b1eed_row7_col9 {
#   background-color: #ceecb3;
#   color: #000000;
# }
# #T_b1eed_row7_col10 {
#   background-color: #fc935f;
#   color: #000000;
# }
# #T_b1eed_row7_col11 {
#   background-color: #48b9c3;
#   color: #f1f1f1;
# }
# #T_b1eed_row8_col0 {
#   background-color: #fda872;
#   color: #000000;
# }
# #T_b1eed_row8_col1 {
#   background-color: #253595;
#   color: #f1f1f1;
# }
# #T_b1eed_row8_col2 {
#   background-color: #fdc992;
#   color: #000000;
# }
# #T_b1eed_row8_col3 {
#   background-color: #bbe4b5;
#   color: #000000;
# }
# #T_b1eed_row8_col4 {
#   background-color: #810000;
#   color: #f1f1f1;
# }
# #T_b1eed_row8_col6 {
#   background-color: #fc9560;
#   color: #000000;
# }
# #T_b1eed_row8_col8 {
#   background-color: #fdce97;
#   color: #000000;
# }
# #T_b1eed_row8_col9 {
#   background-color: #a7dcb7;
#   color: #000000;
# }
# #T_b1eed_row8_col10 {
#   background-color: #fdbf88;
#   color: #000000;
# }
# #T_b1eed_row8_col11 {
#   background-color: #87d0ba;
#   color: #000000;
# }
# #T_b1eed_row9_col0 {
#   background-color: #fdcc96;
#   color: #000000;
# }
# #T_b1eed_row9_col1 {
#   background-color: #24409a;
#   color: #f1f1f1;
# }
# #T_b1eed_row9_col6 {
#   background-color: #fdc38c;
#   color: #000000;
# }
# #T_b1eed_row9_col7 {
#   background-color: #50bbc2;
#   color: #000000;
# }
# #T_b1eed_row9_col8 {
#   background-color: #fdad77;
#   color: #000000;
# }
# #T_b1eed_row9_col9 {
#   background-color: #95d5b9;
#   color: #000000;
# }
# #T_b1eed_row9_col10 {
#   background-color: #fdd49f;
#   color: #000000;
# }
# #T_b1eed_row9_col11 {
#   background-color: #c8e9b4;
#   color: #000000;
# }
# #T_b1eed_row10_col0 {
#   background-color: #fff0db;
#   color: #000000;
# }
# #T_b1eed_row10_col1 {
#   background-color: #2351a2;
#   color: #f1f1f1;
# }
# #T_b1eed_row10_col2 {
#   background-color: #fff2e1;
#   color: #000000;
# }
# #T_b1eed_row10_col3 {
#   background-color: #fafdce;
#   color: #000000;
# }
# #T_b1eed_row10_col6 {
#   ba
