# %%
# Nhập thư viện
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import time

import warnings
warnings.filterwarnings('ignore')

# Đọc bộ dữ liệu
corpus = pd.read_csv('data/cleaned_mhc.csv')

# Chuẩn bị dữ liệu
X_train, X_test, y_train, y_test = train_test_split(
    corpus['text'],
    corpus['label'],
    test_size=0.2,
    random_state=42
)

tfidf = TfidfVectorizer(max_features=3500)
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

n_components = 100

lsa = TruncatedSVD(n_components=n_components, random_state=42)
X_train_lsa = lsa.fit_transform(X_train_tfidf)
X_test_lsa = lsa.transform(X_test_tfidf)

print(f"TF-IDF - Train shape: {X_train_tfidf.shape}, Test Shape: {X_test_tfidf.shape}")
print(f"LSA - Train shape: {X_train_lsa.shape}, Test Shape: {X_test_lsa.shape}")
# Out:
# TF-IDF - Train shape: (18592, 3500), Test Shape: (4648, 3500)
# LSA - Train shape: (18592, 100), Test Shape: (4648, 100)

# %%
import time
import numpy as np
import pandas as pd
from sklearn.svm import LinearSVC, SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Define the range of C values to test
C_values = [0.01, 0.1, 1, 10, 100]

# Define the range of gamma values to test
gamma_values = [0.001, 0.01, 0.1, 1, 10]

def evaluate_model(X_train, X_test, y_train, y_test, dataset_name):
    # Prepare a table to store results
    metrics_table = []

    for C in C_values:
        # Initialize the model with the current C value
        model = LinearSVC(C=C, random_state=42, max_iter=10000)

        # Fit the model and record training time
        start_fit = time.time()
        model.fit(X_train, y_train)
        fit_time = time.time() - start_fit

        # Record testing time for predictions
        start_test = time.time()
        y_pred_train = model.predict(X_train)
        y_pred_test = model.predict(X_test)
        test_time = time.time() - start_test

        # Compute metrics
        train_accuracy = accuracy_score(y_train, y_pred_train)
        test_accuracy = accuracy_score(y_test, y_pred_test)
        precision = precision_score(y_test, y_pred_test, average='weighted')
        recall = recall_score(y_test, y_pred_test, average='weighted')
        f1 = f1_score(y_test, y_pred_test, average='weighted')

        # Compute confusion matrix
        conf_matrix = confusion_matrix(y_test, y_pred_test)

        print(f"Confusion Matrix for {dataset_name} (C={C}):")
        print(conf_matrix)

        # Append metrics to the table
        metrics_table.append([C, train_accuracy, test_accuracy, precision, recall, f1, fit_time, test_time])

    # Create a dataframe for the metrics
    columns = ["C", "Train Accuracy", "Test Accuracy", "Precision", "Recall", "F1", "Fit Time", "Test Time"]
    metrics_df = pd.DataFrame(metrics_table, columns=columns)

    # Display the table
    print(f"\nMetrics for {dataset_name}:")
    print(metrics_df.to_string(index=False))

    return metrics_df

# Evaluate on TF-IDF dataset
tfidf_results = evaluate_model(X_train_tfidf, X_test_tfidf, y_train, y_test, "TF-IDF")

# Evaluate on LSA dataset
lsa_results = evaluate_model(X_train_lsa, X_test_lsa, y_train, y_test, "LSA")
# Out:
# Confusion Matrix for TF-IDF (C=0.01):
# [[1909  190]
#  [ 243 2306]]
# Confusion Matrix for TF-IDF (C=0.1):
# [[1927  172]
#  [ 180 2369]]
# Confusion Matrix for TF-IDF (C=1):
# [[1922  177]
#  [ 192 2357]]
# Confusion Matrix for TF-IDF (C=10):
# [[1862  237]
#  [ 250 2299]]
# Confusion Matrix for TF-IDF (C=100):
# [[1783  316]
#  [ 304 2245]]
#
# Metrics for TF-IDF:
#      C  Train Accuracy  Test Accuracy  Precision   Recall       F1  Fit Time  Test Time
#   0.01        0.911252       0.906842   0.907261 0.906842 0.906933  0.036041   0.001961
#   0.10        0.940512       0.924269   0.924299 0.924269 0.924281  0.046930   0.002029
#   1.00        0.962188       0.920611   0.920679 0.920611 0.920635  0.059863   0.002000
#  10.00        0.977786       0.895224   0.895293 0.895224 0.895252  0.085375   0.002000
# 100.00        0.990587       0.866609   0.866552 0.866609 0.866575  0.424543   0.002262
# Confusion Matrix for LSA (C=0.01):
# [[1897  202]
#  [ 267 2282]]
# Confusion Matrix for LSA (C=0.1):
# [[1909  190]
#  [ 235 2314]]
# Confusion Matrix for LSA (C=1):
# [[1903  196]
#  [ 227 2322]]
# Confusion Matrix for LSA (C=10):
# [[1904  195]
#  [ 224 2325]]
# Confusion Matrix for LSA (C=100):
# [[1904  195]
#  [ 223 2326]]
#
# Metrics for LSA:
#      C  Train Accuracy  Test Accuracy  Precision   Recall       F1  Fit Time  Test Time
#   0.01        0.898021       0.899096   0.899685 0.899096 0.899214  0.083750   0.002086
#   0.10        0.909370       0.908563   0.908889 0.908563 0.908641  0.089470   0.001000
#   1.00        0.911736       0.908993   0.909185 0.908993 0.909048  0.126276   0.002000
#  10.00        0.911629       0.909854   0.910028 0.909854 0.909905  0.127320   0.001021
# 100.00        0.911629       0.910069   0.910234 0.910069 0.910118  0.118135   0.001000

# %%
# tfidf_results = tfidf_results.drop(columns=['Fit Time', 'Test Time'])
# lsa_results = lsa_results.drop(columns=['Fit Time', 'Test Time'])

# Define desired column order
ordered_columns = [
    "C", "Train Accuracy", "Test Accuracy", "F1 Score", "Precision", "Recall"
]

tfidf_results = tfidf_results[ordered_columns].rename(columns={
    "F1": "F1 Score",
})

lsa_results = lsa_results[ordered_columns].rename(columns={
    "F1": "F1 Score",
})

# Reorder columns
tfidf_results = tfidf_results[ordered_columns]
lsa_results = lsa_results[ordered_columns]

# Style tables with heatmap, excluding the 'C' column from coloring
def style_heatmap(df, cmap):
    return df.style.applymap(lambda _: "background-color: none;", subset=['C']).background_gradient(
        cmap=cmap, subset=df.columns.difference(['C'])
    ).format(precision=3)

# Apply styles
tfidf_table_styled = style_heatmap(tfidf_results, cmap="Reds")
lsa_table_styled = style_heatmap(lsa_results, cmap="Blues")

# Display the styled tables
print("TF-IDF Results with Styled Heatmap:")
display(tfidf_table_styled)

print("\nLSA Results with Styled Heatmap:")
display(lsa_table_styled)
# Out:
# TF-IDF Results with Styled Heatmap:
# <style type="text/css">
# #T_6dfdd_row0_col0, #T_6dfdd_row1_col0, #T_6dfdd_row2_col0, #T_6dfdd_row3_col0, #T_6dfdd_row4_col0 {
#   background-color: none;
# }
# #T_6dfdd_row0_col1, #T_6dfdd_row4_col2, #T_6dfdd_row4_col3, #T_6dfdd_row4_col4, #T_6dfdd_row4_col5 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_6dfdd_row0_col2, #T_6dfdd_row0_col5 {
#   background-color: #da2723;
#   color: #f1f1f1;
# }
# #T_6dfdd_row0_col3 {
#   background-color: #d92523;
#   color: #f1f1f1;
# }
# #T_6dfdd_row0_col4 {
#   background-color: #d82422;
#   color: #f1f1f1;
# }
# #T_6dfdd_row1_col1 {
#   background-color: #fc9474;
#   color: #000000;
# }
# #T_6dfdd_row1_col2, #T_6dfdd_row1_col3, #T_6dfdd_row1_col4, #T_6dfdd_row1_col5, #T_6dfdd_row4_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_6dfdd_row2_col1 {
#   background-color: #ea362a;
#   color: #f1f1f1;
# }
# #T_6dfdd_row2_col2, #T_6dfdd_row2_col3, #T_6dfdd_row2_col4, #T_6dfdd_row2_col5 {
#   background-color: #860811;
#   color: #f1f1f1;
# }
# #T_6dfdd_row3_col1 {
#   background-color: #b01217;
#   color: #f1f1f1;
# }
# #T_6dfdd_row3_col2, #T_6dfdd_row3_col3, #T_6dfdd_row3_col4, #T_6dfdd_row3_col5 {
#   background-color: #fb6b4b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6dfdd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6dfdd_level0_col0" class="col_heading level0 col0" >C</th>
#       <th id="T_6dfdd_level0_col1" class="col_heading level0 col1" >Train Accuracy</th>
#       <th id="T_6dfdd_level0_col2" class="col_heading level0 col2" >Test Accuracy</th>
#       <th id="T_6dfdd_level0_col3" class="col_heading level0 col3" >F1 Score</th>
#       <th id="T_6dfdd_level0_col4" class="col_heading level0 col4" >Precision</th>
#       <th id="T_6dfdd_level0_col5" class="col_heading level0 col5" >Recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6dfdd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6dfdd_row0_col0" class="data row0 col0" >0.010</td>
#       <td id="T_6dfdd_row0_col1" class="data row0 col1" >0.911</td>
#       <td id="T_6dfdd_row0_col2" class="data row0 col2" >0.907</td>
#       <td id="T_6dfdd_row0_col3" class="data row0 col3" >0.907</td>
#       <td id="T_6dfdd_row0_col4" class="data row0 col4" >0.907</td>
#       <td id="T_6dfdd_row0_col5" class="data row0 col5" >0.907</td>
#     </tr>
#     <tr>
#       <th id="T_6dfdd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6dfdd_row1_col0" class="data row1 col0" >0.100</td>
#       <td id="T_6dfdd_row1_col1" class="data row1 col1" >0.941</td>
#       <td id="T_6dfdd_row1_col2" class="data row1 col2" >0.924</td>
#       <td id="T_6dfdd_row1_col3" class="data row1 col3" >0.924</td>
#       <td id="T_6dfdd_row1_col4" class="data row1 col4" >0.924</td>
#       <td id="T_6dfdd_row1_col5" class="data row1 col5" >0.924</td>
#     </tr>
#     <tr>
#       <th id="T_6dfdd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6dfdd_row2_col0" class="data row2 col0" >1.000</td>
#       <td id="T_6dfdd_row2_col1" class="data row2 col1" >0.962</td>
#       <td id="T_6dfdd_row2_col2" class="data row2 col2" >0.921</td>
#       <td id="T_6dfdd_row2_col3" class="data row2 col3" >0.921</td>
#       <td id="T_6dfdd_row2_col4" class="data row2 col4" >0.921</td>
#       <td id="T_6dfdd_row2_col5" class="data row2 col5" >0.921</td>
#     </tr>
#     <tr>
#       <th id="T_6dfdd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6dfdd_row3_col0" class="data row3 col0" >10.000</td>
#       <td id="T_6dfdd_row3_col1" class="data row3 col1" >0.978</td>
#       <td id="T_6dfdd_row3_col2" class="data row3 col2" >0.895</td>
#       <td id="T_6dfdd_row3_col3" class="data row3 col3" >0.895</td>
#       <td id="T_6dfdd_row3_col4" class="data row3 col4" >0.895</td>
#       <td id="T_6dfdd_row3_col5" class="data row3 col5" >0.895</td>
#     </tr>
#     <tr>
#       <th id="T_6dfdd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6dfdd_row4_col0" class="data row4 col0" >100.000</td>
#       <td id="T_6dfdd_row4_col1" class="data row4 col1" >0.991</td>
#       <td id="T_6dfdd_row4_col2" class="data row4 col2" >0.867</td>
#       <td id="T_6dfdd_row4_col3" class="data row4 col3" >0.867</td>
#       <td id="T_6dfdd_row4_col4" class="data row4 col4" >0.867</td>
#       <td id="T_6dfdd_row4_col5" class="data row4 col5" >0.867</td>
#     </tr>
#   </tbody>
# </table>
# LSA Results with Styled Heatmap:
# <style type="text/css">
# #T_8d583_row0_col0, #T_8d583_row1_col0, #T_8d583_row2_col0, #T_8d583_row3_col0, #T_8d583_row4_col0 {
#   background-color: none;
# }
# #T_8d583_row0_col1, #T_8d583_row0_col2, #T_8d583_row0_col3, #T_8d583_row0_col4, #T_8d583_row0_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_8d583_row1_col1 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_8d583_row1_col2, #T_8d583_row1_col5 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_8d583_row1_col3 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_8d583_row1_col4 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_8d583_row2_col1, #T_8d583_row4_col2, #T_8d583_row4_col3, #T_8d583_row4_col4, #T_8d583_row4_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8d583_row2_col2, #T_8d583_row2_col3, #T_8d583_row2_col4, #T_8d583_row2_col5 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_8d583_row3_col1, #T_8d583_row4_col1 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_8d583_row3_col2, #T_8d583_row3_col3, #T_8d583_row3_col4, #T_8d583_row3_col5 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8d583">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d583_level0_col0" class="col_heading level0 col0" >C</th>
#       <th id="T_8d583_level0_col1" class="col_heading level0 col1" >Train Accuracy</th>
#       <th id="T_8d583_level0_col2" class="col_heading level0 col2" >Test Accuracy</th>
#       <th id="T_8d583_level0_col3" class="col_heading level0 col3" >F1 Score</th>
#       <th id="T_8d583_level0_col4" class="col_heading level0 col4" >Precision</th>
#       <th id="T_8d583_level0_col5" class="col_heading level0 col5" >Recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d583_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8d583_row0_col0" class="data row0 col0" >0.010</td>
#       <td id="T_8d583_row0_col1" class="data row0 col1" >0.898</td>
#       <td id="T_8d583_row0_col2" class="data row0 col2" >0.899</td>
#       <td id="T_8d583_row0_col3" class="data row0 col3" >0.899</td>
#       <td id="T_8d583_row0_col4" class="data row0 col4" >0.900</td>
#       <td id="T_8d583_row0_col5" class="data row0 col5" >0.899</td>
#     </tr>
#     <tr>
#       <th id="T_8d583_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8d583_row1_col0" class="data row1 col0" >0.100</td>
#       <td id="T_8d583_row1_col1" class="data row1 col1" >0.909</td>
#       <td id="T_8d583_row1_col2" class="data row1 col2" >0.909</td>
#       <td id="T_8d583_row1_col3" class="data row1 col3" >0.909</td>
#       <td id="T_8d583_row1_col4" class="data row1 col4" >0.909</td>
#       <td id="T_8d583_row1_col5" class="data row1 col5" >0.909</td>
#     </tr>
#     <tr>
#       <th id="T_8d583_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8d583_row2_col0" class="data row2 col0" >1.000</td>
#       <td id="T_8d583_row2_col1" class="data row2 col1" >0.912</td>
#       <td id="T_8d583_row2_col2" class="data row2 col2" >0.909</td>
#       <td id="T_8d583_row2_col3" class="data row2 col3" >0.909</td>
#       <td id="T_8d583_row2_col4" class="data row2 col4" >0.909</td>
#       <td id="T_8d583_row2_col5" class="data row2 col5" >0.909</td>
#     </tr>
#     <tr>
#       <th id="T_8d583_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8d583_row3_col0" class="data row3 col0" >10.000</td>
#       <td id="T_8d583_row3_col1" class="data row3 col1" >0.912</td>
#       <td id="T_8d583_row3_col2" class="data row3 col2" >0.910</td>
#       <td id="T_8d583_row3_col3" class="data row3 col3" >0.910</td>
#       <td id="T_8d583_row3_col4" class="data row3 col4" >0.910</td>
#       <td id="T_8d583_row3_col5" class="data row3 col5" >0.910</td>
#     </tr>
#     <tr>
#       <th id="T_8d583_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8d583_row4_col0" class="data row4 col0" >100.000</td>
#       <td id="T_8d583_row4_col1" class="data row4 col1" >0.912</td>
#       <td id="T_8d583_row4_col2" class="data row4 col2" >0.910</td>
#       <td id="T_8d583_row4_col3" class="data row4 col3" >0.910</td>
#       <td id="T_8d583_row4_col4" class="data row4 col4" >0.910</td>
#       <td id="T_8d583_row4_col5" class="data row4 col5" >0.910</td>
#     </tr>
#   </tbody>
# </table>

# %%
from sklearn.svm import LinearSVC, SVC

vis_model = LinearSVC(C=0.1, random_state=42, max_iter=10000)
vis_model.fit(X_train_tfidf, y_train)

feature_names_tfidf = tfidf.get_feature_names_out()

k = 70

coefficients_tfidf = vis_model.coef_[0]
top_k_tfidf_indices = np.argsort(np.abs(coefficients_tfidf))[-k:][::-1]
top_k_tfidf_terms = [(feature_names_tfidf[i], coefficients_tfidf[i]) for i in top_k_tfidf_indices]

print(f"Top {k} coefficients for TF-IDF model:")
for term, coef in top_k_tfidf_terms:
    print(f"{term}: {coef:.4f}")


# Extract the top-k terms based on absolute values of coefficients
top_k_tfidf_indices = np.argsort(np.abs(coefficients_tfidf))[-k:][::-1]
top_k_tfidf_terms = [(feature_names_tfidf[i], coefficients_tfidf[i]) for i in top_k_tfidf_indices]

# Prepare data for the bar chart
terms, coefs = zip(*top_k_tfidf_terms)
colors = ['lightcoral' if coef < 0 else 'lightblue' for coef in coefs]

# Plot the bar chart
plt.figure(figsize=(12, 4))
plt.bar(terms, coefs, color=colors)
plt.axhline(0, color='black', linewidth=0.8, linestyle='--')
plt.xticks(rotation=75, ha='right')
plt.title(f"Top {k} Coefficients for SVM Model (TF-IDF)")
plt.xlabel("Tokens")
plt.ylabel("Coefficient Value")
plt.grid(axis='x', linestyle='--', linewidth=0.5, alpha=0.7)  # Adding gridlines
plt.tight_layout()
plt.show()
# Out:
# Top 70 coefficients for TF-IDF model:
# redflag: 2.8847
# kill: 2.6053
# suicidal: 2.0760
# life: 1.8902
# die: 1.8429
# film: -1.8267
# cannot: 1.5544
# movie: -1.5542
# depression: 1.4645
# anymore: 1.4525
# killing: 1.4092
# pill: 1.3187
# feel: 1.3019
# want: 1.2188
# depressed: 1.2129
# end: 1.1686
# alive: 1.1663
# crush: -1.1315
# living: 1.1034
# tried: 1.0716
# job: 1.0556
# alone: 1.0519
# que: 1.0239
# yall: -1.0024
# worse: 0.9874
# tired: 0.9604
# live: 0.9472
# kinda: -0.9313
# family: 0.9272
# pain: 0.9203
# hospital: 0.9179
# rope: 0.9111
# point: 0.8988
# nothing: 0.8872
# thought: 0.8838
# death: 0.8794
# done: 0.8766
# suicide: 0.8675
# jump: 0.8612
# character: -0.8581
# gun: 0.8482
# ending: 0.8441
# guy: -0.8420
# fun: -0.8326
# everything: 0.8251
# cant: 0.8229
# covid: -0.8164
# hang: 0.8134
# like: -0.8017
# school: -0.8012
# therapy: 0.8001
# bruh: -0.7996
# goodbye: 0.7821
# teenager: -0.7802
# tonight: 0.7741
# world: 0.7736
# gone: 0.7614
# dead: 0.7537
# minecraft: -0.7461
# work: 0.7442
# cut: 0.7415
# way: 0.7412
# enough: 0.7355
# self: 0.7355
# last: 0.7282
# lol: -0.7276
# tho: -0.7210
# care: 0.7173
# sure: 0.7158
# miserable: 0.7131

# %%
import time
import numpy as np
import pandas as pd
from sklearn.svm import LinearSVC, SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Define the range of C values to test
C_values = [0.01, 0.1, 1, 10, 100]

# Define the range of gamma values to test
gamma_values = [0.001, 0.01, 0.1, 1, 10]

def evaluate_rbf_svc(X_train, X_test, y_train, y_test, dataset_name):
    # Prepare a table to store results
    metrics_table = []

    for C in C_values:
        for gamma in gamma_values:
            # Initialize the model with the current C and gamma values
            model = SVC(C=C, kernel='rbf', gamma=gamma, random_state=42)

            # Fit the model and record training time
            start_fit = time.time()
            model.fit(X_train, y_train)
            fit_time = time.time() - start_fit

            # Record testing time for predictions
            start_test = time.time()
            y_pred_train = model.predict(X_train)
            y_pred_test = model.predict(X_test)
            test_time = time.time() - start_test

            # Compute metrics
            train_accuracy = accuracy_score(y_train, y_pred_train)
            test_accuracy = accuracy_score(y_test, y_pred_test)
            precision = precision_score(y_test, y_pred_test, average='weighted')
            recall = recall_score(y_test, y_pred_test, average='weighted')
            f1 = f1_score(y_test, y_pred_test, average='weighted')

            # Compute confusion matrix
            conf_matrix = confusion_matrix(y_test, y_pred_test)

            print(f"Confusion Matrix for {dataset_name} (C={C}, gamma={gamma}):")
            print(conf_matrix)

            # Append metrics to the table
            metrics_table.append([C, gamma, train_accuracy, test_accuracy, f1, precision, recall, fit_time, test_time])

    # Create a dataframe for the metrics
    columns = ["C", "Gamma", "Train Accuracy", "Test Accuracy", "F1", "Precision", "Recall", "Fit Time", "Test Time"]
    metrics_df = pd.DataFrame(metrics_table, columns=columns)

    # Display the table
    print(f"\nMetrics for {dataset_name}:")
    print(metrics_df.to_string(index=False))

    return metrics_df

# Evaluate RBF SVC on LSA dataset
metrics = evaluate_rbf_svc(X_train_lsa, X_test_lsa, y_train, y_test, "LSA")
# Out:
# Confusion Matrix for LSA (C=0.01, gamma=0.001):
# [[   0 2099]
#  [   0 2549]]
# Confusion Matrix for LSA (C=0.01, gamma=0.01):
# [[   0 2099]
#  [   0 2549]]
# Confusion Matrix for LSA (C=0.01, gamma=0.1):
# [[   1 2098]
#  [   0 2549]]
# Confusion Matrix for LSA (C=0.01, gamma=1):
# [[1877  222]
#  [ 305 2244]]
# Confusion Matrix for LSA (C=0.01, gamma=10):
# [[1113  986]
#  [ 129 2420]]
# Confusion Matrix for LSA (C=0.1, gamma=0.001):
# [[   0 2099]
#  [   0 2549]]
# Confusion Matrix for LSA (C=0.1, gamma=0.01):
# [[   6 2093]
#  [   0 2549]]
# Confusion Matrix for LSA (C=0.1, gamma=0.1):
# [[1913  186]
#  [ 327 2222]]
# Confusion Matrix for LSA (C=0.1, gamma=1):
# [[1894  205]
#  [ 235 2314]]
# Confusion Matrix for LSA (C=0.1, gamma=10):
# [[1587  512]
#  [ 150 2399]]
# Confusion Matrix for LSA (C=1, gamma=0.001):
# [[   7 2092]
#  [   0 2549]]
# Confusion Matrix for LSA (C=1, gamma=0.01):
# [[1913  186]
#  [ 329 2220]]
# Confusion Matrix for LSA (C=1, gamma=0.1):
# [[1901  198]
#  [ 242 2307]]
# Confusion Matrix for LSA (C=1, gamma=1):
# [[1902  197]
#  [ 201 2348]]
# Confusion Matrix for LSA (C=1, gamma=10):
# [[1833  266]
#  [ 162 2387]]
# Confusion Matrix for LSA (C=10, gamma=0.001):
# [[1913  186]
#  [ 328 2221]]
# Confusion Matrix for LSA (C=10, gamma=0.01):
# [[1902  197]
#  [ 242 2307]]
# Confusion Matrix for LSA (C=10, gamma=0.1):
# [[1901  198]
#  [ 216 2333]]
# Confusion Matrix for LSA (C=10, gamma=1):
# [[1898  201]
#  [ 202 2347]]
# Confusion Matrix for LSA (C=10, gamma=10):
# [[1832  267]
#  [ 165 2384]]
# Confusion Matrix for LSA (C=100, gamma=0.001):
# [[1901  198]
#  [ 242 2307]]
# Confusion Matrix for LSA (C=100, gamma=0.01):
# [[1899  200]
#  [ 221 2328]]
# Confusion Matrix for LSA (C=100, gamma=0.1):
# [[1908  191]
#  [ 198 2351]]
# Confusion Matrix for LSA (C=100, gamma=1):
# [[1855  244]
#  [ 231 2318]]
# Confusion Matrix for LSA (C=100, gamma=10):
# [[1824  275]
#  [ 169 2380]]
#
# Metrics for LSA:
#      C  Gamma  Train Accuracy  Test Accuracy       F1  Precision   Recall  Fit Time  Test Time
#   0.01  0.001        0.543191       0.548408 0.388465   0.300751 0.548408 44.557353  67.693552
#   0.01  0.010        0.543191       0.548408 0.388465   0.300751 0.548408 48.074983  69.863225
#   0.01  0.100        0.543890       0.548623 0.388949   0.752408 0.548623 44.065198  66.870051
#   0.01  1.000        0.880648       0.886618 0.886779   0.887506 0.886618 32.586492  50.641204
#   0.01 10.000        0.753066       0.760112 0.746606   0.794337 0.760112 38.606059  56.068889
#   0.10  0.001        0.543191       0.548408 0.388465   0.300751 0.548408 47.166431  65.793084
#   0.10  0.010        0.546256       0.549699 0.391364   0.752732 0.549699 42.856556  65.930178
#   0.10  0.100        0.886618       0.889630 0.889854   0.891715 0.889630 27.326112  44.638572
#   0.10  1.000        0.907864       0.905336 0.905391   0.905523 0.905336 18.946836  25.382989
#   0.10 10.000        0.872149       0.857573 0.855574   0.864546 0.857573 23.647385  35.503794
#   1.00  0.001        0.546364       0.549914 0.391845   0.752797 0.549914 39.100968  62.059803
#   1.00  0.010        0.886672       0.889200 0.889426   0.891336 0.889200 27.780123  45.922446
#   1.00  0.100        0.907164       0.905336 0.905415   0.905656 0.905336 16.566790  24.729877
#   1.00  1.000        0.921633       0.914372 0.914379   0.914387 0.914372 12.745685  17.624619
#   1.00 10.000        0.981228       0.907917 0.907668   0.908344 0.907917 59.106802  32.923438
#  10.00  0.001        0.886725       0.889415 0.889640   0.891526 0.889415 27.193861  42.170656
#  10.00  0.010        0.907487       0.905551 0.905631   0.905882 0.905551 16.138999  23.559327
#  10.00  0.100        0.913511       0.910929 0.910962   0.911022 0.910929 12.151776  16.653279
#  10.00  1.000        0.950247       0.913296 0.913298   0.913300 0.913296 14.041231  16.285201
#  10.00 10.000        0.999086       0.907057 0.906811   0.907454 0.907057 69.081972  34.842927
# 100.00  0.001        0.907380       0.905336 0.905415   0.905656 0.905336 15.897183  23.254864
# 100.00  0.010        0.912113       0.909423 0.909462   0.909537 0.909423 12.088844  16.592379
# 100.00  0.100        0.922386       0.916308 0.916320   0.916337 0.916308 13.789850  15.230556
# 100.00  1.000        0.985747       0.897806 0.897777   0.897762 0.897806 38.366232  17.364415
# 100.00 10.000        0.999623       0.904475 0.904211   0.904903 0.904475 71.878896  34.178265

# %%
# Define desired column order
ordered_columns = [
    "C", "Gamma", "Train Accuracy", "Test Accuracy", "F1", "Precision", "Recall", "Fit Time", "Test Time"
]

# Rename columns
lsa_results = metrics[ordered_columns].rename(columns={
    "F1": "F1 Score",
    "Fit Time": "Fit Time (s)",
    "Test Time": "Test Time (s)"
})

# Styling function for heatmap
def style_heatmap(df, cmap_yellow, cmap_red, cmap_blue):
    return (
        df.style
        # Yellow gradient for 'C' and 'Gamma'
        .background_gradient(cmap=cmap_yellow, subset=["C", "Gamma"])
        # Blue gradient for accuracy, F1 Score, Precision, Recall
        .background_gradient(cmap=cmap_blue, subset=["Train Accuracy", "Test Accuracy", "F1 Score", "Precision", "Recall"])
        # Red gradient for time metrics
        .background_gradient(cmap=cmap_red, subset=["Fit Time (s)", "Test Time (s)"])
        # Precision formatting
        .format(precision=3)
    )

# Apply styling
lsa_table_styled = style_heatmap(lsa_results, cmap_yellow="YlOrBr", cmap_red="Reds", cmap_blue="Blues")

# Display the results
print("\nLSA Results with Styled Heatmap:")
display(lsa_table_styled)
# Out:
# LSA Results with Styled Heatmap:
# <style type="text/css">
# #T_34ea5_row0_col0, #T_34ea5_row0_col1, #T_34ea5_row1_col0, #T_34ea5_row1_col1, #T_34ea5_row2_col0, #T_34ea5_row3_col0, #T_34ea5_row4_col0, #T_34ea5_row5_col0, #T_34ea5_row5_col1, #T_34ea5_row6_col0, #T_34ea5_row6_col1, #T_34ea5_row7_col0, #T_34ea5_row8_col0, #T_34ea5_row9_col0, #T_34ea5_row10_col1, #T_34ea5_row11_col1, #T_34ea5_row15_col1, #T_34ea5_row16_col1, #T_34ea5_row20_col1, #T_34ea5_row21_col1 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_34ea5_row0_col2, #T_34ea5_row0_col3, #T_34ea5_row0_col4, #T_34ea5_row0_col5, #T_34ea5_row0_col6, #T_34ea5_row1_col2, #T_34ea5_row1_col3, #T_34ea5_row1_col4, #T_34ea5_row1_col5, #T_34ea5_row1_col6, #T_34ea5_row2_col2, #T_34ea5_row2_col3, #T_34ea5_row2_col4, #T_34ea5_row2_col6, #T_34ea5_row5_col2, #T_34ea5_row5_col3, #T_34ea5_row5_col4, #T_34ea5_row5_col5, #T_34ea5_row5_col6, #T_34ea5_row6_col3, #T_34ea5_row6_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_34ea5_row0_col7 {
#   background-color: #f7593f;
#   color: #f1f1f1;
# }
# #T_34ea5_row0_col8 {
#   background-color: #7a0510;
#   color: #f1f1f1;
# }
# #T_34ea5_row1_col7 {
#   background-color: #f14331;
#   color: #f1f1f1;
# }
# #T_34ea5_row1_col8, #T_34ea5_row24_col7 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_34ea5_row2_col1, #T_34ea5_row7_col1, #T_34ea5_row10_col0, #T_34ea5_row11_col0, #T_34ea5_row12_col0, #T_34ea5_row12_col1, #T_34ea5_row13_col0, #T_34ea5_row14_col0, #T_34ea5_row17_col1, #T_34ea5_row22_col1 {
#   background-color: #fffee2;
#   color: #000000;
# }
# #T_34ea5_row2_col5, #T_34ea5_row6_col5, #T_34ea5_row10_col5 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_34ea5_row2_col7 {
#   background-color: #f85d42;
#   color: #f1f1f1;
# }
# #T_34ea5_row2_col8 {
#   background-color: #820711;
#   color: #f1f1f1;
# }
# #T_34ea5_row3_col1, #T_34ea5_row8_col1, #T_34ea5_row13_col1, #T_34ea5_row15_col0, #T_34ea5_row16_col0, #T_34ea5_row17_col0, #T_34ea5_row18_col0, #T_34ea5_row18_col1, #T_34ea5_row19_col0, #T_34ea5_row23_col1 {
#   background-color: #fff9c5;
#   color: #000000;
# }
# #T_34ea5_row3_col2 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_34ea5_row3_col3, #T_34ea5_row3_col6 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_34ea5_row3_col4 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_34ea5_row3_col5 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_34ea5_row3_col7 {
#   background-color: #fc9d7f;
#   color: #000000;
# }
# #T_34ea5_row3_col8 {
#   background-color: #e93529;
#   color: #f1f1f1;
# }
# #T_34ea5_row4_col1, #T_34ea5_row9_col1, #T_34ea5_row14_col1, #T_34ea5_row19_col1, #T_34ea5_row20_col0, #T_34ea5_row21_col0, #T_34ea5_row22_col0, #T_34ea5_row23_col0, #T_34ea5_row24_col0, #T_34ea5_row24_col1 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_34ea5_row4_col2 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_34ea5_row4_col3, #T_34ea5_row4_col6 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_34ea5_row4_col4 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_34ea5_row4_col5 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_34ea5_row4_col7 {
#   background-color: #fb7c5c;
#   color: #f1f1f1;
# }
# #T_34ea5_row4_col8 {
#   background-color: #cb181d;
#   color: #f1f1f1;
# }
# #T_34ea5_row5_col7 {
#   background-color: #f34935;
#   color: #f1f1f1;
# }
# #T_34ea5_row5_col8 {
#   background-color: #8c0912;
#   color: #f1f1f1;
# }
# #T_34ea5_row6_col2, #T_34ea5_row6_col4, #T_34ea5_row10_col2, #T_34ea5_row10_col3, #T_34ea5_row10_col4, #T_34ea5_row10_col6 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_34ea5_row6_col7 {
#   background-color: #fa6547;
#   color: #f1f1f1;
# }
# #T_34ea5_row6_col8 {
#   background-color: #8a0812;
#   color: #f1f1f1;
# }
# #T_34ea5_row7_col2, #T_34ea5_row11_col2, #T_34ea5_row15_col2 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_34ea5_row7_col3, #T_34ea5_row7_col6, #T_34ea5_row11_col3, #T_34ea5_row11_col6, #T_34ea5_row15_col3, #T_34ea5_row15_col6 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_34ea5_row7_col4, #T_34ea5_row15_col4, #T_34ea5_row23_col3, #T_34ea5_row23_col6 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_34ea5_row7_col5, #T_34ea5_row11_col5, #T_34ea5_row14_col2, #T_34ea5_row15_col5 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_34ea5_row7_col7 {
#   background-color: #fcb99f;
#   color: #000000;
# }
# #T_34ea5_row7_col8 {
#   background-color: #f75c41;
#   color: #f1f1f1;
# }
# #T_34ea5_row8_col2, #T_34ea5_row12_col2, #T_34ea5_row16_col2, #T_34ea5_row20_col2 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_34ea5_row8_col3, #T_34ea5_row8_col6, #T_34ea5_row12_col3, #T_34ea5_row12_col6, #T_34ea5_row16_col3, #T_34ea5_row16_col6, #T_34ea5_row20_col3, #T_34ea5_row20_col6, #T_34ea5_row23_col2, #T_34ea5_row23_col5 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_34ea5_row8_col4, #T_34ea5_row12_col4, #T_34ea5_row14_col3, #T_34ea5_row14_col6, #T_34ea5_row16_col4, #T_34ea5_row20_col4, #T_34ea5_row24_col4 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_34ea5_row8_col5, #T_34ea5_row12_col5, #T_34ea5_row14_col4, #T_34ea5_row16_col5, #T_34ea5_row19_col4, #T_34ea5_row20_col5, #T_34ea5_row21_col3, #T_34ea5_row21_col6, #T_34ea5_row24_col5 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_34ea5_row8_col7 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_34ea5_row8_col8 {
#   background-color: #fdcebb;
#   color: #000000;
# }
# #T_34ea5_row9_col2 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_34ea5_row9_col3, #T_34ea5_row9_col6 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_34ea5_row9_col4 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_34ea5_row9_col5 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_34ea5_row9_col7 {
#   background-color: #fdccb8;
#   color: #000000;
# }
# #T_34ea5_row9_col8 {
#   background-color: #fc9474;
#   color: #000000;
# }
# #T_34ea5_row10_col7 {
#   background-color: #fb7a5a;
#   color: #f1f1f1;
# }
# #T_34ea5_row10_col8 {
#   background-color: #aa1016;
#   color: #f1f1f1;
# }
# #T_34ea5_row11_col4 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_34ea5_row11_col7 {
#   background-color: #fcb79c;
#   color: #000000;
# }
# #T_34ea5_row11_col8 {
#   background-color: #f5533b;
#   color: #f1f1f1;
# }
# #T_34ea5_row12_col7 {
#   background-color: #fee8de;
#   color: #000000;
# }
# #T_34ea5_row12_col8 {
#   background-color: #fdd2bf;
#   color: #000000;
# }
# #T_34ea5_row13_col2, #T_34ea5_row22_col2 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_34ea5_row13_col3, #T_34ea5_row13_col6, #T_34ea5_row18_col4, #T_34ea5_row18_col5 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_34ea5_row13_col4, #T_34ea5_row13_col5, #T_34ea5_row19_col2, #T_34ea5_row22_col3, #T_34ea5_row22_col4, #T_34ea5_row22_col5, #T_34ea5_row22_col6, #T_34ea5_row24_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_34ea5_row13_col7 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_34ea5_row13_col8 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_34ea5_row14_col5, #T_34ea5_row17_col3, #T_34ea5_row17_col6, #T_34ea5_row19_col5, #T_34ea5_row21_col4 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_34ea5_row14_col7 {
#   background-color: #bf151b;
#   color: #f1f1f1;
# }
# #T_34ea5_row14_col8 {
#   background-color: #fca486;
#   color: #000000;
# }
# #T_34ea5_row15_col7 {
#   background-color: #fcbba1;
#   color: #000000;
# }
# #T_34ea5_row15_col8 {
#   background-color: #fb6c4c;
#   color: #f1f1f1;
# }
# #T_34ea5_row16_col7 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_34ea5_row16_col8 {
#   background-color: #fed8c7;
#   color: #000000;
# }
# #T_34ea5_row17_col2 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_34ea5_row17_col4, #T_34ea5_row17_col5, #T_34ea5_row18_col3, #T_34ea5_row18_col6, #T_34ea5_row21_col5 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_34ea5_row17_col7, #T_34ea5_row21_col7, #T_34ea5_row22_col8 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_34ea5_row17_col8, #T_34ea5_row21_col8 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_34ea5_row18_col2 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_34ea5_row18_col7 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_34ea5_row18_col8 {
#   background-color: #fff2ec;
#   col
