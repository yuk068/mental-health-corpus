# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns
import time

import warnings
warnings.filterwarnings('ignore')

original_corpus = pd.read_csv('data/mental_health.csv')
cleaned_corpus = pd.read_csv('data/cleaned_mhc.csv')

print("Shape of Original Corpus", original_corpus.shape)
print("Shape of Cleaned Corpus", cleaned_corpus.shape)
# Out:
# Shape of Original Corpus (27977, 2)
# Shape of Cleaned Corpus (23240, 2)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import time

k_values = [1, 5, 11, 51, 101, 201, 301, 501, 1001, 2001, 5001, 8001]
vectorizer = TfidfVectorizer(max_features=3500)

metrics_original_euclidean = {"K": [], "Training Accuracy": [], "Test Accuracy": [], "Precision": [], "Recall": [], "F1": [], "Test Time (s)": []}
metrics_cleaned_euclidean = {"K": [], "Training Accuracy": [], "Test Accuracy": [], "Precision": [], "Recall": [], "F1": [], "Test Time (s)": []}
metrics_original_cosine = {"K": [], "Training Accuracy": [], "Test Accuracy": [], "Precision": [], "Recall": [], "F1": [], "Test Time (s)": []}
metrics_cleaned_cosine = {"K": [], "Training Accuracy": [], "Test Accuracy": [], "Precision": [], "Recall": [], "F1": [], "Test Time (s)": []}

def run_knn(corpus, target, metrics_dict, dataset_name, metric='euclidean'):
    best_f1 = 0
    best_conf_matrix = None
    best_k = None
    best_test_time = None

    for k in k_values:
        X_train, X_test, y_train, y_test = train_test_split(corpus, target, test_size=0.2, random_state=42)
        vectorizer = TfidfVectorizer(max_features=3500)
        
        X_train_tfidf = vectorizer.fit_transform(X_train)
        X_test_tfidf = vectorizer.transform(X_test)
       
        knn = KNeighborsClassifier(n_neighbors=k, metric=metric)

        knn.fit(X_train_tfidf, y_train)
        
        start_test = time.perf_counter()
        y_test_pred = knn.predict(X_test_tfidf)
        test_time = time.perf_counter() - start_test
        
        y_train_pred = knn.predict(X_train_tfidf)
        
        train_acc = accuracy_score(y_train, y_train_pred)
        test_acc = accuracy_score(y_test, y_test_pred)
        prec = precision_score(y_test, y_test_pred)
        rec = recall_score(y_test, y_test_pred)
        f1 = f1_score(y_test, y_test_pred)
        
        metrics_dict["K"].append(k)
        metrics_dict["Training Accuracy"].append(train_acc)
        metrics_dict["Test Accuracy"].append(test_acc)
        metrics_dict["Precision"].append(prec)
        metrics_dict["Recall"].append(rec)
        metrics_dict["F1"].append(f1)
        metrics_dict["Test Time (s)"].append(test_time)

        if f1 > best_f1:
            best_f1 = f1
            best_conf_matrix = confusion_matrix(y_test, y_test_pred)
            best_k = k
            best_test_time = test_time
        print(f"Finished for {dataset_name} with k = {k}")
    

    print(f"Best F1 Score for {dataset_name} Corpus (k={best_k}, metric={metric}): {best_f1:.4f}, "
          f"Test time: {best_test_time:.4f} s")
    print("Confusion Matrix:\n", best_conf_matrix)

run_knn(original_corpus['text'], original_corpus['label'], metrics_original_euclidean, "Original", metric='euclidean')
run_knn(cleaned_corpus['text'], cleaned_corpus['label'], metrics_cleaned_euclidean, "Cleaned", metric='euclidean')
run_knn(original_corpus['text'], original_corpus['label'], metrics_original_cosine, "Original", metric='cosine')
run_knn(cleaned_corpus['text'], cleaned_corpus['label'], metrics_cleaned_cosine, "Cleaned", metric='cosine')

df_original_euclidean = pd.DataFrame(metrics_original_euclidean)
df_cleaned_euclidean = pd.DataFrame(metrics_cleaned_euclidean)
df_original_cosine = pd.DataFrame(metrics_original_cosine)
df_cleaned_cosine = pd.DataFrame(metrics_cleaned_cosine)

print("\nMetrics for Original Corpus with Euclidean Distance:\n", df_original_euclidean)
print("\nMetrics for Cleaned Corpus with Euclidean Distance:\n", df_cleaned_euclidean)
print("\nMetrics for Original Corpus with Cosine Distance:\n", df_original_cosine)
print("\nMetrics for Cleaned Corpus with Cosine Distance:\n", df_cleaned_cosine)
# Out:
# Finished for Original with k = 1
# Finished for Original with k = 5
# Finished for Original with k = 11
# Finished for Original with k = 51
# Finished for Original with k = 101
# Finished for Original with k = 201
# Finished for Original with k = 301
# Finished for Original with k = 501
# Finished for Original with k = 1001
# Finished for Original with k = 2001
# Finished for Original with k = 5001
# Finished for Original with k = 8001
# Best F1 Score for Original Corpus (k=201, metric=euclidean): 0.8837, Test time: 3.9008 s
# Confusion Matrix:
#  [[2275  527]
#  [ 165 2629]]
# Finished for Cleaned with k = 1
# Finished for Cleaned with k = 5
# Finished for Cleaned with k = 11
# Finished for Cleaned with k = 51
# Finished for Cleaned with k = 101
# Finished for Cleaned with k = 201
# Finished for Cleaned with k = 301
# Finished for Cleaned with k = 501
# Finished for Cleaned with k = 1001
# Finished for Cleaned with k = 2001
# Finished for Cleaned with k = 5001
# Finished for Cleaned with k = 8001
# Best F1 Score for Cleaned Corpus (k=51, metric=euclidean): 0.9017, Test time: 3.0043 s
# Confusion Matrix:
#  [[1692  407]
#  [ 122 2427]]
# Finished for Original with k = 1
# Finished for Original with k = 5
# Finished for Original with k = 11
# Finished for Original with k = 51
# Finished for Original with k = 101
# Finished for Original with k = 201
# Finished for Original with k = 301
# Finished for Original with k = 501
# Finished for Original with k = 1001
# Finished for Original with k = 2001
# Finished for Original with k = 5001
# Finished for Original with k = 8001
# Best F1 Score for Original Corpus (k=51, metric=cosine): 0.8859, Test time: 3.5361 s
# Confusion Matrix:
#  [[2365  437]
#  [ 225 2569]]
# Finished for Cleaned with k = 1
# Finished for Cleaned with k = 5
# Finished for Cleaned with k = 11
# Finished for Cleaned with k = 51
# Finished for Cleaned with k = 101
# Finished for Cleaned with k = 201
# Finished for Cleaned with k = 301
# Finished for Cleaned with k = 501
# Finished for Cleaned with k = 1001
# Finished for Cleaned with k = 2001
# Finished for Cleaned with k = 5001
# Finished for Cleaned with k = 8001
# Best F1 Score for Cleaned Corpus (k=51, metric=cosine): 0.8981, Test time: 2.8621 s
# Confusion Matrix:
#  [[1641  458]
#  [  98 2451]]
#
# Metrics for Original Corpus with Euclidean Distance:
#         K  Training Accuracy  Test Accuracy  Precision    Recall        F1  \
# 0      1           0.999196       0.510543   0.642487  0.044381  0.083026
# 6        3.704157
# 7        3.767037
# 8        3.993479
# 9        4.366533
# 10       5.527356
# 11       6.803846
#
# Metrics for Cleaned Corpus with Cosine Distance:
#         K  Training Accuracy  Test Accuracy  Precision    Recall        F1  \
# 0      1           1.000000       0.800559   0.850475  0.772067  0.809377
# 1      5           0.900602       0.868546   0.882399  0.877207  0.879795
# 2     11           0.896353       0.880594   0.877938  0.908592  0.893002
# 3     51           0.880970       0.880379   0.842558  0.961554  0.898131
# 4    101           0.863167       0.860585   0.808304  0.977638  0.884943
# 5    201           0.828582       0.830034   0.768059  0.988623  0.864494
# 6    301           0.801796       0.804432   0.740047  0.991761  0.847611
# 7    501           0.762478       0.766997   0.703047  0.995685  0.824160
# 8   1001           0.706433       0.708262   0.653066  0.998431  0.789637
# 9   2001           0.655766       0.659854   0.617248  0.999608  0.763217
# 10  5001           0.567179       0.572719   0.562073  1.000000  0.719650
# 11  8001           0.543352       0.548623   0.548526  1.000000  0.708449
#
#     Test Time (s)
# 0        2.325661
# 1        2.861756
# 2        2.861545
# 3        2.862139
# 4        2.886768
# 5        2.953287
# 6        2.941675
# 7        3.050775
# 8        3.170099
# 9        3.527853
# 10       4.672108
# 11       5.535333

# %%
metrics_to_plot = ["Training Accuracy", "Test Accuracy", "Precision", "Recall", "F1", "Test Time (s)"]

df_original_euclidean["Metric"] = "Euclidean"
df_original_cosine["Metric"] = "Cosine"
df_original_combined = pd.concat([df_original_euclidean, df_original_cosine])

df_cleaned_euclidean["Metric"] = "Euclidean"
df_cleaned_cosine["Metric"] = "Cosine"
df_cleaned_combined = pd.concat([df_cleaned_euclidean, df_cleaned_cosine])

fig, axes = plt.subplots(len(metrics_to_plot), 2, figsize=(16, 36), sharey=True)
fig.suptitle("KNN Metrics for Original and Cleaned Corpora (Blue L2 | Orange Cosine)", fontsize=16)

for i, metric in enumerate(metrics_to_plot):
    sns.barplot(ax=axes[i, 0], y="K", x=metric, hue="Metric", data=df_original_combined, orient='h', 
                palette={"Euclidean": "royalblue", "Cosine": "orange"})
    axes[i, 0].set_title(f"Original Corpus - {metric}")
    axes[i, 0].get_legend().remove()

    sns.barplot(ax=axes[i, 1], y="K", x=metric, hue="Metric", data=df_cleaned_combined, orient='h', 
                palette={"Euclidean": "royalblue", "Cosine": "orange"})
    axes[i, 1].set_title(f"Cleaned Corpus - {metric}")
    axes[i, 1].get_legend().remove()

handles, labels = axes[0, 0].get_legend_handles_labels()
fig.legend(handles, labels, loc="upper right", title="Metric")

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.savefig('plots/knn_results.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
metrics_to_display = ["Training Accuracy", "Test Accuracy", "Precision", "Recall", "F1", "Test Time (s)"]

original_data = {}
for metric in metrics_to_display:
    if metric == "K":
        original_data[("K", "")] = df_original_euclidean["K"]
    else:
        original_data[(metric, "Euclidean")] = df_original_euclidean[metric].round(3)
        original_data[(metric, "Cosine")] = df_original_cosine[metric].round(3)

cleaned_data = {}
for metric in metrics_to_display:
    if metric == "K":
        cleaned_data[("K", "")] = df_cleaned_euclidean["K"]
    else:
        cleaned_data[(metric, "Euclidean")] = df_cleaned_euclidean[metric].round(3)
        cleaned_data[(metric, "Cosine")] = df_cleaned_cosine[metric].round(3)

df_original_combined = pd.DataFrame(original_data)
df_cleaned_combined = pd.DataFrame(cleaned_data)

def apply_dual_heatmap_combined(table):
    styled_table = table.style
    
    styled_table = styled_table.format("{:.3f}", subset=[(col, subtype) for col, subtype in table.columns 
                                                        if col != "K" and subtype != ""])
    
    for metric in metrics_to_display:
        if metric != "K":
            styled_table = styled_table.background_gradient(
                cmap="YlGnBu",
                subset=[(metric, "Euclidean")]
            )
            styled_table = styled_table.background_gradient(
                cmap="OrRd",
                subset=[(metric, "Cosine")]
            )
    
    styled_table = styled_table.set_properties(**{
        'border-collapse': 'collapse'
    })
    
    return styled_table

print("Metrics Table for Original Corpus (Combined Euclidean and Cosine):")
display(apply_dual_heatmap_combined(df_original_combined))

print("\nMetrics Table for Cleaned Corpus (Combined Euclidean and Cosine):")
display(apply_dual_heatmap_combined(df_cleaned_combined))
# Out:
# Metrics Table for Original Corpus (Combined Euclidean and Cosine):
# <style type="text/css">
# #T_0aade_row0_col0, #T_0aade_row4_col4, #T_0aade_row5_col2, #T_0aade_row5_col8, #T_0aade_row9_col6, #T_0aade_row10_col6, #T_0aade_row11_col6, #T_0aade_row11_col10 {
#   background-color: #081d58;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row0_col1, #T_0aade_row2_col5, #T_0aade_row3_col3, #T_0aade_row3_col9, #T_0aade_row10_col7, #T_0aade_row11_col7, #T_0aade_row11_col11 {
#   background-color: #7f0000;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row0_col2 {
#   background-color: #fbfdd0;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_0aade_row0_col3 {
#   background-color: #dc3a27;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row0_col4 {
#   background-color: #8ed3ba;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_0aade_row0_col5 {
#   background-color: #b90805;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row0_col6 {
#   background-color: #f9fdcc;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_0aade_row0_col7, #T_0aade_row0_col11, #T_0aade_row11_col1, #T_0aade_row11_col3, #T_0aade_row11_col5, #T_0aade_row11_col9 {
#   background-color: #fff7ec;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_0aade_row0_col8 {
#   background-color: #f3fabd;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_0aade_row0_col9 {
#   background-color: #fda671;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_0aade_row0_col10, #T_0aade_row3_col6, #T_0aade_row3_col8, #T_0aade_row11_col0, #T_0aade_row11_col2, #T_0aade_row11_col4 {
#   background-color: #ffffd9;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_0aade_row1_col0, #T_0aade_row1_col8 {
#   background-color: #90d4b9;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_0aade_row1_col1 {
#   background-color: #ca1e14;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row1_col2 {
#   background-color: #f8fcc9;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_0aade_row1_col3 {
#   background-color: #ad0000;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row1_col4 {
#   background-color: #edf8b1;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_0aade_row1_col5, #T_0aade_row4_col9, #T_0aade_row8_col7 {
#   background-color: #860000;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row1_col6 {
#   background-color: #d3eeb3;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_0aade_row1_col7 {
#   background-color: #fdca94;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_0aade_row1_col9 {
#   background-color: #d62f1e;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row1_col10 {
#   background-color: #e2f4b2;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_0aade_row1_col11 {
#   background-color: #fee3bd;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_0aade_row2_col0 {
#   background-color: #e0f3b2;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_0aade_row2_col1 {
#   background-color: #cd2316;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row2_col2, #T_0aade_row10_col4 {
#   background-color: #f9fdcb;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_0aade_row2_col3 {
#   background-color: #960000;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row2_col4 {
#   background-color: #cdebb4;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_0aade_row2_col6 {
#   background-color: #f0f9b8;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_0aade_row2_col7 {
#   background-color: #fca26d;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_0aade_row2_col8 {
#   background-color: #d7efb3;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_0aade_row2_col9 {
#   background-color: #b40201;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row2_col10, #T_0aade_row3_col10 {
#   background-color: #dff2b2;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_0aade_row2_col11 {
#   background-color: #fee4bf;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_0aade_row3_col0 {
#   background-color: #fcfed1;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_0aade_row3_col1 {
#   background-color: #cf2618;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row3_col2 {
#   background-color: #feffd8;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_0aade_row3_col4 {
#   background-color: #253494;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row3_col5 {
#   background-color: #970000;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row3_col7, #T_0aade_row7_col9 {
#   background-color: #dc3c28;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row3_col11 {
#   background-color: #fee5c3;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_0aade_row4_col0 {
#   background-color: #2258a5;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row4_col1 {
#   background-color: #d52d1d;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row4_col2, #T_0aade_row8_col6 {
#   background-color: #091e5a;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row4_col3 {
#   background-color: #870000;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row4_col5, #T_0aade_row6_col3 {
#   background-color: #b70503;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row4_col6 {
#   background-color: #24439b;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row4_col7 {
#   background-color: #c3150e;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row4_col8, #T_0aade_row7_col6 {
#   background-color: #0c2060;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row4_col10 {
#   background-color: #dbf1b2;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_0aade_row4_col11 {
#   background-color: #fee2bb;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_0aade_row5_col0 {
#   background-color: #2259a6;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row5_col1 {
#   background-color: #de3f2b;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row5_col3, #T_0aade_row5_col9 {
#   background-color: #9b0000;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row5_col4 {
#   background-color: #24489d;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row5_col5 {
#   background-color: #d12719;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row5_col6 {
#   background-color: #162874;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row5_col7 {
#   background-color: #a90000;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row5_col10, #T_0aade_row9_col4 {
#   background-color: #daf0b3;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_0aade_row5_col11 {
#   background-color: #fee2bc;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_0aade_row6_col0 {
#   background-color: #216bae;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row6_col1, #T_0aade_row10_col11 {
#   background-color: #e7533a;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row6_col2 {
#   background-color: #13266f;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row6_col4 {
#   background-color: #216aad;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row6_col5 {
#   background-color: #e55038;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row6_col6 {
#   background-color: #0f2367;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row6_col7 {
#   background-color: #9e0000;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row6_col8 {
#   background-color: #0b1f5e;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row6_col9 {
#   background-color: #bb0b07;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row6_col10 {
#   background-color: #d6efb3;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_0aade_row6_col11 {
#   background-color: #fddeb3;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_0aade_row7_col0 {
#   background-color: #1d90c0;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row7_col1 {
#   background-color: #f4734e;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_0aade_row7_col2, #T_0aade_row9_col8 {
#   background-color: #24449c;
#   color: #f1f1f1;
#   border-collapse: collapse;
# Metrics Table for Cleaned Corpus (Combined Euclidean and Cosine):
# <style type="text/css">
# #T_a5697_row0_col0, #T_a5697_row1_col4, #T_a5697_row3_col2, #T_a5697_row3_col8, #T_a5697_row8_col6, #T_a5697_row9_col6, #T_a5697_row10_col6, #T_a5697_row11_col6, #T_a5697_row11_col10 {
#   background-color: #081d58;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_a5697_row0_col1, #T_a5697_row1_col5, #T_a5697_row2_col3, #T_a5697_row3_col3, #T_a5697_row3_col9, #T_a5697_row9_col7, #T_a5697_row10_col7, #T_a5697_row11_col7, #T_a5697_row11_col11 {
#   background-color: #7f0000;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_a5697_row0_col2, #T_a5697_row0_col6, #T_a5697_row0_col8, #T_a5697_row0_col10, #T_a5697_row11_col0, #T_a5697_row11_col4 {
#   background-color: #ffffd9;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_a5697_row0_col3 {
#   background-color: #d42c1c;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_a5697_row0_col4 {
#   background-color: #42b6c4;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_a5697_row0_col5, #T_a5697_row1_col9, #T_a5697_row4_col7 {
#   background-color: #a60000;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_a5697_row0_col7, #T_a5697_row0_col11, #T_a5697_row11_col1, #T_a5697_row11_col3, #T_a5697_row11_col5, #T_a5697_row11_col9 {
#   background-color: #fff7ec;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_a5697_
;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_a5697_row7_col8 {
#   background-color: #1c2d81;
#   color: #f1f1f1;
#   border-co

# %%
from sklearn.decomposition import TruncatedSVD

k_values = [1, 5, 11, 51, 101, 201, 301, 501, 1001, 2001, 5001, 8001]
vectorizer = TfidfVectorizer(max_features=3500)

lsa_metrics_original_euclidean = {"K": [], "Training Accuracy": [], "Test Accuracy": [], "Precision": [], "Recall": [], "F1": [], "Test Time (s)": []}
lsa_metrics_cleaned_euclidean = {"K": [], "Training Accuracy": [], "Test Accuracy": [], "Precision": [], "Recall": [], "F1": [], "Test Time (s)": []}
lsa_metrics_original_cosine = {"K": [], "Training Accuracy": [], "Test Accuracy": [], "Precision": [], "Recall": [], "F1": [], "Test Time (s)": []}
lsa_metrics_cleaned_cosine = {"K": [], "Training Accuracy": [], "Test Accuracy": [], "Precision": [], "Recall": [], "F1": [], "Test Time (s)": []}

def run_knn_lsa(corpus, target, lsa_metrics_dict, dataset_name, metric='euclidean'):
    best_f1 = 0
    best_conf_matrix = None
    best_k = None
    best_test_time = None

    X_train, X_test, y_train, y_test = train_test_split(corpus, target, test_size=0.2, random_state=42)
    vectorizer = TfidfVectorizer(max_features=3500)

    n_components = 150
    lsa = TruncatedSVD(n_components=n_components, random_state=42)
        
    X_train_tfidf = vectorizer.fit_transform(X_train)
    X_train_lsa = lsa.fit_transform(X_train_tfidf)    
    X_test_tfidf = vectorizer.transform(X_test)
    X_test_lsa = lsa.transform(X_test_tfidf)
    
    for k in k_values:
        knn = KNeighborsClassifier(n_neighbors=k, metric=metric)

        knn.fit(X_train_lsa, y_train)
        
        start_test = time.perf_counter()
        y_test_pred = knn.predict(X_test_lsa)
        test_time = time.perf_counter() - start_test
        
        y_train_pred = knn.predict(X_train_lsa)
        
        train_acc = accuracy_score(y_train, y_train_pred)
        test_acc = accuracy_score(y_test, y_test_pred)
        prec = precision_score(y_test, y_test_pred)
        rec = recall_score(y_test, y_test_pred)
        f1 = f1_score(y_test, y_test_pred)
        
        lsa_metrics_dict["K"].append(k)
        lsa_metrics_dict["Training Accuracy"].append(train_acc)
        lsa_metrics_dict["Test Accuracy"].append(test_acc)
        lsa_metrics_dict["Precision"].append(prec)
        lsa_metrics_dict["Recall"].append(rec)
        lsa_metrics_dict["F1"].append(f1)
        lsa_metrics_dict["Test Time (s)"].append(test_time)

        print(f"Finished for {dataset_name} with k = {k}")

        if f1 > best_f1:
            best_f1 = f1
            best_conf_matrix = confusion_matrix(y_test, y_test_pred)
            best_k = k
            best_test_time = test_time

    print(f"Best F1 Score for {dataset_name} Corpus (k={best_k}, metric={metric}): {best_f1:.4f}, "
          f"Test time: {best_test_time:.4f} s")
    print("Confusion Matrix:\n", best_conf_matrix)

run_knn_lsa(original_corpus['text'], original_corpus['label'], lsa_metrics_original_euclidean, "Original", metric='euclidean')
run_knn_lsa(cleaned_corpus['text'], cleaned_corpus['label'], lsa_metrics_cleaned_euclidean, "Cleaned", metric='euclidean')
run_knn_lsa(original_corpus['text'], original_corpus['label'], lsa_metrics_original_cosine, "Original", metric='cosine')
run_knn_lsa(cleaned_corpus['text'], cleaned_corpus['label'], lsa_metrics_cleaned_cosine, "Cleaned", metric='cosine')

df_lsa_original_euclidean = pd.DataFrame(lsa_metrics_original_euclidean)
df_lsa_cleaned_euclidean = pd.DataFrame(lsa_metrics_cleaned_euclidean)
df_lsa_original_cosine = pd.DataFrame(lsa_metrics_original_cosine)
df_lsa_cleaned_cosine = pd.DataFrame(lsa_metrics_cleaned_cosine)

print("\nMetrics for Original Corpus with LSA (Euclidean Distance):\n", df_lsa_original_euclidean)
print("\nMetrics for Cleaned Corpus with LSA (Euclidean Distance):\n", df_lsa_cleaned_euclidean)
print("\nMetrics for Original Corpus with LSA (Cosine Distance):\n", df_lsa_original_cosine)
print("\nMetrics for Cleaned Corpus with LSA (Cosine Distance):\n", df_lsa_cleaned_cosine)
# Out:
# Finished for Original with k = 1
# Finished for Original with k = 5
# Finished for Original with k = 11
# Finished for Original with k = 51
# Finished for Original with k = 101
# Finished for Original with k = 201
# Finished for Original with k = 301
# Finished for Original with k = 501
# Finished for Original with k = 1001
# Finished for Original with k = 2001
# Finished for Original with k = 5001
# Finished for Original with k = 8001
# Best F1 Score for Original Corpus (k=1, metric=euclidean): 0.7006, Test time: 0.4565 s
# Confusion Matrix:
#  [[2523  279]
#  [1137 1657]]
# Finished for Cleaned with k = 1
# Finished for Cleaned with k = 5
# Finished for Cleaned with k = 11
# Finished for Cleaned with k = 51
# Finished for Cleaned with k = 101
# Finished for Cleaned with k = 201
# Finished for Cleaned with k = 301
# Finished for Cleaned with k = 501
# Finished for Cleaned with k = 1001
# Finished for Cleaned with k = 2001
# Finished for Cleaned with k = 5001
# Finished for Cleaned with k = 8001
# Best F1 Score for Cleaned Corpus (k=1, metric=euclidean): 0.7090, Test time: 0.2674 s
# Confusion Matrix:
#  [[1895  204]
#  [1037 1512]]
# Finished for Original with k = 1
# Finished for Original with k = 5
# Finished for Original with k = 11
# Finished for Original with k = 51
# Finished for Original with k = 101
# Finished for Original with k = 201
# Finished for Original with k = 301
# Finished for Original with k = 501
# Finished for Original with k = 1001
# Finished for Original with k = 2001
# Finished for Original with k = 5001
# Finished for Original with k = 8001
# Best F1 Score for Original Corpus (k=51, metric=cosine): 0.8610, Test time: 1.5353 s
# Confusion Matrix:
#  [[2257  545]
#  [ 270 2524]]
# Finished for Cleaned with k = 1
# Finished for Cleaned with k = 5
# Finished for Cleaned with k = 11
# Finished for Cleaned with k = 51
# Finished for Cleaned with k = 101
# Finished for Cleaned with k = 201
# Finished for Cleaned with k = 301
# Finished for Cleaned with k = 501
# Finished for Cleaned with k = 1001
# Finished for Cleaned with k = 2001
# Finished for Cleaned with k = 5001
# Finished for Cleaned with k = 8001
# Best F1 Score for Cleaned Corpus (k=11, metric=cosine): 0.8806, Test time: 1.1586 s
# Confusion Matrix:
#  [[1667  432]
#  [ 204 2345]]
#
# Metrics for Original Corpus with LSA (Euclidean Distance):
#         K  Training Accuracy  Test Accuracy  Precision    Recall        F1  \
# 0      1           0.999196       0.746962   0.855888  0.593057  0.700634
# 1      5           0.813279       0.753753   0.926506  0.550465  0.690615
# 2     11           0.780305       0.747320   0.946313  0.523622  0.674194
#
# Metrics for Cleaned Corpus with LSA (Cosine Distance):
#         K  Training Accuracy  Test Accuracy  Precision    Recall        F1  \
# 0      1           1.000000       0.822935   0.837109  0.840722  0.838912
# 1      5           0.901947       0.852625   0.843658  0.897607  0.869797
# 2     11           0.884897       0.863167   0.844436  0.919969  0.880586
# 3     51           0.862629       0.858434   0.823027  0.945077  0.879839
# 4    101           0.853163       0.848967   0.805289  0.955669  0.874058
# 5    201           0.837242       0.837349   0.785056  0.968615  0.867229
# 6    301           0.825247       0.827238   0.768946  0.979208  0.861432
# 7    501           0.806261       0.804862   0.742899  0.985092  0.847023
# 8   1001           0.767965       0.768933   0.705375  0.993723  0.825081
# 9   2001           0.723214       0.727410   0.668684  0.996862  0.800441
# 10  5001           0.647429       0.656411   0.614865  0.999608  0.761392
# 11  8001           0.567179       0.572074   0.561728  0.999608  0.719266
#
#     Test Time (s)
# 0        0.624343
# 1        1.156971
# 2        1.158601
# 3        1.213284
# 4        1.210098
# 5        1.257557
# 6        1.267670
# 7        1.319881
# 8        1.487339
# 9        1.824724
# 10       2.826805
# 11       3.833168

# %%
metrics_to_plot = ["Training Accuracy", "Test Accuracy", "Precision", "Recall", "F1", "Test Time (s)"]

df_lsa_original_euclidean["Metric"] = "Euclidean"
df_lsa_original_cosine["Metric"] = "Cosine"
df_lsa_original_combined = pd.concat([df_lsa_original_euclidean, df_lsa_original_cosine])

df_lsa_cleaned_euclidean["Metric"] = "Euclidean"
df_lsa_cleaned_cosine["Metric"] = "Cosine"
df_lsa_cleaned_combined = pd.concat([df_lsa_cleaned_euclidean, df_lsa_cleaned_cosine])

fig, axes = plt.subplots(len(metrics_to_plot), 2, figsize=(16, 36), sharey=True)
fig.suptitle("KNN Metrics for Original and Cleaned Corpora with LSA (Blue L2 | Orange Cosine)", fontsize=16)

for i, metric in enumerate(metrics_to_plot):
    sns.barplot(ax=axes[i, 0], y="K", x=metric, hue="Metric", data=df_lsa_original_combined, orient='h', 
                palette={"Euclidean": "royalblue", "Cosine": "orange"})
    axes[i, 0].set_title(f"Original Corpus with LSA - {metric}")
    axes[i, 0].get_legend().remove()

    sns.barplot(ax=axes[i, 1], y="K", x=metric, hue="Metric", data=df_lsa_cleaned_combined, orient='h', 
                palette={"Euclidean": "royalblue", "Cosine": "orange"})
    axes[i, 1].set_title(f"Cleaned Corpus with LSA - {metric}")
    axes[i, 1].get_legend().remove()

handles, labels = axes[0, 0].get_legend_handles_labels()
fig.legend(handles, labels, loc="upper right", title="Metric")

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
metrics_to_display = ["Training Accuracy", "Test Accuracy", "Precision", "Recall", "F1", "Test Time (s)"]

original_lsa_data = {}
for metric in metrics_to_display:
    if metric == "K":
        original_lsa_data[("K", "")] = df_lsa_original_euclidean["K"]
    else:
        original_lsa_data[(metric, "Euclidean")] = df_lsa_original_euclidean[metric].round(3)
        original_lsa_data[(metric, "Cosine")] = df_lsa_original_cosine[metric].round(3)

cleaned_lsa_data = {}
for metric in metrics_to_display:
    if metric == "K":
        cleaned_lsa_data[("K", "")] = df_lsa_cleaned_euclidean["K"]
    else:
        cleaned_lsa_data[(metric, "Euclidean")] = df_lsa_cleaned_euclidean[metric].round(3)
        cleaned_lsa_data[(metric, "Cosine")] = df_lsa_cleaned_cosine[metric].round(3)

df_lsa_original_combined = pd.DataFrame(original_lsa_data)
df_lsa_cleaned_combined = pd.DataFrame(cleaned_lsa_data)

print("Metrics Table for Original Corpus with LSA (Combined Euclidean and Cosine):")
display(apply_dual_heatmap_combined(df_lsa_original_combined))

print("\nMetrics Table for Cleaned Corpus with LSA (Combined Euclidean and Cosine):")
display(apply_dual_heatmap_combined(df_lsa_cleaned_combined))
# Out:
# Metrics Table for Original Corpus with LSA (Combined Euclidean and Cosine):
# <style type="text/css">
# #T_433cd_row0_col0, #T_433cd_row0_col6, #T_433cd_row0_col8, #T_433cd_row1_col2, #T_433cd_row9_col4, #T_433cd_row11_col10 {
#   background-color: #081d58;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row0_col1, #T_433cd_row1_col5, #T_433cd_row2_col5, #T_433cd_row3_col3, #T_433cd_row3_col9, #T_433cd_row10_col7, #T_433cd_row11_col7, #T_433cd_row11_col11 {
#   background-color: #7f0000;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row0_col2, #T_433cd_row2_col2 {
#   background-color: #12256d;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row0_col3 {
#   background-color: #a80000;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row0_col4, #T_433cd_row1_col10, #T_433cd_row9_col0, #T_433cd_row9_col2, #T_433cd_row9_col6, #T_433cd_row9_col8 {
#   background-color: #ffffd9;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_433cd_row0_col5 {
#   background-color: #940000;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row0_col7, #T_433cd_row0_col11, #T_433cd_row11_col1, #T_433cd_row11_col3, #T_433cd_row11_col5, #T_433cd_row11_col9 {
#   background-color: #fff7ec;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_433cd_row0_col9 {
#   background-color: #cd2316;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row0_col10, #T_433cd_row3_col10 {
#   background-color: #fafdcf;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_433cd_row1_col0 {
#   background-color: #39adc3;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row1_col1 {
#   background-color: #d52d1d;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row1_col3 {
#   background-color: #8a0000;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row1_col4 {
#   background-color: #31a5c2;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row1_col6 {
#   background-color: #21308b;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row1_col7 {
#   background-color: #fee4c0;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_433cd_row1_col8 {
#   background-color: #0d2163;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row1_col9 {
#   background-color: #a30000;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row1_col11 {
#   background-color: #fee2bb;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_433cd_row2_col0 {
#   background-color: #5bc0c0;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_433cd_row2_col1 {
#   background-color: #db3926;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row2_col3, #T_433cd_row4_col9 {
#   background-color: #810000;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row2_col4 {
#   background-color: #2072b1;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row2_col6 {
#   background-color: #24449c;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row2_col7 {
#   background-color: #fdd39d;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_433cd_row2_col8 {
#   background-color: #182a7a;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row2_col9 {
#   background-color: #8f0000;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row2_col10, #T_433cd_row10_col2, #T_433cd_row10_col6 {
#   background-color: #fdfed5;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_433cd_row2_col11, #T_433cd_row3_col11 {
#   background-color: #fee2bc;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_433cd_row3_col0 {
#   background-color: #99d7b8;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_433cd_row3_col1 {
#   background-color: #e24831;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row3_col2 {
#   background-color: #234c9f;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row3_col4 {
#   background-color: #234fa1;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row3_col5 {
#   background-color: #990000;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row3_col6 {
#   background-color: #1f7bb6;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row3_col7 {
#   background-color: #fc9b66;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_433cd_row3_col8 {
#   background-color: #234da0;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row4_col0 {
#   background-color: #b4e2b6;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_433cd_row4_col1 {
#   background-color: #e55038;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row4_col2 {
#   background-color: #1e8abd;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row4_col3 {
#   background-color: #840000;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row4_col4 {
#   background-color: #2354a3;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row4_col5 {
#   background-color: #b30000;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row4_col6 {
#   background-color: #33a7c2;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row4_col7 {
#   background-color: #f26e4c;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row4_col8 {
#   background-color: #1f7db6;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row4_col10 {
#   background-color: #fafdce;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_433cd_row4_col11, #T_433cd_row6_col11, #T_433cd_row10_col9 {
#   background-color: #fddbad;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_433cd_row5_col0 {
#   background-color: #d1edb3;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_433cd_row5_col1, #T_433cd_row7_col5 {
#   background-color: #e9583e;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row5_col2 {
#   background-color: #3cb1c3;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row5_col3 {
#   background-color: #8e0000;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row5_col4 {
#   background-color: #243f99;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row5_col5 {
#   background-color: #c51810;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row5_col6 {
#   background-color: #61c2bf;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_433cd_row5_col7 {
#   background-color: #de3f2b;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row5_col8 {
#   background-color: #32a6c2;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row5_col9 {
#   background-color: #890000;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row5_col10 {
#   background-color: #f3fabf;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_433cd_row5_col11 {
#   background-color: #fedfb4;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_433cd_row6_col0 {
#   background-color: #dff2b2;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_433cd_row6_col1 {
#   background-color: #ee6246;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row6_col2 {
#   background-color: #65c3bf;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_433cd_row6_col3 {
#   background-color: #9c0000;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row6_col4 {
#   background-color: #243c98;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row6_col5 {
#   background-color: #d42c1c;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row6_col6 {
#   background-color: #87d0ba;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_433cd_row6_col7 {
#   background-color: #d32a1b;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row6_col8 {
#   background-color: #50bbc2;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_433cd_row6_col9 {
#   background-color: #970000;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row6_col10 {
#   background-color: #eef8b3;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_433cd_row7_col0, #T_433cd_row11_col2 {
#   background-color: #f0f9b7;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_433cd_row7_col1 {
#   background-color: #f2704c;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_433cd_row7_col2 {
#   background-color: #c2e7b4;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_433cd_row7_col3, #T_433cd_row7_col9 {
#   background-color: #ba0906;
#   color: #f
# Metrics Table for Cleaned Corpus with LSA (Combined Euclidean and Cosine):
# <style type="text/css">
# #T_dc1f2_row0_col0, #T_dc1f2_row0_col6, #T_dc1f2_row0_col8, #T_dc1f2_row1_col2, #T_dc1f2_row10_col4, #T_dc1f2_row11_col10 {
#   background-color: #081d58;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_dc1f2_row0_col1, #T_dc1f2_row1_col5, #T_dc1f2_row2_col3, #T_dc1f2_row2_col5, #T_dc1f2_row2_col9, #T_dc1f2_row10_col7, #T_dc1f2_row11_col7, #T_dc1f2_row11_col11 {
#   background-color: #7f0000;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_dc1f2_row0_col2 {
#   background-color: #13266f;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_dc1f2_row0_col3, #T_dc1f2_row4_col5 {
#   background-color: #b70503;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_dc1f2_row0_col4, #T_dc1f2_row1_col10, #T_dc1f2_row9_col0, #T_dc1f2_row9_col2, #T_dc1f2_row9_col6, #T_dc1f2_row9_col8, #T_dc1f2_row10_col0, #T_dc1f2_row10_col6 {
#   background-color: #ffffd9;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_dc1f2_row0_col5 {
#   background-color: #890000;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_dc1f2_row0_col7, #T_dc1f2_row0_col11, #T_dc1f2_row11_col1, #T_dc1f2_row11_col3, #T_dc1f2_row11_col5, #T_dc1f2_row11_col9 {
#   background-color: #fff7ec;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_dc1f2_row0_col9 {
#   background-color: #d93422;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_dc1f2_row0_col10 {
#   background-color: #fdfed5;
#   color: #000000;
#   border-collapse: collapse;
# }
# #T_dc1f2_row1_col0 {
#   background-color: #2ca1c2;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_dc1f2_row1_col1 {
#   background-color: #cf2618;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_dc1f2_row1_col3 {
#   background-color: #8c0000;
#   color: #f1f1f1;
#   border-collapse: collapse;
# }
# #T_dc1f2_