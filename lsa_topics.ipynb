# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns
import time

import warnings
warnings.filterwarnings('ignore')

original_corpus = pd.read_csv('data/mental_health.csv')
cleaned_corpus = pd.read_csv('data/cleaned_mhc.csv')

print("Shape of Original Corpus", original_corpus.shape)
print("Shape of Cleaned Corpus", cleaned_corpus.shape)
# Out:
# Shape of Original Corpus (27977, 2)
# Shape of Cleaned Corpus (23240, 2)

# %%
from sklearn.decomposition import TruncatedSVD

highlight_terms = ['suicidal', 'depression', 'suicide', 'kill', 'myself', 'die',
                   'died', 'pain', 'sad', 'help', 'sorry', 'anxiety', 'therapy',
                   'suffering', 'killing', 'pill',
                   'movie', 'film', 'character', 'story', 'actor', 'performance', 'show',
                   'plot', 'acting']

n_topics = 3
n_top_words = 200

vectorizer = TfidfVectorizer(max_features=3500)
svd_model = TruncatedSVD(n_components=n_topics, random_state=42)

def display_topics(model, feature_names, num_top_words, highlight_terms):
    for idx, topic in enumerate(model.components_):
        top_words = [feature_names[i] for i in topic.argsort()[:-num_top_words - 1:-1]]
        top_words = [word.upper() if word in highlight_terms else word for word in top_words]
        print(f"Topic {idx + 1}: {', '.join(top_words)} \n")

X_original_tfidf = vectorizer.fit_transform(original_corpus['text'])
svd_model.fit(X_original_tfidf)
print("Top topics in Original Corpus:")
display_topics(svd_model, vectorizer.get_feature_names_out(), n_top_words, highlight_terms)

X_cleaned_tfidf = vectorizer.fit_transform(cleaned_corpus['text'])
svd_model.fit(X_cleaned_tfidf)
print("\nTop topics in Cleaned Corpus:")
display_topics(svd_model, vectorizer.get_feature_names_out(), n_top_words, highlight_terms)
# Out:
# Top topics in Original Corpus:
# Topic 1: im, like, want, feel, know, life, ive, me, cant, get, dont, people, even, really, one, would, time, it, think, going, never, go, friends, much, HELP, day, anymore, fucking, years, good, things, someone, anything, make, DIE, way, need, talk, better, end, could, everything, KILL, got, nothing, anyone, see, still, live, family, always, back, something, love, school, hate, every, MYSELF, ill, right, redflag, work, shit, ever, everyone, bad, say, year, this, last, now, tired, care, feeling, happy, friend, take, point, thing, since, person, parents, keep, tell, try, tried, job, thought, getting, told, also, alone, PAIN, long, around, fuck, thats, trying, find, wish, made, stop, do, away, well, done, DEPRESSION, enough, first, else, lot, hard, best, maybe, said, living, SUICIDAL, world, worse, many, give, thoughts, please, br, wanted, reason, that, sure, days, thinking, actually, depressed, ago, felt, mom, scared, hope, makes, months, up, started, them, without, lost, probably, though, today, out, girl, again, old, theres, home, little, left, times, id, MOVIE, SAD, her, cannot, SORRY, gonna, past, two, feels, sleep, night, post, look, pretty, hurt, another, come, able, already, let, wanna, might, new, here, put, went, all, to, mind, almost, wrong, guess, you, leave, FILM, great, death, finally, guys, money, dad, week, college
#
# Topic 2: br, MOVIE, FILM, one, the, great, good, STORY, films, movies, well, also, see, first, characters, would, CHARACTER, seen, best, watch, time, love, many, scenes, funny, PLOT, us, scene, two, little, man, ACTING, SHOW, made, cast, actors, saw, it, music, watching, quite, new, real, PERFORMANCE, comedy, could, excellent, action, young, role, part, interesting, series, dvd, director, must, beautiful, fun, wonderful, may, played, people, and, really, however, performances, big, like, way, though, horror, tv, original, perfect, war, although, lot, still, ever, shows, makes, especially, say, true, recommend, another, plays, much, got, watched, woman, found, bit, liked, fact, classic, american, look, old, different, ACTOR, thought, john, make, find, enjoyed, said, years, moments, takes, back, main, screen, course, version, script, later, pretty, hes, times, amazing, along, world, him, men, fan, remember, definitely, come, hollywood, worth, highly, cinema, in, three, seeing, together, simply, but, black, play, brilliant, far, goes, based, favorite, nice, entertaining, humor, comes, something, often, enjoy, audience, certainly, star, think, guy, seems, father, special, drama, effects, book, gives, work, perhaps, thing, almost, stars, kind, shot, truly, there, never, went, hilarious, wife, girl, came, dialogue, yes, early, short, whole, last, mr, rather, this, small, you, gets, production, is, set, playing, overall, loved, her, roles
#
# Topic 3: filler, wanna, text, bored, anyone, im, dm, talk, need, post, someone, yeah, guys, chat, ur, ask, idk, title, please, day, asking, rn, hey, horny, MOVIE, gonna, ampxb, yall, reddit, girl, girls, play, discord, blah, dms, pm, gay, favourite, open, really, anybody, award, comment, weird, send, bruh, karma, today, like, dont, you, lol, tell, watch, thats, tbh, pretty, awards, subreddit, questions, stuff, boys, everyone, kinda, server, good, posts, youre, whats, comments, lines, watched, game, among, cute, link, song, cool, guy, friend, yes, lonely, music, bro, fellow, sub, cat, fun, question, HELP, bot, yo, crush, listen, read, politics, looking, probably, using, interested, video, name, ring, free, idc, caught, amazing, tho, say, lmao, random, else, hi, theyre, knife, new, kids, also, right, gaming, group, imma, girlfriend, joke, join, gt, iq, scrolling, fuck, fill, rteenagers, first, finger, posting, use, grandmother, cringe, kick, us, tea, laugh, virgin, shes, wondering, goodnight, block, gang, ppl, prefer, halloween, advice, minecraft, dogs, number, lies, bf, CHARACTER, funny, whatever, ya, penis, super, thighs, not, voices, pls, loser, ship, rule, ok, naked, nice, alot, sea, favorite, messaged, luck, called, female, STORY, atm, cause, thanks, songs, stream, hit, tie, issues, said, board, door, code, bit, hot, one, rap, lyrics, lt, dumb, watching
#
#
# Top topics in Cleaned Corpus:
# Topic 1: im, want, like, feel, know, life, ive, get, cant, dont, friend, time, people, even, one, really, year, would, think, thing, day, going, go, HELP, never, make, much, anymore, fucking, thought, way, good, someone, anything, DIE, need, end, talk, better, everything, hate, love, nothing, KILL, family, live, see, could, always, anyone, feeling, school, care, still, say, something, every, got, back, work, redflag, right, ill, shit, keep, everyone, ever, last, take, bad, tired, tell, job, point, happy, parent, try, person, since, tried, month, getting, alone, PAIN, reason, also, told, find, fuck, long, wish, trying, give, lot, around, stop, DEPRESSION, away, done, girl, thats, SUICIDAL, hurt, week, hard, made, living, enough, best, else, well, worse, guy, MOVIE, maybe, world, first, said, many, come, please, hope, sure, ago, mom, depressed, thinking, wanted, scared, post, actually, look, today, felt, without, lost, night, let, problem, cry, probably, old, FILM, SAD, cannot, started, left, though, home, past, SORRY, little, gonna, sleep, already, two, might, able, pretty, put, another, wanna, hour, new, relationship, mind, wrong, mean, almost, guess, dad, death, place, leave, matter, went, great, money, start, seems, finally, college, gone, head, talking, used, ANXIETY, real, alive, making, sometimes, next, part, self, close, understand, kind, sick, change, nobody
#
# Topic 2: MOVIE, FILM, one, CHARACTER, great, STORY, good, scene, well, see, also, first, time, seen, watch, SHOW, best, would, ACTOR, PERFORMANCE, love, many, PLOT, funny, ACTING, made, little, cast, role, saw, man, two, make, comedy, watching, part, play, lot, music, director, new, woman, real, quite, action, excellent, fun, girl, look, fan, could, come, interesting, young, really, guy, dvd, like, must, beautiful, year, people, horror, wonderful, played, may, star, big, got, war, however, way, say, still, original, although, perfect, recommend, old, find, american, liked, song, though, especially, series, ever, bit, watched, classic, true, moment, fact, said, line, favorite, enjoyed, another, thing, kid, work, different, found, audience, pretty, give, amazing, viewer, child, screen, back, shot, definitely, main, remember, cinema, effect, john, book, course, hollywood, game, script, later, seeing, set, nice, highly, version, humor, enjoy, men, video, something, along, together, picture, father, entertaining, drama, kind, three, black, take, much, special, boy, simply, based, name, world, think, went, actress, dialogue, laugh, far, brilliant, often, minute, loved, came, playing, hilarious, almost, certainly, worth, lead, episode, small, brother, short, seems, yes, comment, last, whole, top, art, production, wife, opinion, perhaps, early, place, experience, day, eye, budget, style, never, overall, truly, sound, genre, cannot, score, start, actually, meet
#
# Topic 3: im, MOVIE, FILM, gonna, ive, going, tired, cant, SORRY, bored, ill, CHARACTER, fucking, great, done, STORY, guy, wanna, school, scene, well, scared, girl, good, thats, watch, pretty, play, sure, class, seen, ACTOR, first, got, sick, tonight, probably, PERFORMANCE, funny, fuck, game, kinda, PLOT, man, reddit, also, looking, watching, post, cast, ready, ACTING, chat, job, SHOW, music, one, best, saw, new, comedy, bit, lol, director, fan, role, old, hour, posting, boy, two, excellent, hey, dvd, whats, favorite, goodbye, dad, fun, horror, test, yeah, yall, set, interesting, high, grade, star, song, gay, played, trying, american, little, bye, next, minute, cause, soon, teacher, original, wait, luck, nervous, tomorrow, young, war, playing, classic, recommend, guess, although, video, quite, must, screen, watched, entertaining, wonderful, see, lazy, finally, version, book, cool, glad, loser, final, script, shit, ugly, john, highly, viewer, piece, action, buy, failing, today, joke, comment, cinema, audience, age, hollywood, house, writing, line, failure, hilarious, enjoyed, humor, interested, starting, hot, cuz, woman, number, last, college, top, town, shes, wont, among, short, math, shot, surprised, pls, theyre, cute, wondering, white, dialogue, stuff, beautiful, english, thanks, supporting, disappointed, series, ANXIETY, overall, teen, picture, musical, early, student, damn, genre, kid, brilliant, fat, score, already, based, hair, lonely, straight

# %%
from sklearn.decomposition import TruncatedSVD

n_topics = 10
n_top_words = 10

vectorizer = TfidfVectorizer(max_features=3500)
svd_model = TruncatedSVD(n_components=n_topics, random_state=42)

def display_topics(model, feature_names, num_top_words):
    for idx, topic in enumerate(model.components_):
        top_words = [feature_names[i] for i in topic.argsort()[:-num_top_words - 1:-1]]
        print(f"Topic {idx + 1}: {', '.join(top_words)}")

X_original_tfidf = vectorizer.fit_transform(original_corpus['text'])
svd_model.fit(X_original_tfidf)
print("Top topics in Original Corpus:")
display_topics(svd_model, vectorizer.get_feature_names_out(), n_top_words)

X_cleaned_tfidf = vectorizer.fit_transform(cleaned_corpus['text'])
svd_model.fit(X_cleaned_tfidf)
print("\nTop topics in Cleaned Corpus:")
display_topics(svd_model, vectorizer.get_feature_names_out(), n_top_words)
# Out:
# Top topics in Original Corpus:
# Topic 1: im, like, want, feel, know, life, ive, me, cant, get
# Topic 2: br, movie, film, one, the, great, good, story, films, movies
# Topic 3: filler, wanna, text, bored, anyone, im, dm, talk, need, someone
# Topic 4: im, br, movie, film, gonna, bored, going, tired, the, ive
# Topic 5: want, dont, br, die, film, movie, fucking, kill, anymore, cant
# Topic 6: dont, talk, like, need, someone, wanna, help, please, anyone, know
# Topic 7: like, feel, dont, im, feels, feeling, movie, makes, br, people
# Topic 8: fucking, fuck, dont, shit, hate, people, wanna, guys, like, got
# Topic 9: dont, know, got, didnt, think, said, ive, told, mom, day
# Topic 10: want, day, wanna, school, got, die, guys, bored, im, girl
#
# Top topics in Cleaned Corpus:
# Topic 1: im, want, like, feel, know, life, ive, get, cant, dont
# Topic 2: movie, film, one, character, great, story, good, scene, well, see
# Topic 3: im, movie, film, gonna, ive, going, tired, cant, sorry, bored
# Topic 4: want, movie, dont, film, die, fucking, cant, anymore, hate, tired
# Topic 5: dont, like, talk, know, feel, someone, wanna, need, please, girl
# Topic 6: feel, like, im, feeling, movie, film, life, tired, nothing, sad
# Topic 7: fucking, fuck, shit, like, hate, girl, guy, school, people, wanna
# Topic 8: dont, know, year, ive, school, day, didnt, mom, got, doesnt
# Topic 9: want, friend, school, die, im, girl, really, day, game, got
# Topic 10: people, life, would, care, never, think, love, wish, person, thing

# %%
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
import numpy as np
from IPython.display import display, HTML

def style_df_with_highlights(df, highlight_terms):
    def highlight_words(val):
        if isinstance(val, str) and val.upper() in [term.upper() for term in highlight_terms]:
            return 'background-color: #800080'
        return ''
    
    return df.style.applymap(highlight_words)

def display_topics_tabular(model, feature_names, num_top_words, highlight_terms, words_per_row=15):
    topic_dfs = []
    
    for idx, topic in enumerate(model.components_):
        # Get top words for the topic
        top_words = [feature_names[i] for i in topic.argsort()[:-num_top_words - 1:-1]]
        # Apply highlighting (uppercase)
        top_words = [word.upper() if word in highlight_terms else word for word in top_words]
        
        # Calculate number of rows needed
        num_rows = (len(top_words) + words_per_row - 1) // words_per_row
        
        # Create a 2D array of words, padding with empty strings if necessary
        rows = []
        for row in range(num_rows):
            start_idx = row * words_per_row
            end_idx = min(start_idx + words_per_row, len(top_words))
            row_words = top_words[start_idx:end_idx]
            # Pad row with empty strings if needed
            row_words.extend([''] * (words_per_row - len(row_words)))
            rows.append(row_words)
        
        # Create DataFrame for this topic
        df = pd.DataFrame(
            rows,
            columns=[f'Token_{i+1}' for i in range(words_per_row)]
        )
        
        # Add topic number as index
        df.index = [f'Row_{i+1}' for i in range(len(df))]
        
        topic_dfs.append((idx + 1, df))

    # Display each topic's DataFrame with styling
    for topic_num, df in topic_dfs:
        print(f"\nTopic {topic_num}")
        
        # Apply styling and display
        styled_df = style_df_with_highlights(df, highlight_terms)
        
        # Display the styled DataFrame
        display(styled_df)
        print("\n")

# Example usage:
highlight_terms = ['suicidal', 'depression', 'suicide', 'kill', 'myself', 'die',
                   'died', 'pain', 'sad', 'help', 'sorry', 'anxiety', 'therapy',
                   'suffering', 'killing', 'pill', 'depressed', 'death', 'cry', 'redflag', 'tired',
                   'movie', 'film', 'character', 'story', 'actor', 'performance', 'show',
                   'plot', 'acting', 'scene', 'watch', 'seen', 'funny', 'dvd', 'drama', 
		   'dialouge', 'entertaining', 'hollywood', 'humor', 'star', 'horror', 'series',
		   'genre', 'production', 'cinema', 'effect', 'audience', 'picture', 'actress']

n_topics = 3
n_top_words = 195
vectorizer = TfidfVectorizer(max_features=3500)
svd_model = TruncatedSVD(n_components=n_topics, random_state=42)

# For cleaned corpus
X_cleaned_tfidf = vectorizer.fit_transform(cleaned_corpus['text'])
svd_model.fit(X_cleaned_tfidf)
print("\nTop topics in Cleaned Corpus:")
display_topics_tabular(svd_model, vectorizer.get_feature_names_out(), n_top_words, highlight_terms)
# Out:
# Top topics in Cleaned Corpus:
#
# Topic 1
# <style type="text/css">
# #T_dae25_row1_col8, #T_dae25_row2_col4, #T_dae25_row2_col13, #T_dae25_row4_col0, #T_dae25_row4_col10, #T_dae25_row5_col8, #T_dae25_row6_col6, #T_dae25_row6_col11, #T_dae25_row7_col8, #T_dae25_row8_col5, #T_dae25_row9_col4, #T_dae25_row9_col7, #T_dae25_row9_col8, #T_dae25_row10_col0, #T_dae25_row11_col6, #T_dae25_row12_col6 {
#   background-color: #800080;
# }
# </style>
# <table id="T_dae25">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dae25_level0_col0" class="col_heading level0 col0" >Token_1</th>
#       <th id="T_dae25_level0_col1" class="col_heading level0 col1" >Token_2</th>
#       <th id="T_dae25_level0_col2" class="col_heading level0 col2" >Token_3</th>
#       <th id="T_dae25_level0_col3" class="col_heading level0 col3" >Token_4</th>
#       <th id="T_dae25_level0_col4" class="col_heading level0 col4" >Token_5</th>
#       <th id="T_dae25_level0_col5" class="col_heading level0 col5" >Token_6</th>
#       <th id="T_dae25_level0_col6" class="col_heading level0 col6" >Token_7</th>
#       <th id="T_dae25_level0_col7" class="col_heading level0 col7" >Token_8</th>
#       <th id="T_dae25_level0_col8" class="col_heading level0 col8" >Token_9</th>
#       <th id="T_dae25_level0_col9" class="col_heading level0 col9" >Token_10</th>
#       <th id="T_dae25_level0_col10" class="col_heading level0 col10" >Token_11</th>
#       <th id="T_dae25_level0_col11" class="col_heading level0 col11" >Token_12</th>
#       <th id="T_dae25_level0_col12" class="col_heading level0 col12" >Token_13</th>
#       <th id="T_dae25_level0_col13" class="col_heading level0 col13" >Token_14</th>
#       <th id="T_dae25_level0_col14" class="col_heading level0 col14" >Token_15</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dae25_level0_row0" class="row_heading level0 row0" >Row_1</th>
#       <td id="T_dae25_row0_col0" class="data row0 col0" >im</td>
#       <td id="T_dae25_row0_col1" class="data row0 col1" >want</td>
#       <td id="T_dae25_row0_col2" class="data row0 col2" >like</td>
#       <td id="T_dae25_row0_col3" class="data row0 col3" >feel</td>
#       <td id="T_dae25_row0_col4" class="data row0 col4" >know</td>
#       <td id="T_dae25_row0_col5" class="data row0 col5" >life</td>
#       <td id="T_dae25_row0_col6" class="data row0 col6" >ive</td>
#       <td id="T_dae25_row0_col7" class="data row0 col7" >get</td>
#       <td id="T_dae25_row0_col8" class="data row0 col8" >cant</td>
#       <td id="T_dae25_row0_col9" class="data row0 col9" >dont</td>
#       <td id="T_dae25_row0_col10" class="data row0 col10" >friend</td>
#       <td id="T_dae25_row0_col11" class="data row0 col11" >time</td>
#       <td id="T_dae25_row0_col12" class="data row0 col12" >people</td>
#       <td id="T_dae25_row0_col13" class="data row0 col13" >even</td>
#       <td id="T_dae25_row0_col14" class="data row0 col14" >one</td>
#     </tr>
#     <tr>
#       <th id="T_dae25_level0_row1" class="row_heading level0 row1" >Row_2</th>
#       <td id="T_dae25_row1_col0" class="data row1 col0" >really</td>
#       <td id="T_dae25_row1_col1" class="data row1 col1" >year</td>
#       <td id="T_dae25_row1_col2" class="data row1 col2" >would</td>
#       <td id="T_dae25_row1_col3" class="data row1 col3" >think</td>
#       <td id="T_dae25_row1_col4" class="data row1 col4" >thing</td>
#       <td id="T_dae25_row1_col5" class="data row1 col5" >day</td>
#       <td id="T_dae25_row1_col6" class="data row1 col6" >going</td>
#       <td id="T_dae25_row1_col7" class="data row1 col7" >go</td>
#       <td id="T_dae25_row1_col8" class="data row1 col8" >HELP</td>
#       <td id="T_dae25_row1_col9" class="data row1 col9" >never</td>
#       <td id="T_dae25_row1_col10" class="data row1 col10" >make</td>
#       <td id="T_dae25_row1_col11" class="data row1 col11" >much</td>
#       <td id="T_dae25_row1_col12" class="data row1 col12" >anymore</td>
#       <td id="T_dae25_row1_col13" class="data row1 col13" >fucking</td>
#       <td id="T_dae25_row1_col14" class="data row1 col14" >thought</td>
#     </tr>
#     <tr>
#       <th id="T_dae25_level0_row2" class="row_heading level0 row2" >Row_3</th>
#       <td id="T_dae25_row2_col0" class="data row2 col0" >way</td>
#       <td id="T_dae25_row2_col1" class="data row2 col1" >good</td>
#       <td id="T_dae25_row2_col2" class="data row2 col2" >someone</td>
#       <td id="T_dae25_row2_col3" class="data row2 col3" >anything</td>
#       <td id="T_dae25_row2_col4" class="data row2 col4" >DIE</td>
#       <td id="T_dae25_row2_col5" class="data row2 col5" >need</td>
#       <td id="T_dae25_row2_col6" class="data row2 col6" >end</td>
#       <td id="T_dae25_row2_col7" class="data row2 col7" >talk</td>
#       <td id="T_dae25_row2_col8" class="data row2 col8" >better</td>
#       <td id="T_dae25_row2_col9" class="data row2 col9" >everything</td>
#       <td id="T_dae25_row2_col10" class="data row2 col10" >hate</td>
#       <td id="T_dae25_row2_col11" class="data row2 col11" >love</td>
#       <td id="T_dae25_row2_col12" class="data row2 col12" >nothing</td>
#       <td id="T_dae25_row2_col13" class="data row2 col13" >KILL</td>
#       <td id="T_dae25_row2_col14" class="data row2 col14" >family</td>
#     </tr>
#     <tr>
#       <th id="T_dae25_level0_row3" class="row_heading level0 row3" >Row_4</th>
#       <td id="T_dae25_row3_col0" class="data row3 col0" >live</td>
#       <td id="T_dae25_row3_col1" class="data row3 col1" >see</td>
#       <td id="T_dae25_row3_col2" class="data row3 col2" >could</td>
#       <td id="T_dae25_row3_col3" class="data row3 col3" >always</td>
#       <td id="T_dae25_row3_col4" class="data row3 col4" >anyone</td>
#       <td id="T_dae25_row3_col5" class="data row3 col5" >feeling</td>
#       <td id="T_dae25_row3_col6" class="data row3 col6" >school</td>
#       <td id="T_dae25_row3_col7" class="data row3 col7" >care</td>
#       <td id="T_dae25_row3_col8" class="data row3 col8" >still</td>
#       <td id="T_dae25_row3_col9" class="data row3 col9" >say</td>
#       <td id="T_dae25_row3_col10" class="data row3 col10" >something</td>
#       <td id="T_dae25_row3_col11" class="data row3 col11" >every</td>
#       <td id="T_dae25_row3_col12" class="data row3 col12" >got</td>
#       <td id="T_dae25_row3_col13" class="data row3 col13" >back</td>
#       <td id="T_dae25_row3_col14" class="data row3 col14" >work</td>
#     </tr>
#     <tr>
#       <th id="T_dae25_level0_row4" class="row_heading level0 row4" >Row_5</th>
#       <td id="T_dae25_row4_col0" class="data row4 col0" >REDFLAG</td>
#       <td id="T_dae25_row4_col1" class="data row4 col1" >right</td>
#       <td id="T_dae25_row4_col2" class="data row4 col2" >ill</td>
#       <td id="T_dae25_row4_col3" class="data row4 col3" >shit</td>
#       <td id="T_dae25_row4_col4" class="data row4 col4" >keep</td>
#       <td id="T_dae25_row4_col5" class="data row4 col5" >everyone</td>
#       <td id="T_dae25_row4_col6" class="data row4 col6" >ever</td>
#       <td id="T_dae25_row4_col7" class="data row4 col7" >last</td>
#       <td id="T_dae25_row4_col8" class="data row4 col8" >take</td>
#       <td id="T_dae25_row4_col9" class="data row4 col9" >bad</td>
#       <td id="T_dae25_row4_col10" class="data row4 col10" >TIRED</td>
#       <td id="T_dae25_row4_col11" class="data row4 col11" >tell</td>
#       <td id="T_dae25_row4_col12" class="data row4 col12" >job</td>
#       <td id="T_dae25_row4_col13" class="data row4 col13" >point</td>
#       <td id="T_dae25_row4_col14" class="data row4 col14" >happy</td>
#     </tr>
#     <tr>
#       <th id="T_dae25_level0_row5" class="row_heading level0 row5" >Row_6</th>
#       <td id="T_dae25_row5_col0" class="data row5 col0" >parent</td>
#       <td id="T_dae25_row5_col1" class="data row5 col1" >try</td>
#       <td id="T_dae25_row5_col2" class="data row5 col2" >person</td>
#       <td id="T_dae25_row5_col3" class="data row5 col3" >since</td>
#       <td id="T_dae25_row5_col4" class="data row5 col4" >tried</td>
#       <td id="T_dae25_row5_col5" class="data row5 col5" >month</td>
#       <td id="T_dae25_row5_col6" class="data row5 col6" >getting</td>
#       <td id="T_dae25_row5_col7" class="data row5 col7" >alone</td>
#       <td id=
# Topic 2
# <style type="text/css">
# #T_624cb_row0_col0, #T_624cb_row0_col1, #T_624cb_row0_col3, #T_624cb_row0_col5, #T_624cb_row0_col7, #T_624cb_row0_col13, #T_624cb_row0_col14, #T_624cb_row1_col0, #T_624cb_row1_col3, #T_624cb_row1_col4, #T_624cb_row1_col7, #T_624cb_row1_col8, #T_624cb_row1_col9, #T_624cb_row3_col11, #T_624cb_row4_col2, #T_624cb_row4_col6, #T_624cb_row5_col10, #T_624cb_row6_col13, #T_624cb_row7_col10, #T_624cb_row7_col11, #T_624cb_row8_col0, #T_624cb_row8_col9, #T_624cb_row9_col1, #T_624cb_row9_col3, #T_624cb_row9_col4, #T_624cb_row10_col3, #T_624cb_row11_col14, #T_624cb_row12_col14 {
#   background-color: #800080;
# }
# </style>
# <table id="T_624cb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_624cb_level0_col0" class="col_heading level0 col0" >Token_1</th>
#       <th id="T_624cb_level0_col1" class="col_heading level0 col1" >Token_2</th>
#       <th id="T_624cb_level0_col2" class="col_heading level0 col2" >Token_3</th>
#       <th id="T_624cb_level0_col3" class="col_heading level0 col3" >Token_4</th>
#       <th id="T_624cb_level0_col4" class="col_heading level0 col4" >Token_5</th>
#       <th id="T_624cb_level0_col5" class="col_heading level0 col5" >Token_6</th>
#       <th id="T_624cb_level0_col6" class="col_heading level0 col6" >Token_7</th>
#       <th id="T_624cb_level0_col7" class="col_heading level0 col7" >Token_8</th>
#       <th id="T_624cb_level0_col8" class="col_heading level0 col8" >Token_9</th>
#       <th id="T_624cb_level0_col9" class="col_heading level0 col9" >Token_10</th>
#       <th id="T_624cb_level0_col10" class="col_heading level0 col10" >Token_11</th>
#       <th id="T_624cb_level0_col11" class="col_heading level0 col11" >Token_12</th>
#       <th id="T_624cb_level0_col12" class="col_heading level0 col12" >Token_13</th>
#       <th id="T_624cb_level0_col13" class="col_heading level0 col13" >Token_14</th>
#       <th id="T_624cb_level0_col14" class="col_heading level0 col14" >Token_15</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_624cb_level0_row0" class="row_heading level0 row0" >Row_1</th>
#       <td id="T_624cb_row0_col0" class="data row0 col0" >MOVIE</td>
#       <td id="T_624cb_row0_col1" class="data row0 col1" >FILM</td>
#       <td id="T_624cb_row0_col2" class="data row0 col2" >one</td>
#       <td id="T_624cb_row0_col3" class="data row0 col3" >CHARACTER</td>
#       <td id="T_624cb_row0_col4" class="data row0 col4" >great</td>
#       <td id="T_624cb_row0_col5" class="data row0 col5" >STORY</td>
#       <td id="T_624cb_row0_col6" class="data row0 col6" >good</td>
#       <td id="T_624cb_row0_col7" class="data row0 col7" >SCENE</td>
#       <td id="T_624cb_row0_col8" class="data row0 col8" >well</td>
#       <td id="T_624cb_row0_col9" class="data row0 col9" >see</td>
#       <td id="T_624cb_row0_col10" class="data row0 col10" >also</td>
#       <td id="T_624cb_row0_col11" class="data row0 col11" >first</td>
#       <td id="T_624cb_row0_col12" class="data row0 col12" >time</td>
#       <td id="T_624cb_row0_col13" class="data row0 col13" >SEEN</td>
#       <td id="T_624cb_row0_col14" class="data row0 col14" >WATCH</td>
#     </tr>
#     <tr>
#       <th id="T_624cb_level0_row1" class="row_heading level0 row1" >Row_2</th>
#       <td id="T_624cb_row1_col0" class="data row1 col0" >SHOW</td>
#       <td id="T_624cb_row1_col1" class="data row1 col1" >best</td>
#       <td id="T_624cb_row1_col2" class="data row1 col2" >would</td>
#       <td id="T_624cb_row1_col3" class="data row1 col3" >ACTOR</td>
#       <td id="T_624cb_row1_col4" class="data row1 col4" >PERFORMANCE</td>
#       <td id="T_624cb_row1_col5" class="data row1 col5" >love</td>
#       <td id="T_624cb_row1_col6" class="data row1 col6" >many</td>
#       <td id="T_624cb_row1_col7" class="data row1 col7" >PLOT</td>
#       <td id="T_624cb_row1_col8" class="data row1 col8" >FUNNY</td>
#       <td id="T_624cb_row1_col9" class="data row1 col9" >ACTING</td>
#       <td id="T_624cb_row1_col10" class="data row1 col10" >made</td>
#       <td id="T_624cb_row1_col11" class="data row1 col11" >little</td>
#       <td id="T_624cb_row1_col12" class="data row1 col12" >cast</td>
#       <td id="T_624cb_row1_col13" class="data row1 col13" >role</td>
#       <td id="T_624cb_row1_col14" class="data row1 col14" >saw</td>
#     </tr>
#     <tr>
#       <th id="T_624cb_level0_row2" class="row_heading level0 row2" >Row_3</th>
#       <td id="T_624cb_row2_col0" class="data row2 col0" >man</td>
#       <td id="T_624cb_row2_col1" class="data row2 col1" >two</td>
#       <td id="T_624cb_row2_col2" class="data row2 col2" >make</td>
#       <td id="T_624cb_row2_col3" class="data row2 col3" >comedy</td>
#       <td id="T_624cb_row2_col4" class="data row2 col4" >watching</td>
#       <td id="T_624cb_row2_col5" class="data row2 col5" >part</td>
#       <td id="T_624cb_row2_col6" class="data row2 col6" >play</td>
#       <td id="T_624cb_row2_col7" class="data row2 col7" >lot</td>
#       <td id="T_624cb_row2_col8" class="data row2 col8" >music</td>
#       <td id="T_624cb_row2_col9" class="data row2 col9" >director</td>
#       <td id="T_624cb_row2_col10" class="data row2 col10" >new</td>
#       <td id="T_624cb_row2_col11" class="data row2 col11" >woman</td>
#       <td id="T_624cb_row2_col12" class="data row2 col12" >real</td>
#       <td id="T_624cb_row2_col13" class="data row2 col13" >quite</td>
#       <td id="T_624cb_row2_col14" class="data row2 col14" >action</td>
#     </tr>
#     <tr>
#       <th id="T_624cb_level0_row3" class="row_heading level0 row3" >Row_4</th>
#       <td id="T_624cb_row3_col0" class="data row3 col0" >excellent</td>
#       <td id="T_624cb_row3_col1" class="data row3 col1" >fun</td>
#       <td id="T_624cb_row3_col2" class="data row3 col2" >girl</td>
#       <td id="T_624cb_row3_col3" class="data row3 col3" >look</td>
#       <td id="T_624cb_row3_col4" class="data row3 col4" >fan</td>
#       <td id="T_624cb_row3_col5" class="data row3 col5" >could</td>
#       <td id="T_624cb_row3_col6" class="data row3 col6" >come</td>
#       <td id="T_624cb_row3_col7" class="data row3 col7" >interesting</td>
#       <td id="T_624cb_row3_col8" class="data row3 col8" >young</td>
#       <td id="T_624cb_row3_col9" class="data row3 col9" >really</td>
#       <td id="T_624cb_row3_col10" class="data row3 col10" >guy</td>
#       <td id="T_624cb_row3_col11" class="data row3 col11" >DVD</td>
#       <td id="T_624cb_row3_col12" class="data row3 col12" >like</td>
#       <td id="T_624cb_row3_col13" class="data row3 col13" >must</td>
#       <td id="T_624cb_row3_col14" class="data row3 col14" >beautiful</td>
#     </tr>
#     <tr>
#       <th id="T_624cb_level0_row4" class="row_heading level0 row4" >Row_5</th>
#       <td id="T_624cb_row4_col0" class="data row4 col0" >year</td>
#       <td id="T_624cb_row4_col1" class="data row4 col1" >people</td>
#       <td id="T_624cb_row4_col2" class="data row4 col2" >HORROR</td>
#       <td id="T_624cb_row4_col3" class="data row4 col3" >wonderful</td>
#       <td id="T_624cb_row4_col4" class="data row4 col4" >played</td>
#       <td id="T_624cb_row4_col5" class="data row4 col5" >may</td>
#       <td id="T_624cb_row4_col6" class="data row4 col6" >STAR</td>
#       <td id="T_624cb_row4_col7" class="data row4 col7" >big</td>
#       <td id="T_624cb_row4_col8" class="data row4 col8" >got</td>
#       <td id="T_624cb_row4_col9" class="data row4 col9" >war</td>
#       <td id="T_624cb_row4_col10" class="data row4 col10" >however</td>
#       <td id="T_624cb_row4_col11" class="data row4 col11" >way</td>
#       <td id="T_624cb_row4_col12" class="data row4 col12" >say</td>
#       <td id="T_624cb_row4_col13" class="data row4 col13" >still</td>
#       <td id="T_624cb_row4_col14" class="data row4 col14" >original</td>
#     </tr>
#     <tr>
#       <th id="T_624cb_level0_row5" class="row_heading level0 row5" >Row_6</th>
#       <td id="T_624cb_row5_col0" class="data row5 col0" >although</td>
#       <td id="T_624cb_row5_col1" class="data row5 col1" >perfect</td>
#       <td id="T_624cb_row5_col2" class="data row5 col2" >recommend</td>
#       <td id="T_624cb_row5_col3" class="data row5 col3" >old</td>
#       <td id="T_624cb_
# Topic 3
# <style type="text/css">
# #T_fc24f_row0_col1, #T_fc24f_row0_col2, #T_fc24f_row0_col6, #T_fc24f_row0_col8, #T_fc24f_row0_col11, #T_fc24f_row1_col0, #T_fc24f_row1_col4, #T_fc24f_row1_col10, #T_fc24f_row2_col0, #T_fc24f_row2_col1, #T_fc24f_row2_col7, #T_fc24f_row2_col8, #T_fc24f_row2_col12, #T_fc24f_row3_col6, #T_fc24f_row3_col9, #T_fc24f_row4_col13, #T_fc24f_row5_col4, #T_fc24f_row5_col12, #T_fc24f_row7_col12, #T_fc24f_row9_col6, #T_fc24f_row9_col7, #T_fc24f_row9_col9, #T_fc24f_row10_col1, #T_fc24f_row12_col1, #T_fc24f_row12_col2, #T_fc24f_row12_col5, #T_fc24f_row12_col10 {
#   background-color: #800080;
# }
# </style>
# <table id="T_fc24f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc24f_level0_col0" class="col_heading level0 col0" >Token_1</th>
#       <th id="T_fc24f_level0_col1" class="col_heading level0 col1" >Token_2</th>
#       <th id="T_fc24f_level0_col2" class="col_heading level0 col2" >Token_3</th>
#       <th id="T_fc24f_level0_col3" class="col_heading level0 col3" >Token_4</th>
#       <th id="T_fc24f_level0_col4" class="col_heading level0 col4" >Token_5</th>
#       <th id="T_fc24f_level0_col5" class="col_heading level0 col5" >Token_6</th>
#       <th id="T_fc24f_level0_col6" class="col_heading level0 col6" >Token_7</th>
#       <th id="T_fc24f_level0_col7" class="col_heading level0 col7" >Token_8</th>
#       <th id="T_fc24f_level0_col8" class="col_heading level0 col8" >Token_9</th>
#       <th id="T_fc24f_level0_col9" class="col_heading level0 col9" >Token_10</th>
#       <th id="T_fc24f_level0_col10" class="col_heading level0 col10" >Token_11</th>
#       <th id="T_fc24f_level0_col11" class="col_heading level0 col11" >Token_12</th>
#       <th id="T_fc24f_level0_col12" class="col_heading level0 col12" >Token_13</th>
#       <th id="T_fc24f_level0_col13" class="col_heading level0 col13" >Token_14</th>
#       <th id="T_fc24f_level0_col14" class="col_heading level0 col14" >Token_15</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc24f_level0_row0" class="row_heading level0 row0" >Row_1</th>
#       <td id="T_fc24f_row0_col0" class="data row0 col0" >im</td>
#       <td id="T_fc24f_row0_col1" class="data row0 col1" >MOVIE</td>
#       <td id="T_fc24f_row0_col2" class="data row0 col2" >FILM</td>
#       <td id="T_fc24f_row0_col3" class="data row0 col3" >gonna</td>
#       <td id="T_fc24f_row0_col4" class="data row0 col4" >ive</td>
#       <td id="T_fc24f_row0_col5" class="data row0 col5" >going</td>
#       <td id="T_fc24f_row0_col6" class="data row0 col6" >TIRED</td>
#       <td id="T_fc24f_row0_col7" class="data row0 col7" >cant</td>
#       <td id="T_fc24f_row0_col8" class="data row0 col8" >SORRY</td>
#       <td id="T_fc24f_row0_col9" class="data row0 col9" >bored</td>
#       <td id="T_fc24f_row0_col10" class="data row0 col10" >ill</td>
#       <td id="T_fc24f_row0_col11" class="data row0 col11" >CHARACTER</td>
#       <td id="T_fc24f_row0_col12" class="data row0 col12" >fucking</td>
#       <td id="T_fc24f_row0_col13" class="data row0 col13" >great</td>
#       <td id="T_fc24f_row0_col14" class="data row0 col14" >done</td>
#     </tr>
#     <tr>
#       <th id="T_fc24f_level0_row1" class="row_heading level0 row1" >Row_2</th>
#       <td id="T_fc24f_row1_col0" class="data row1 col0" >STORY</td>
#       <td id="T_fc24f_row1_col1" class="data row1 col1" >guy</td>
#       <td id="T_fc24f_row1_col2" class="data row1 col2" >wanna</td>
#       <td id="T_fc24f_row1_col3" class="data row1 col3" >school</td>
#       <td id="T_fc24f_row1_col4" class="data row1 col4" >SCENE</td>
#       <td id="T_fc24f_row1_col5" class="data row1 col5" >well</td>
#       <td id="T_fc24f_row1_col6" class="data row1 col6" >scared</td>
#       <td id="T_fc24f_row1_col7" class="data row1 col7" >girl</td>
#       <td id="T_fc24f_row1_col8" class="data row1 col8" >good</td>
#       <td id="T_fc24f_row1_col9" class="data row1 col9" >thats</td>
#       <td id="T_fc24f_row1_col10" class="data row1 col10" >WATCH</td>
#       <td id="T_fc24f_row1_col11" class="data row1 col11" >pretty</td>
#       <td id="T_fc24f_row1_col12" class="data row1 col12" >play</td>
#       <td id="T_fc24f_row1_col13" class="data row1 col13" >sure</td>
#       <td id="T_fc24f_row1_col14" class="data row1 col14" >class</td>
#     </tr>
#     <tr>
#       <th id="T_fc24f_level0_row2" class="row_heading level0 row2" >Row_3</th>
#       <td id="T_fc24f_row2_col0" class="data row2 col0" >SEEN</td>
#       <td id="T_fc24f_row2_col1" class="data row2 col1" >ACTOR</td>
#       <td id="T_fc24f_row2_col2" class="data row2 col2" >first</td>
#       <td id="T_fc24f_row2_col3" class="data row2 col3" >got</td>
#       <td id="T_fc24f_row2_col4" class="data row2 col4" >sick</td>
#       <td id="T_fc24f_row2_col5" class="data row2 col5" >tonight</td>
#       <td id="T_fc24f_row2_col6" class="data row2 col6" >probably</td>
#       <td id="T_fc24f_row2_col7" class="data row2 col7" >PERFORMANCE</td>
#       <td id="T_fc24f_row2_col8" class="data row2 col8" >FUNNY</td>
#       <td id="T_fc24f_row2_col9" class="data row2 col9" >fuck</td>
#       <td id="T_fc24f_row2_col10" class="data row2 col10" >game</td>
#       <td id="T_fc24f_row2_col11" class="data row2 col11" >kinda</td>
#       <td id="T_fc24f_row2_col12" class="data row2 col12" >PLOT</td>
#       <td id="T_fc24f_row2_col13" class="data row2 col13" >man</td>
#       <td id="T_fc24f_row2_col14" class="data row2 col14" >reddit</td>
#     </tr>
#     <tr>
#       <th id="T_fc24f_level0_row3" class="row_heading level0 row3" >Row_4</th>
#       <td id="T_fc24f_row3_col0" class="data row3 col0" >also</td>
#       <td id="T_fc24f_row3_col1" class="data row3 col1" >looking</td>
#       <td id="T_fc24f_row3_col2" class="data row3 col2" >watching</td>
#       <td id="T_fc24f_row3_col3" class="data row3 col3" >post</td>
#       <td id="T_fc24f_row3_col4" class="data row3 col4" >cast</td>
#       <td id="T_fc24f_row3_col5" class="data row3 col5" >ready</td>
#       <td id="T_fc24f_row3_col6" class="data row3 col6" >ACTING</td>
#       <td id="T_fc24f_row3_col7" class="data row3 col7" >chat</td>
#       <td id="T_fc24f_row3_col8" class="data row3 col8" >job</td>
#       <td id="T_fc24f_row3_col9" class="data row3 col9" >SHOW</td>
#       <td id="T_fc24f_row3_col10" class="data row3 col10" >music</td>
#       <td id="T_fc24f_row3_col11" class="data row3 col11" >one</td>
#       <td id="T_fc24f_row3_col12" class="data row3 col12" >best</td>
#       <td id="T_fc24f_row3_col13" class="data row3 col13" >saw</td>
#       <td id="T_fc24f_row3_col14" class="data row3 col14" >new</td>
#     </tr>
#     <tr>
#       <th id="T_fc24f_level0_row4" class="row_heading level0 row4" >Row_5</th>
#       <td id="T_fc24f_row4_col0" class="data row4 col0" >comedy</td>
#       <td id="T_fc24f_row4_col1" class="data row4 col1" >bit</td>
#       <td id="T_fc24f_row4_col2" class="data row4 col2" >lol</td>
#       <td id="T_fc24f_row4_col3" class="data row4 col3" >director</td>
#       <td id="T_fc24f_row4_col4" class="data row4 col4" >fan</td>
#       <td id="T_fc24f_row4_col5" class="data row4 col5" >role</td>
#       <td id="T_fc24f_row4_col6" class="data row4 col6" >old</td>
#       <td id="T_fc24f_row4_col7" class="data row4 col7" >hour</td>
#       <td id="T_fc24f_row4_col8" class="data row4 col8" >posting</td>
#       <td id="T_fc24f_row4_col9" class="data row4 col9" >boy</td>
#       <td id="T_fc24f_row4_col10" class="data row4 col10" >two</td>
#       <td id="T_fc24f_row4_col11" class="data row4 col11" >excellent</td>
#       <td id="T_fc24f_row4_col12" class="data row4 col12" >hey</td>
#       <td id="T_fc24f_row4_col13" class="data row4 col13" >DVD</td>
#       <td id="T_fc24f_row4_col14" class="data row4 col14" >whats</td>
#     </tr>
#     <tr>
#       <th id="T_fc24f_level0_row5" class="row_heading level0 row5" >Row_6</th>
#       <td id="T_fc24f_row5_col0" class="data row5 col0" >favorite</td>
#       <td id="T_fc24f_row5_col1" class="data row5 col1" >goodbye</td>
#       <td id="T_fc24f_row5_col2" class="data row5 col2" >dad</td>
#       <td id="T_fc24f_row5_col3" class="data row5 col3" >fun</td>
#       <td id="T_fc24f_row5_col4" class="data row5 col4" >
