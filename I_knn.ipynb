# %%
# Nhập thư viện
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import time

import warnings
warnings.filterwarnings('ignore')

# Đọc bộ dữ liệu
corpus = pd.read_csv('data/cleaned_mhc.csv')

# %%
# Chuẩn bị dữ liệu
X_train, X_test, y_train, y_test = train_test_split(
    corpus['text'],
    corpus['label'],
    test_size=0.2,
    random_state=42
)

tfidf = TfidfVectorizer(max_features=3500)
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

n_components = 100

lsa = TruncatedSVD(n_components=n_components, random_state=42)
X_train_lsa = lsa.fit_transform(X_train_tfidf)
X_test_lsa = lsa.transform(X_test_tfidf)

print(f"TF-IDF - Train shape: {X_train_tfidf.shape}, Test Shape: {X_test_tfidf.shape}")
print(f"LSA - Train shape: {X_train_lsa.shape}, Test Shape: {X_test_lsa.shape}")

import pandas as pd

print("Class distribution in y_train:")
print(pd.Series(y_train).value_counts())

print("\nClass distribution in y_test:")
print(pd.Series(y_test).value_counts())
# Out:
# TF-IDF - Train shape: (18592, 3500), Test Shape: (4648, 3500)
# LSA - Train shape: (18592, 100), Test Shape: (4648, 100)
# Class distribution in y_train:
# label
# 1    10099
# 0     8493
# Name: count, dtype: int64
#
# Class distribution in y_test:
# label
# 1    2549
# 0    2099
# Name: count, dtype: int64

# %%
k_values = [1, 5, 10, 50, 100, 200, 500, 1000, 2000, 4000]
metrics = ['euclidean', 'cosine']
datasets = {'TF-IDF': (X_train_tfidf, X_test_tfidf), 'LSA': (X_train_lsa, X_test_lsa)}

results = pd.DataFrame(columns=['Dataset', 'Distance', 'K', 'Train Accuracy', 'Test Accuracy',
                                'F1 Score', 'Precision', 'Recall', 'Test Time (s)'])

for dataset_name, (X_train, X_test) in datasets.items():
    for metric in metrics:
        for k in k_values:
            knn = KNeighborsClassifier(n_neighbors=k, metric=metric)
            
            knn.fit(X_train, y_train)
            start_time = time.time()
            y_pred = knn.predict(X_test)
            test_time = time.time() - start_time
            
            train_accuracy = knn.score(X_train, y_train)
            test_accuracy = accuracy_score(y_test, y_pred)
            f1 = f1_score(y_test, y_pred, average='weighted')
            precision = precision_score(y_test, y_pred, average='weighted')
            recall = recall_score(y_test, y_pred, average='weighted')
            
            results.loc[len(results)] = [dataset_name, metric, k, train_accuracy, test_accuracy, 
                                         f1, precision, recall, test_time]
            
            print(f"Finished KNN for {dataset_name} with {metric} distance at K={k}")

best_models = results.loc[results.groupby(['Dataset', 'Distance'])['F1 Score'].idxmax()]

for _, row in best_models.iterrows():
    best_knn = KNeighborsClassifier(n_neighbors=int(row['K']), metric=row['Distance'])
    best_knn.fit(datasets[row['Dataset']][0], y_train)
    y_best_pred = best_knn.predict(datasets[row['Dataset']][1])
    confusion = confusion_matrix(y_test, y_best_pred)
    
    print(f"\nBest model for {row['Dataset']} with {row['Distance']} distance and K={row['K']}:")
    print(f"Train Accuracy: {row['Train Accuracy']:.4f}, Test Accuracy: {row['Test Accuracy']:.4f}")
    print(f"F1 Score: {row['F1 Score']:.4f}, Precision: {row['Precision']:.4f}, Recall: {row['Recall']:.4f}")
    print(f"Test Time: {row['Test Time (s)']:.4f} seconds")
    print("Confusion Matrix:\n", confusion)
# Out:
# Finished KNN for TF-IDF with euclidean distance at K=1
# Finished KNN for TF-IDF with euclidean distance at K=5
# Finished KNN for TF-IDF with euclidean distance at K=10
# Finished KNN for TF-IDF with euclidean distance at K=50
# Finished KNN for TF-IDF with euclidean distance at K=100
# Finished KNN for TF-IDF with euclidean distance at K=200
# Finished KNN for TF-IDF with euclidean distance at K=500
# Finished KNN for TF-IDF with euclidean distance at K=1000
# Finished KNN for TF-IDF with euclidean distance at K=2000
# Finished KNN for TF-IDF with euclidean distance at K=4000
# Finished KNN for TF-IDF with cosine distance at K=1
# Finished KNN for TF-IDF with cosine distance at K=5
# Finished KNN for TF-IDF with cosine distance at K=10
# Finished KNN for TF-IDF with cosine distance at K=50
# Finished KNN for TF-IDF with cosine distance at K=100
# Finished KNN for TF-IDF with cosine distance at K=200
# Finished KNN for TF-IDF with cosine distance at K=500
# Finished KNN for TF-IDF with cosine distance at K=1000
# Finished KNN for TF-IDF with cosine distance at K=2000
# Finished KNN for TF-IDF with cosine distance at K=4000
# Finished KNN for LSA with euclidean distance at K=1
# Finished KNN for LSA with euclidean distance at K=5
# Finished KNN for LSA with euclidean distance at K=10
# Finished KNN for LSA with euclidean distance at K=50
# Finished KNN for LSA with euclidean distance at K=100
# Finished KNN for LSA with euclidean distance at K=200
# Finished KNN for LSA with euclidean distance at K=500
# Finished KNN for LSA with euclidean distance at K=1000
# Finished KNN for LSA with euclidean distance at K=2000
# Finished KNN for LSA with euclidean distance at K=4000
# Finished KNN for LSA with cosine distance at K=1
# Finished KNN for LSA with cosine distance at K=5
# Finished KNN for LSA with cosine distance at K=10
# Finished KNN for LSA with cosine distance at K=50
# Finished KNN for LSA with cosine distance at K=100
# Finished KNN for LSA with cosine distance at K=200
# Finished KNN for LSA with cosine distance at K=500
# Finished KNN for LSA with cosine distance at K=1000
# Finished KNN for LSA with cosine distance at K=2000
# Finished KNN for LSA with cosine distance at K=4000
#
# Best model for LSA with cosine distance and K=10:
# Train Accuracy: 0.8905, Test Accuracy: 0.8655
# F1 Score: 0.8653, Precision: 0.8655, Recall: 0.8655
# Test Time: 1.1908 seconds
# Confusion Matrix:
#  [[1750  349]
#  [ 276 2273]]
#
# Best model for LSA with euclidean distance and K=5:
# Train Accuracy: 0.8456, Test Accuracy: 0.7898
# F1 Score: 0.7879, Precision: 0.8256, Recall: 0.7898
# Test Time: 0.2998 seconds
# Confusion Matrix:
#  [[1971  128]
#  [ 849 1700]]
#
# Best model for TF-IDF with cosine distance and K=50:
# Train Accuracy: 0.8844, Test Accuracy: 0.8825
# F1 Score: 0.8811, Precision: 0.8887, Recall: 0.8825
# Test Time: 2.7225 seconds
# Confusion Matrix:
#  [[1664  435]
#  [ 111 2438]]
#
# Best model for TF-IDF with euclidean distance and K=50:
# Train Accuracy: 0.8892, Test Accuracy: 0.8883
# F1 Score: 0.8874, Precision: 0.8920, Recall: 0.8883
# Test Time: 2.8669 seconds
# Confusion Matrix:
#  [[1712  387]
#  [ 132 2417]]

# %% [markdown]
# $
# \begin{bmatrix}
# \text{True Negative (TN) - Class 0} & \text{False Positive (FP) - Predict 1 but 0} \\
# \text{False Negative (FN) - Predict 0 but 1} & \text{True Positive (TP) - Class 1} \\
# \end{bmatrix}
# $

# %%
# Pivot tables for TF-IDF and LSA
tfidf_table = results[results["Dataset"] == "TF-IDF"].pivot(index="K", columns="Distance", values=[
    "Train Accuracy", "Test Accuracy", "F1 Score", "Precision", "Recall", "Test Time (s)"
])

lsa_table = results[results["Dataset"] == "LSA"].pivot(index="K", columns="Distance", values=[
    "Train Accuracy", "Test Accuracy", "F1 Score", "Precision", "Recall", "Test Time (s)"
])

# Function to apply dual heatmap styling
def apply_dual_heatmap(styler):
    # Select columns for euclidean and cosine distances
    euclidean_columns = [col for col in styler.columns if col[1] == 'euclidean']
    styler = styler.background_gradient(subset=euclidean_columns, cmap='Reds')
    
    cosine_columns = [col for col in styler.columns if col[1] == 'cosine']
    styler = styler.background_gradient(subset=cosine_columns, cmap='Blues')
    
    return styler

# Apply styling and formatting with 3 decimal points
tfidf_table_styled = tfidf_table.style.pipe(apply_dual_heatmap).format(precision=3)
lsa_table_styled = lsa_table.style.pipe(apply_dual_heatmap).format(precision=3)

# Display the tables with dual heatmap
print("TF-IDF Table with Dual Heatmap:")
display(tfidf_table_styled)

print("\nLSA Table with Dual Heatmap:")
display(lsa_table_styled)
# Out:
# TF-IDF Table with Dual Heatmap:
# <style type="text/css">
# #T_9e8ba_row0_col0, #T_9e8ba_row3_col2, #T_9e8ba_row3_col4, #T_9e8ba_row3_col6, #T_9e8ba_row3_col8, #T_9e8ba_row9_col10 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_9e8ba_row0_col1, #T_9e8ba_row3_col3, #T_9e8ba_row3_col5, #T_9e8ba_row3_col7, #T_9e8ba_row3_col9, #T_9e8ba_row8_col11 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_9e8ba_row0_col2, #T_9e8ba_row0_col8 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_9e8ba_row0_col3, #T_9e8ba_row0_col5, #T_9e8ba_row0_col7, #T_9e8ba_row0_col9, #T_9e8ba_row0_col11, #T_9e8ba_row9_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_9e8ba_row0_col4, #T_9e8ba_row5_col6 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_9e8ba_row0_col6, #T_9e8ba_row6_col10 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_9e8ba_row0_col10, #T_9e8ba_row9_col0, #T_9e8ba_row9_col2, #T_9e8ba_row9_col4, #T_9e8ba_row9_col6, #T_9e8ba_row9_col8 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_9e8ba_row1_col0 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_9e8ba_row1_col1 {
#   background-color: #f96245;
#   color: #f1f1f1;
# }
# #T_9e8ba_row1_col2, #T_9e8ba_row1_col8 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_9e8ba_row1_col3, #T_9e8ba_row1_col9, #T_9e8ba_row2_col1 {
#   background-color: #e12d26;
#   color: #f1f1f1;
# }
# #T_9e8ba_row1_col4, #T_9e8ba_row2_col2, #T_9e8ba_row2_col8 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_9e8ba_row1_col5, #T_9e8ba_row9_col11 {
#   background-color: #ca181d;
#   color: #f1f1f1;
# }
# #T_9e8ba_row1_col6 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_9e8ba_row1_col7 {
#   background-color: #da2723;
#   color: #f1f1f1;
# }
# #T_9e8ba_row1_col10 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_9e8ba_row1_col11 {
#   background-color: #fcc2aa;
#   color: #000000;
# }
# #T_9e8ba_row2_col0 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_9e8ba_row2_col3, #T_9e8ba_row2_col9 {
#   background-color: #9c0d14;
#   color: #f1f1f1;
# }
# #T_9e8ba_row2_col4 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_9e8ba_row2_col5 {
#   background-color: #8c0912;
#   color: #f1f1f1;
# }
# #T_9e8ba_row2_col6 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_9e8ba_row2_col7, #T_9e8ba_row5_col3, #T_9e8ba_row5_col9 {
#   background-color: #a30f15;
#   color: #f1f1f1;
# }
# #T_9e8ba_row2_col10 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_9e8ba_row2_col11 {
#   background-color: #fdc6b0;
#   color: #000000;
# }
# #T_9e8ba_row3_col0 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_9e8ba_row3_col1, #T_9e8ba_row6_col3, #T_9e8ba_row6_col9 {
#   background-color: #d21f20;
#   color: #f1f1f1;
# }
# #T_9e8ba_row3_col10 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_9e8ba_row3_col11, #T_9e8ba_row5_col11 {
#   background-color: #fcc1a8;
#   color: #000000;
# }
# #T_9e8ba_row4_col0 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_9e8ba_row4_col1 {
#   background-color: #e02c26;
#   color: #f1f1f1;
# }
# #T_9e8ba_row4_col2, #T_9e8ba_row4_col6, #T_9e8ba_row4_col8 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_9e8ba_row4_col3, #T_9e8ba_row4_col9 {
#   background-color: #7c0510;
#   color: #f1f1f1;
# }
# #T_9e8ba_row4_col4 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_9e8ba_row4_col5 {
#   background-color: #79040f;
#   color: #f1f1f1;
# }
# #T_9e8ba_row4_col7 {
#   background-color: #77040f;
#   color: #f1f1f1;
# }
# #T_9e8ba_row4_col10 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_9e8ba_row4_col11 {
#   background-color: #fdc5ae;
#   color: #000000;
# }
# #T_9e8ba_row5_col0 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_9e8ba_row5_col1 {
#   background-color: #f34a36;
#   color: #f1f1f1;
# }
# #T_9e8ba_row5_col2, #T_9e8ba_row5_col8 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_9e8ba_row5_col4 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_9e8ba_row5_col5 {
#   background-color: #980c13;
#   color: #f1f1f1;
# }
# #T_9e8ba_row5_col7 {
#   background-color: #940b13;
#   color: #f1f1f1;
# }
# #T_9e8ba_row5_col10 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_9e8ba_row6_col0 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_9e8ba_row6_col1 {
#   background-color: #fc8565;
#   color: #f1f1f1;
# }
# #T_9e8ba_row6_col2, #T_9e8ba_row6_col8 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_9e8ba_row6_col4 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_9e8ba_row6_col5 {
#   background-color: #c5171c;
#   color: #f1f1f1;
# }
# #T_9e8ba_row6_col6 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_9e8ba_row6_col7 {
#   background-color: #bd151a;
#   color: #f1f1f1;
# }
# #T_9e8ba_row6_col11 {
#   background-color: #fcb499;
#   color: #000000;
# }
# #T_9e8ba_row7_col0 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_9e8ba_row7_col1 {
#   background-color: #fcb398;
#   color: #000000;
# }
# #T_9e8ba_row7_col2, #T_9e8ba_row7_col8 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_9e8ba_row7_col3, #T_9e8ba_row7_col9, #T_9e8ba_row7_col11 {
#   background-color: #f34c37;
#   color: #f1f1f1;
# }
# #T_9e8ba_row7_col4 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_9e8ba_row7_col5 {
#   background-color: #ee3a2c;
#   color: #f1f1f1;
# }
# #T_9e8ba_row7_col6 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_9e8ba_row7_col7 {
#   background-color: #d92523;
#   color: #f1f1f1;
# }
# #T_9e8ba_row7_col10 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_9e8ba_row8_col0 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_9e8ba_row8_col1 {
#   background-color: #fedaca;
#   color: #000000;
# }
# #T_9e8ba_row8_col2, #T_9e8ba_row8_col8 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_9e8ba_row8_col3, #T_9e8ba_row8_col9 {
#   background-color: #fb7353;
#   color: #f1f1f1;
# }
# #T_9e8ba_row8_col4 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_9e8ba_row8_col5 {
#   background-color: #fa6849;
#   color: #f1f1f1;
# }
# #T_9e8ba_row8_col6 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_9e8ba_row8_col7 {
#   background-color: #ec382b;
#   color: #f1f1f1;
# }
# #T_9e8ba_row8_col10 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_9e8ba_row9_col3, #T_9e8ba_row9_col5, #T_9e8ba_row9_col9 {
#   background-color: #fc9e80;
#   color: #000000;
# }
# #T_9e8ba_row9_col7 {
#   background-color: #f5523a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9e8ba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9e8ba_level0_col0" class="col_heading level0 col0" colspan="2">Train Accuracy</th>
#       <th id="T_9e8ba_level0_col2" class="col_heading level0 col2" colspan="2">Test Accuracy</th>
#       <th id="T_9e8ba_level0_col4" class="col_heading level0 col4" colspan="2">F1 Score</th>
#       <th id="T_9e8ba_level0_col6" class="col_heading level0 col6" colspan="2">Precision</th>
#       <th id="T_9e8ba_level0_col8" class="col_heading level0 col8" colspan="2">Recall</th>
#       <th id="T_9e8ba_level0_col10" class="col_heading level0 col10" colspan="2">Test Time (s)</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Distance</th>
#       <th id="T_9e8ba_level1_col0" class="col_heading level1 col0" >cosine</th>
#       <th id="T_9e8ba_level1_col1" class="col_heading level1 col1" >euclidean</th>
#       <th id="T_9e8ba_level1_col2" class="col_heading level1 col2" >cosine</th>
#       <th id="T_9e8ba_level1_col3" class="col_heading level1 col3" >euclidean</th>
#       <th id="T_9e8ba_level1_col4" class="col_heading level1 col4" >cosine</th>
#       <th id="T_9e8ba_level1_col5" class="col_heading level1 col5" >euclidean</th>
#       <th id="T_9e8ba_level1_col6" class="col_heading level1 col6" >cosine</th>
#       <th id="T_9e8ba_level1_col7" class="col_heading level1 col7" >euclidean</th>
#       <th id="T_9e8ba_level1_col8" class="col_heading level1 col8" >cosine</th>
#       <th id="T_9e8ba_level1_col9" class="col_heading level1 col9" >euclidean</th>
#       <th id="T_9e8ba_level1_col10" class="col_heading level1 col10" >cosine</th>
#       <th id="T_9e8ba_level1_col11" class="col_heading level1 col11" >euclidean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >K</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</t
# LSA Table with Dual Heatmap:
# <style type="text/css">
# #T_5c803_row0_col0, #T_5c803_row2_col2, #T_5c803_row2_col4, #T_5c803_row2_col6, #T_5c803_row2_col8, #T_5c803_row9_col10 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_5c803_row0_col1, #T_5c803_row1_col3, #T_5c803_row1_col5, #T_5c803_row1_col7, #T_5c803_row1_col9, #T_5c803_row9_col11 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_5c803_row0_col2, #T_5c803_row0_col8 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_5c803_row0_col3, #T_5c803_row0_col9 {
#   background-color: #a91016;
#   color: #f1f1f1;
# }
# #T_5c803_row0_col4 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_5c803_row0_col5 {
#   background-color: #9c0d14;
#   color: #f1f1f1;
# }
# #T_5c803_row0_col6 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_5c803_row0_col7 {
#   background-color: #fcb095;
#   color: #000000;
# }
# #T_5c803_row0_col10, #T_5c803_row9_col0, #T_5c803_row9_col2, #T_5c803_row9_col4, #T_5c803_row9_col6, #T_5c803_row9_col8 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_5c803_row0_col11 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_5c803_row1_col0 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_5c803_row1_col1 {
#   background-color: #f14130;
#   color: #f1f1f1;
# }
# #T_5c803_row1_col2, #T_5c803_row1_col8 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_5c803_row1_col4, #T_5c803_row3_col4 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_5c803_row1_col6 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_5c803_row1_col10 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_5c803_row1_col11, #T_5c803_row2_col11, #T_5c803_row8_col7, #T_5c803_row9_col1, #T_5c803_row9_col3, #T_5c803_row9_col5, #T_5c803_row9_col9 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_5c803_row2_col0 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_5c803_row2_col1 {
#   background-color: #fb6d4d;
#   color: #f1f1f1;
# }
# #T_5c803_row2_col3, #T_5c803_row2_col9 {
#   background-color: #aa1016;
#   color: #f1f1f1;
# }
# #T_5c803_row2_col5 {
#   background-color: #a50f15;
#   color: #f1f1f1;
# }
# #T_5c803_row2_col7, #T_5c803_row3_col7 {
#   background-color: #900a12;
#   color: #f1f1f1;
# }
# #T_5c803_row2_col10 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_5c803_row3_col0 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_5c803_row3_col1 {
#   background-color: #fc8767;
#   color: #f1f1f1;
# }
# #T_5c803_row3_col2, #T_5c803_row3_col8 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_5c803_row3_col3, #T_5c803_row3_col9 {
#   background-color: #b71319;
#   color: #f1f1f1;
# }
# #T_5c803_row3_col5 {
#   background-color: #b11218;
#   color: #f1f1f1;
# }
# #T_5c803_row3_col6 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_5c803_row3_col10, #T_5c803_row8_col6 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_5c803_row3_col11 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_5c803_row4_col0 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_5c803_row4_col1 {
#   background-color: #fc9576;
#   color: #000000;
# }
# #T_5c803_row4_col2, #T_5c803_row4_col6, #T_5c803_row4_col8 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_5c803_row4_col3, #T_5c803_row4_col9 {
#   background-color: #cc191e;
#   color: #f1f1f1;
# }
# #T_5c803_row4_col4 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_5c803_row4_col5 {
#   background-color: #c4161c;
#   color: #f1f1f1;
# }
# #T_5c803_row4_col7 {
#   background-color: #b31218;
#   color: #f1f1f1;
# }
# #T_5c803_row4_col10, #T_5c803_row8_col4 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_5c803_row4_col11 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_5c803_row5_col0 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_5c803_row5_col1 {
#   background-color: #fca98c;
#   color: #000000;
# }
# #T_5c803_row5_col2, #T_5c803_row5_col8 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_5c803_row5_col3, #T_5c803_row5_col9 {
#   background-color: #ef3c2c;
#   color: #f1f1f1;
# }
# #T_5c803_row5_col4 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_5c803_row5_col5 {
#   background-color: #e53228;
#   color: #f1f1f1;
# }
# #T_5c803_row5_col6 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_5c803_row5_col7 {
#   background-color: #e83429;
#   color: #f1f1f1;
# }
# #T_5c803_row5_col10 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_5c803_row5_col11, #T_5c803_row8_col5 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_5c803_row6_col0 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_5c803_row6_col1 {
#   background-color: #fdc7b2;
#   color: #000000;
# }
# #T_5c803_row6_col2, #T_5c803_row6_col8 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_5c803_row6_col3, #T_5c803_row6_col7, #T_5c803_row6_col9 {
#   background-color: #fb7c5c;
#   color: #f1f1f1;
# }
# #T_5c803_row6_col4 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_5c803_row6_col5 {
#   background-color: #fb7050;
#   color: #f1f1f1;
# }
# #T_5c803_row6_col6 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_5c803_row6_col10 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_5c803_row6_col11 {
#   background-color: #fcb69b;
#   color: #000000;
# }
# #T_5c803_row7_col0 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_5c803_row7_col1 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_5c803_row7_col2, #T_5c803_row7_col8 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_5c803_row7_col3, #T_5c803_row7_col9 {
#   background-color: #fcbca2;
#   color: #000000;
# }
# #T_5c803_row7_col4 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_5c803_row7_col5 {
#   background-color: #fcb296;
#   color: #000000;
# }
# #T_5c803_row7_col6 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_5c803_row7_col7 {
#   background-color: #fdccb8;
#   color: #000000;
# }
# #T_5c803_row7_col10 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_5c803_row7_col11 {
#   background-color: #fb7757;
#   color: #f1f1f1;
# }
# #T_5c803_row8_col0 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_5c803_row8_col1 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_5c803_row8_col2, #T_5c803_row8_col8 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_5c803_row8_col3, #T_5c803_row8_col9 {
#   background-color: #fee8de;
#   color: #000000;
# }
# #T_5c803_row8_col10 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_5c803_row8_col11 {
#   background-color: #e43027;
#   color: #f1f1f1;
# }
# #T_5c803_row9_col7 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# </style>
# <table id="T_5c803">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5c803_level0_col0" class="col_heading level0 col0" colspan="2">Train Accuracy</th>
#       <th id="T_5c803_level0_col2" class="col_heading level0 col2" colspan="2">Test Accuracy</th>
#       <th id="T_5c803_level0_col4" class="col_heading level0 col4" colspan="2">F1 Score</th>
#       <th id="T_5c803_level0_col6" class="col_heading level0 col6" colspan="2">Precision</th>
#       <th id="T_5c803_level0_col8" class="col_heading level0 col8" colspan="2">Recall</th>
#       <th id="T_5c803_level0_col10" class="col_heading level0 col10" colspan="2">Test Time (s)</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Distance</th>
#       <th id="T_5c803_level1_col0" class="col_heading level1 col0" >cosine</th>
#       <th id="T_5c803_level1_col1" class="col_heading level1 col1" >euclidean</th>
#       <th id="T_5c803_level1_col2" class="col_heading level1 col2" >cosine</th>
#       <th id="T_5c803_level1_col3" class="col_heading level1 col3" >euclidean</th>
#       <th id="T_5c803_level1_col4" class="col_heading level1 col4" >cosine</th>
#       <th id="T_5c803_level1_col5" class="col_heading level1 col5" >euclidean</th>
#       <th id="T_5c803_level1_col6" class="col_heading level1 col6" >cosine</th>
#       <th id="T_5c803_level1_col7" class="col_heading level1 col7" >euclidean</th>
#       <th id="T_5c803_level1_col8" class="col_heading level1 col8" >cosine</th>
#       <th id="T_5c803_level1_col9" class="col_heading level1 col9" >euclidean</th>
#       <th id="T_5c803_level1_col10" class="col_heading level1 col10" >cosine</th>
#       <th id="T_5c803_level1_col11" class="col_heading level1 col11" >euclidean</th>
#     </tr>
#     <tr>
#       <th class="
